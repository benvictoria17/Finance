# %%
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import numpy as np
import pandas as pd
from collections import OrderedDict

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/Finance/master/dataset/Walmart%20Stock%20Price%20from%201972-2022/WMT.csv").set_index("Date")
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1972-08-25  0.063477  0.064697  0.063477  0.064453   0.036447  2508800
# 1972-08-28  0.064453  0.064941  0.064209  0.064209   0.036309   972800
# 1972-08-29  0.063965  0.063965  0.063477  0.063477   0.035895  1945600
# 1972-08-30  0.063477  0.063477  0.062988  0.063477   0.035895   409600
# 1972-08-31  0.062988  0.062988  0.062500  0.062500   0.035343   870400

# %%
class WLMRTSSTOCKPRICE(Dataset):
    def __init__(self, split = "Train"):
        super(WLMRTSSTOCKPRICE, self).__init__()
        df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/Finance/master/dataset/Walmart%20Stock%20Price%20from%201972-2022/WMT.csv").set_index("Date").sample(frac = 1)
        self.df_x = df[["Open", "High", "Low"]]
        self.df_y = df[["Close", "Adj Close"]]
        
        if split == "Train":
            self.x = torch.from_numpy(self.df_x.iloc[:10000].to_numpy()).type(torch.FloatTensor)
            self.y = torch.from_numpy(self.df_y.iloc[:10000].to_numpy()).type(torch.FloatTensor)
            self.len = self.x.shape[0]
        elif split == "Valid":
            self.x = torch.from_numpy(self.df_x.iloc[10000:12000].to_numpy()).type(torch.FloatTensor)
            self.y = torch.from_numpy(self.df_y.iloc[10000:12000].to_numpy()).type(torch.FloatTensor)
            self.len = self.x.shape[0]
        elif split == "Test":
            self.x = torch.from_numpy(self.df_x.iloc[12000:].to_numpy()).type(torch.FloatTensor)
            self.y = torch.from_numpy(self.df_y.iloc[12000:].to_numpy()).type(torch.FloatTensor)
            self.len = self.x.shape[0]
        else:
            print("Unknown Split")
        
        
    def __len__(self):
        return self.len
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]
train_dataset = WLMRTSSTOCKPRICE(split = "Train")
valid_dataset = WLMRTSSTOCKPRICE(split = "Valid")
test_dataset = WLMRTSSTOCKPRICE(split = "Test")

train_loader = DataLoader(train_dataset, batch_size = 128, shuffle = True)
valid_loader = DataLoader(valid_dataset, batch_size = 64, shuffle = False)
test_loader = DataLoader(test_dataset, batch_size = 1, shuffle = False)
class WLMRTNET(nn.Module):
    def __init__(self, input_size, number_of_classes, p = 0.1):
        super(WLMRTNET, self).__init__()
        self.input_layer = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(inplace = True),
            nn.Dropout(p = p)
        )
        
        self.h1 = nn.Sequential(
            nn.Linear(64, 256),
            nn.ReLU(inplace = True),
            nn.Dropout(p = p)
        )
        
        self.h2 = nn.Sequential(
            nn.Linear(256, 512),
            nn.ReLU(inplace = True),
            nn.Dropout(p = p)
        )
        
        self.h3 = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(inplace = True),
            nn.Dropout(p = p)
        )
        
        self.h4 = nn.Sequential(
            nn.Linear(256, 64),
            nn.ReLU(inplace = True),
            nn.Dropout(p = p)
        )
        
        self.output_layer = nn.Sequential(
            nn.Linear(64, number_of_classes)
        )
        
    def forward(self, x):
        x = F.relu(self.input_layer(x))
        x = F.relu(self.h1(x))
        x = F.relu(self.h2(x))
        x = F.relu(self.h3(x))
        x = F.relu(self.h4(x))
        x = self.output_layer(x)
        return x
model = WLMRTNET(3, 2, 0.0)
LEARNING_RATE = 0.0001
EPOCHS = 100
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = LEARNING_RATE, weight_decay = 0.001)
min_loss = np.inf

model.to(device)
# Out:
# WLMRTNET(
#   (input_layer): Sequential(
#     (0): Linear(in_features=3, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (h1): Sequential(
#     (0): Linear(in_features=64, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (h2): Sequential(
#     (0): Linear(in_features=256, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (h3): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (h4): Sequential(
#     (0): Linear(in_features=256, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.0, inplace=False)
#   )
#   (output_layer): Sequential(
#     (0): Linear(in_features=64, out_features=2, bias=True)
#   )
# )

# %%
def train(model, epochs, optimizer, criterion, min_loss):
    training_losses, valid_losses, accs = [],[],[]
    for epoch in range(epochs):
        train_loss = 0
        for x, y in train_loader:
            optimizer.zero_grad()
            x, y = x.to(device), y.to(device)
            yhat = model(x)
            loss = criterion(yhat, y)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
        training_losses.append(train_loss)
        
        with torch.no_grad():
            valid_loss = 0
            for x, y in valid_loader:
                x, y = x.to(device), y.to(device)
                yhat = model(x)
                loss = criterion(yhat, y)
                
                valid_loss += loss.item()
                
            valid_losses.append(valid_loss)
                
        print("EPOCH: {}.. \tTRAINING LOSS: {:.6F}.. \tVALID LOSS: {:.6F}".format(epoch + 1, train_loss, valid_loss))
        
        if valid_loss <= min_loss:
            print("Saving Model: {:.4f} ---> {:.4f}".format(min_loss, valid_loss))
            save_obj = OrderedDict([
                ("model", model.state_dict()),
                ("min_loss", min_loss)
            ])
            torch.save(save_obj, "/kaggle/working/wlmrt.pt")
            min_loss = valid_loss
            
    return training_losses, valid_loss, accs

# %%
training_loss, valid_loss, accs = train(model, EPOCHS, optimizer, criterion, min_loss)
# Out:
# EPOCH: 1.. 	TRAINING LOSS: 84632.871088.. 	VALID LOSS: 644.720412
# Saving Model: inf ---> 644.7204
# EPOCH: 2.. 	TRAINING LOSS: 1528.496832.. 	VALID LOSS: 602.878479
# Saving Model: 644.7204 ---> 602.8785
# EPOCH: 3.. 	TRAINING LOSS: 1433.758623.. 	VALID LOSS: 586.913805
# Saving Model: 602.8785 ---> 586.9138
# EPOCH: 4.. 	TRAINING LOSS: 1374.531817.. 	VALID LOSS: 560.584536
# Saving Model: 586.9138 ---> 560.5845
# EPOCH: 5.. 	TRAINING LOSS: 1317.468917.. 	VALID LOSS: 505.289371
# Saving Model: 560.5845 ---> 505.2894
# EPOCH: 6.. 	TRAINING LOSS: 1150.766778.. 	VALID LOSS: 528.198351
# EPOCH: 7.. 	TRAINING LOSS: 1009.820642.. 	VALID LOSS: 354.348148
# Saving Model: 505.2894 ---> 354.3481
# EPOCH: 8.. 	TRAINING LOSS: 725.327001.. 	VALID LOSS: 385.487185
# EPOCH: 9.. 	TRAINING LOSS: 612.037677.. 	VALID LOSS: 174.982761
# Saving Model: 354.3481 ---> 174.9828
# EPOCH: 10.. 	TRAINING LOSS: 355.973829.. 	VALID LOSS: 124.956701
# Saving Model: 174.9828 ---> 124.9567
# EPOCH: 11.. 	TRAINING LOSS: 266.442605.. 	VALID LOSS: 257.744101
# EPOCH: 12.. 	TRAINING LOSS: 279.906184.. 	VALID LOSS: 90.174849
# Saving Model: 124.9567 ---> 90.1748
# EPOCH: 13.. 	TRAINING LOSS: 223.484828.. 	VALID LOSS: 105.322472
# EPOCH: 14.. 	TRAINING LOSS: 200.467535.. 	VALID LOSS: 78.724614
# Saving Model: 90.1748 ---> 78.7246
# EPOCH: 15.. 	TRAINING LOSS: 181.527382.. 	VALID LOSS: 90.593767
# EPOCH: 16.. 	TRAINING LOSS: 191.096183.. 	VALID LOSS: 67.664216
# Saving Model: 78.7246 ---> 67.6642
# EPOCH: 17.. 	TRAINING LOSS: 174.054757.. 	VALID LOSS: 77.624618
# EPOCH: 18.. 	TRAINING LOSS: 180.665887.. 	VALID LOSS: 75.954392
# EPOCH: 19.. 	TRAINING LOSS: 156.927198.. 	VALID LOSS: 66.476793
# Saving Model: 67.6642 ---> 66.4768
# EPOCH: 20.. 	TRAINING LOSS: 149.273144.. 	VALID LOSS: 69.631097
# EPOCH: 21.. 	TRAINING LOSS: 146.319742.. 	VALID LOSS: 61.228858
# Saving Model: 66.4768 ---> 61.2289
# EPOCH: 22.. 	TRAINING LOSS: 145.848148.. 	VALID LOSS: 57.723927
# Saving Model: 61.2289 ---> 57.7239
# EPOCH: 23.. 	TRAINING LOSS: 152.103931.. 	VALID LOSS: 53.680799
# Saving Model: 57.7239 ---> 53.6808
# EPOCH: 24.. 	TRAINING LOSS: 163.806766.. 	VALID LOSS: 52.401201
# Saving Model: 53.6808 ---> 52.4012
# EPOCH: 25.. 	TRAINING LOSS: 143.927557.. 	VALID LOSS: 52.665802
# EPOCH: 26.. 	TRAINING LOSS: 146.976165.. 	VALID LOSS: 54.565375
# EPOCH: 27.. 	TRAINING LOSS: 152.885803.. 	VALID LOSS: 51.706629
# Saving Model: 52.4012 ---> 51.7066
# EPOCH: 28.. 	TRAINING LOSS: 145.148078.. 	VALID LOSS: 60.398140
# EPOCH: 29.. 	TRAINING LOSS: 137.146954.. 	VALID LOSS: 50.624949
# Saving Model: 51.7066 ---> 50.6249
# EPOCH: 30.. 	TRAINING LOSS: 140.381101.. 	VALID LOSS: 70.176983
# EPOCH: 31.. 	TRAINING LOSS: 165.703188.. 	VALID LOSS: 55.348543
# EPOCH: 32.. 	TRAINING LOSS: 148.318301.. 	VALID LOSS: 49.459357
# Saving Model: 50.6249 ---> 49.4594
# EPOCH: 33.. 	TRAINING LOSS: 150.514782.. 	VALID LOSS: 48.739976
# Saving Model: 49.4594 ---> 48.7400
# EPOCH: 34.. 	TRAINING LOSS: 163.961449.. 	VALID LOSS: 64.287706
# EPOCH: 35.. 	TRAINING LOSS: 155.059226.. 	VALID LOSS: 48.587195
# Saving Model: 48.7400 ---> 48.5872
# EPOCH: 36.. 	TRAINING LOSS: 137.878929.. 	VALID LOSS: 49.810891
# EPOCH: 37.. 	TRAINING LOSS: 136.444656.. 	VALID LOSS: 94.265005
# EPOCH: 38.. 	TRAINING LOSS: 159.036777.. 	VALID LOSS: 52.746541
# EPOCH: 39.. 	TRAINING LOSS: 137.775023.. 	VALID LOSS: 69.118815
# EPOCH: 40.. 	TRAINING LOSS: 139.635202.. 	VALID LOSS: 52.484009
# EPOCH: 41.. 	TRAINING LOSS: 148.263256.. 	VALID LOSS: 71.217814
# EPOCH: 42.. 	TRAINING LOSS: 150.893025.. 	VALID LOSS: 52.939698
# EPOCH: 43.. 	TRAINING LOSS: 148.944627.. 	VALID LOSS: 46.628259
# Saving Model: 48.5872 ---> 46.6283
# EPOCH: 44.. 	TRAINING LOSS: 134.538779.. 	VALID LOSS: 49.013220
# EPOCH: 45.. 	TRAINING LOSS: 137.548670.. 	VALID LOSS: 70.854632
# EPOCH: 46.. 	TRAINING LOSS: 144.798094.. 	VALID LOSS: 61.448985
# EPOCH: 47.. 	TRAINING LOSS: 139.547480.. 	VALID LOSS: 145.657964
# EPOCH: 48.. 	TRAINING LOSS: 142.932421.. 	VALID LOSS: 46.798502
# EPOCH: 49.. 	TRAINING LOSS: 145.133670.. 	VALID LOSS: 48.078324
# EPOCH: 50.. 	TRAINING LOSS: 133.884891.. 	VALID LOSS: 47.761622
# EPOCH: 51.. 	TRAINING LOSS: 141.923093.. 	VALID LOSS: 46.265294
# Saving Model: 46.6283 ---> 46.2653
# EPOCH: 52.. 	TRAINING LOSS: 154.674065.. 	VALID LOSS: 88.879121
# EPOCH: 53.. 	TRAINING LOSS: 154.061427.. 	VALID LOSS: 46.088175
# Saving Model: 46.2653 ---> 46.0882
# EPOCH: 54.. 	TRAINING LOSS: 130.530081.. 	VALID LOSS: 67.186622
# EPOCH: 55.. 	TRAINING LOSS: 151.308200.. 	VALID LOSS: 46.591176
# EPOCH: 56.. 	TRAINING LOSS: 145.324189.. 	VALID LOSS: 71.208094
# EPOCH: 57.. 	TRAINING LOSS: 137.254405.. 	VALID LOSS: 59.365905
# EPOCH: 58.. 	TRAINING LOSS: 138.509262.. 	VALID LOSS: 50.955077
# EPOCH: 59.. 	TRAINING LOSS: 131.796977.. 	VALID LOSS: 48.433285
# EPOCH: 60.. 	TRAINING LOSS: 129.882403.. 	VALID LOSS: 46.426326
# EPOCH: 61.. 	TRAINING LOSS: 131.958060.. 	VALID LOSS: 50.653995
# EPOCH: 62.. 	TRAINING LOSS: 133.444889.. 	VALID LOSS: 51.917988
# EPOCH: 63.. 	TRAINING LOSS: 145.462241.. 	VALID LOSS: 63.011997
# EPOCH: 64.. 	TRAINING LOSS: 140.779390.. 	VALID LOSS: 54.154258
# EPOCH: 65.. 	TRAINING LOSS: 152.854263.. 	VALID LOSS: 55.693902
# EPOCH: 66.. 	TRAINING LOSS: 139.964278.. 	VALID LOSS: 51.312476
# EPOCH: 67.. 	TRAINING LOSS: 137.097607.. 	VALID LOSS: 46.112182
# EPOCH: 68.. 	TRAINING LOSS: 143.984470.. 	VALID LOSS: 54.255041
# EPOCH: 69.. 	TRAINING LOSS: 141.533116.. 	VALID LOSS: 56.018203
# EPOCH: 70.. 	TRAINING LOSS: 136.672155.. 	VALID LOSS: 50.884446
# EPOCH: 71.. 	TRAINING LOSS: 144.025497.. 	VALID LOSS: 46.244844
# EPOCH: 72.. 	TRAINING LOSS: 139.210010.. 	VALID LOSS: 47.199190
# EPOCH: 73.. 	TRAINING LOSS: 140.526762.. 	VALID LOSS: 47.338741
# EPOCH: 74.. 	TRAINING LOSS: 137.389179.. 	VALID LOSS: 45.524330
# Saving Model: 46.0882 ---> 45.5243
# EPOCH: 75.. 	TRAINING LOSS: 146.880869.. 	VALID LOSS: 48.612650
# EPOCH: 76.. 	TRAINING LOSS: 142.887838.. 	VALID LOSS: 60.301873
# EPOCH: 77.. 	TRAINING LOSS: 150.719446.. 	VALID LOSS: 50.051494
# EPOCH: 78.. 	TRAINING LOSS: 139.253756.. 	VALID LOSS: 75.429296
# EPOCH: 79.. 	TRAINING LOSS: 172.475050.. 	VALID LOSS: 91.189549
# EPOCH: 80.. 	TRAINING LOSS: 149.905700.. 	VALID LOSS: 50.571470
# EPOCH: 81.. 	TRAINING LOSS: 143.613117.. 	VALID LOSS: 67.391600
# EPOCH: 82.. 	TRAINING LOSS: 133.980845.. 	VALID LOSS: 46.458591
# EPOCH: 83.. 	TRAINING LOSS: 135.910534.. 	VALID LOSS: 49.055669
# EPOCH: 84.. 	TRAINING LOSS: 133.396800.. 	VALID LOSS: 60.960328
# EPOCH: 85.. 	TRAINING LOSS: 136.165795.. 	VALID LOSS: 55.675286
# EPOCH: 86.. 	TRAINING LOSS: 137.196685.. 	VALID LOSS: 46.496778
# EPOCH: 87.. 	TRAINING LOSS: 137.512988.. 	VALID LOSS: 73.121182
# EPOCH: 88.. 	TRAINING LOSS: 138.570919.. 	VALID LOSS: 48.314272
# EPOCH: 89.. 	TRAINING LOSS: 140.137393.. 	VALID LOSS: 58.304103
# EPOCH: 90.. 	TRAINING LOSS: 131.049262.. 	VALID LOSS: 55.384541
# EPOCH: 91.. 	TRAINING LOSS: 136.680039.. 	VALID LOSS: 56.182587
# EPOCH: 92.. 	TRAINING LOSS: 141.767286.. 	VALID LOSS: 45.649000
# EPOCH: 93.. 	TRAINING LOSS: 143.689391.. 	VALID LOSS: 45.449146
# Saving Model: 45.5243 ---> 45.4491
# EPOCH: 94.. 	TRAINING LOSS: 132.810606.. 	VALID LOSS: 73.051557
# EPOCH: 95.. 	TRAINING LOSS: 144.314757.. 	VALID LOSS: 45.756443
# EPOCH: 96.. 	TRAINING LOSS: 150.653410.. 	VALID LOSS: 58.012039
# EPOCH: 97.. 	TRAINING LOSS: 137.731797.. 	VALID LOSS: 87.158426
# EPOCH: 98.. 	TRAINING LOSS: 152.753842.. 	VALID LOSS: 46.817361
# EPOCH: 99.. 	TRAINING LOSS: 129.676846.. 	VALID LOSS: 152.882003
# EPOCH: 100.. 	TRAINING LOSS: 150.043789.. 	VALID LOSS: 49.492265

# %%
count = 0
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        yhat = model(x)
        
        if count % 100 == 0:
            print("Predicted Close: {:.3f} True Close: {:.3f} \tPredicted Adj Close: {:.3f} True Adj Close: {:.3f}".format(yhat[0][0].item(), y[0][0].item(), yhat[0][1].item(), y[0][1].item()))
        count += 1
# Out:
# Predicted Close: 0.113 True Close: 0.066 	Predicted Adj Close: -0.008 True Adj Close: 0.038
# Predicted Close: 51.521 True Close: 50.900 	Predicted Adj Close: 36.679 True Adj Close: 37.843
# Predicted Close: 108.120 True Close: 107.520 	Predicted Adj Close: 103.360 True Adj Close: 103.127
# Predicted Close: 0.095 True Close: 0.024 	Predicted Adj Close: -0.018 True Adj Close: 0.014
# Predicted Close: 0.100 True Close: 0.042 	Predicted Adj Close: -0.015 True Adj Close: 0.024
