# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
nbasalariesprediction = pd.read_csv("../input/nba-salaries-prediction-in-20172018-season/2017-18_NBA_salary.csv")

nbasalariesprediction
# Out:
#              Player    Salary       NBA_Country  NBA_DraftNumber  Age   Tm  \
# 0           Zhou Qi    815615             China               43   22  HOU
# 1     Zaza Pachulia   3477600           Georgia               42   33  GSW
# 2     Zach Randolph  12307692               USA               19   36  SAC
# 3       Zach LaVine   3202217               USA               13   22  CHI
# 4      Zach Collins   3057240               USA               10   20  POR
# ..              ...       ...               ...              ...  ...  ...
# 480      Al Horford  27734405  Dominican Rep...                3   31  BOS
# 481     Abdel Nader   1167333             Egypt               58   24  BOS
# 482  Aaron Harrison     83129               USA               62   23  DAL
# 483    Aaron Gordon   5504420               USA                4   22  ORL
# 484    Aaron Brooks   2116955               USA               26   33  MIN
#
# ...

# %%
nbasalariesprediction.head()
# Out:
#           Player    Salary NBA_Country  NBA_DraftNumber  Age   Tm   G    MP  \
# 0        Zhou Qi    815615       China               43   22  HOU  16    87
# 1  Zaza Pachulia   3477600     Georgia               42   33  GSW  66   937
# 2  Zach Randolph  12307692         USA               19   36  SAC  59  1508
# 3    Zach LaVine   3202217         USA               13   22  CHI  24   656
# 4   Zach Collins   3057240         USA               10   20  POR  62   979
#
#     PER    TS%  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0   0.6  0.303  ...  18.2  19.5 -0.4  0.1 -0.2 -0.121 -10.6   0.5 -10.1  -0.2
# 1  16.8  0.608  ...  19.3  17.2  1.7  1.4  3.1  0.160  -0.6   1.3   0.8   0.7
# 2  17.3  0.529  ...  12.5  27.6  0.3  1.1  1.4  0.046  -0.6  -1.3  -1.9   0.0
# 3  14.6  0.499  ...   9.7  29.5 -0.1  0.5  0.4  0.027  -0.7  -2.0  -2.6  -0.1
# 4   8.2  0.487  ...  15.6  15.5 -0.4  1.2  0.8  0.038  -3.7   0.9  -2.9  -0.2
#
# [5 rows x 28 columns]

# %%
nbasalariesprediction.tail()
# Out:
#              Player    Salary       NBA_Country  NBA_DraftNumber  Age   Tm  \
# 480      Al Horford  27734405  Dominican Rep...                3   31  BOS
# 481     Abdel Nader   1167333             Egypt               58   24  BOS
# 482  Aaron Harrison     83129               USA               62   23  DAL
# 483    Aaron Gordon   5504420               USA                4   22  ORL
# 484    Aaron Brooks   2116955               USA               26   33  MIN
#
#       G    MP   PER    TS%  ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  \
# 480  70  2219  17.5  0.577  ...  14.3  18.4  3.8  3.8  7.6  0.164   1.1   3.0
# 481  44   463   5.7  0.464  ...  17.1  16.9 -0.6  0.7  0.0  0.004  -5.3   0.3
# 482   7   164   6.6  0.411  ...   3.9  14.4 -0.1  0.2  0.1  0.019  -3.2   0.3
# 483  55  1838  16.6  0.531  ...   9.7  24.5  1.1  1.9  3.0  0.078   0.1  -0.1
# 484  31   188  10.1  0.508  ...  11.9  19.7  0.1  0.1  0.2  0.039  -0.5  -3.7
#
#      BPM  VORP
# 480  4.1   3.4
# ...

# %%
nbasalariesprediction.describe()
# Out:
#              Salary  NBA_DraftNumber         Age           G           MP  \
# count  4.850000e+02       485.000000  485.000000  485.000000   485.000000
# mean   6.636507e+06        29.451546   26.263918   50.167010  1154.142268
# std    7.392602e+06        21.125760    4.272297   24.874872   811.357419
# min    4.608000e+04         1.000000   19.000000    1.000000     1.000000
# 25%    1.471382e+06        11.000000   23.000000   29.000000   381.000000
# 50%    3.202217e+06        25.000000   26.000000   59.000000  1134.000000
# 75%    1.000000e+07        47.000000   29.000000   71.000000  1819.000000
# max    3.468255e+07        62.000000   41.000000   79.000000  2898.000000
#
#               PER         TS%        3PAr         FTr        ORB%  ...  \
# count  485.000000  483.000000  483.000000  483.000000  485.000000  ...
# mean    13.260825    0.535387    0.337383    0.263404    4.873814  ...
# std      8.769280    0.112352    0.226894    0.294578    4.582810  ...
# ...

# %%
nbasalariesprediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player           485 non-null    object
#  1   Salary           485 non-null    int64
#  2   NBA_Country      485 non-null    object
#  3   NBA_DraftNumber  485 non-null    int64
#  4   Age              485 non-null    int64
#  5   Tm               485 non-null    object
#  6   G                485 non-null    int64
#  7   MP               485 non-null    int64
#  8   PER              485 non-null    float64
#  9   TS%              483 non-null    float64
#  10  3PAr             483 non-null    float64
#  11  FTr              483 non-null    float64
#  12  ORB%             485 non-null    float64
#  13  DRB%             485 non-null    float64
#  14  TRB%             485 non-null    float64
#  15  AST%             485 non-null    float64
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect("nbasalariesprediction.db")
c = conn.cursor()

# %%
nbasalariesprediction.to_sql("nbasalariesprediction", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM nbasalariesprediction""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'Zhou Qi',
#   815615,
#   'China',
#   43,
#   22,
#   'HOU',
#   16,
#   87,
#   0.6,
#   0.303,
#   0.593,
#   0.37,
#   6.5,
#   16.8,
#   11.7,
#   1.5,
#   1.1,
#   6.8,
#   18.2,
#   19.5,
#   -0.4,
#   0.1,
#   -0.2,
#   -0.121,
#   -10.6,
#   0.5,
#   -10.1,
#   -0.2),
#  (1,
#   'Zaza Pachulia',
#   3477600,
#   'Georgia',
#   42,
#   33,
#   'GSW',
#   66,
#   937,
#   16.8,
#   0.608,
#   0.004,
#   0.337,
#   11.0,
#   25.0,
#   18.5,
#   15.4,
#   1.9,
#   1.3,
#   19.3,
#   17.2,
#   1.7,
#   1.4,
#   3.1,
#   0.16,
#   -0.6,
#   1.3,
#   0.8,
#   0.7),
#  (2,
#   'Zach Randolph',
#   12307692,
#   'USA',
#   19,
#   36,
#   'SAC',
#   59,
#   1508,
#   17.3,
#   0.529,
#   0.193,
#   0.14,
#   7.0,
#   23.8,
#   15.0,
#   14.9,
#   1.4,
#   0.6,
#   12.5,
#   27.6,
#   0.3,
#   1.1,
#   1.4,
#   0.046,
#   -0.6,
#   -1.3,
#   -1.9,
#   0.0),
#  (3,
#   'Zach LaVine',
#   3202217,
#   'USA',
#   13,
#   22,
#   'CHI',
#   24,
#   656,
#   14.6,
#   0.499,
# ...

# %%
nbasalariesprediction.to_excel("nbasalariesprediction.xls")

pd.read_excel("nbasalariesprediction.xls")
# Out:
#      Unnamed: 0          Player    Salary       NBA_Country  NBA_DraftNumber  \
# 0             0         Zhou Qi    815615             China               43
# 1             1   Zaza Pachulia   3477600           Georgia               42
# 2             2   Zach Randolph  12307692               USA               19
# 3             3     Zach LaVine   3202217               USA               13
# 4             4    Zach Collins   3057240               USA               10
# ..          ...             ...       ...               ...              ...
# 480         480      Al Horford  27734405  Dominican Rep...                3
# 481         481     Abdel Nader   1167333             Egypt               58
# 482         482  Aaron Harrison     83129               USA               62
# 483         483    Aaron Gordon   5504420               USA                4
# 484         484    Aaron Brooks   2116955               USA               26
#
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('nba-salaries-prediction-in-20172018-season ', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('nba-salaries-prediction-in-20172018-season ')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
