# %%
 # !pip install yfinance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# matplotlib and seaborn are used for plotting graphs 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
 df = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-stock/master/fb-data.csv")

# %%
df.head()

# %%
df.head(254)

# %%
sns.lmplot(x='High', y='Volume', data=df)

plt.show()

# %%
sns.lmplot(x='High', y='Low', data=df)

plt.show()
