# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock-/blob/master/Autodesk%2C_Inc_(ADSK).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ADSK = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ADSK?period1=1565653563&period2=1597275963&interval=1d&events=history")

ADSK
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 0    2019-08-12  149.529999  150.360001  ...  148.869995  148.869995  2584800
# 1    2019-08-13  148.589996  154.520004  ...  151.809998  151.809998  1795400
# 2    2019-08-14  148.520004  148.669998  ...  146.919998  146.919998  2198600
# 3    2019-08-15  144.990005  144.990005  ...  142.919998  142.919998  3180500
# 4    2019-08-16  144.710007  145.320007  ...  144.130005  144.130005  1951800
# ..          ...         ...         ...  ...         ...         ...      ...
# 249  2020-08-06  243.639999  244.500000  ...  243.570007  243.570007   735900
# 250  2020-08-07  242.470001  242.470001  ...  236.240005  236.240005  1042900
# 251  2020-08-10  236.399994  236.929993  ...  231.880005  231.880005  1307700
# 252  2020-08-11  231.169998  232.789993  ...  228.789993  228.789993   927500
# 253  2020-08-12  229.300003  233.839996  ...  231.570007  231.570007   863906
#
# [254 rows x 7 columns]

# %%
ADSK.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2019-08-12  149.529999  150.360001  ...  148.869995  148.869995  2584800
# 1  2019-08-13  148.589996  154.520004  ...  151.809998  151.809998  1795400
# 2  2019-08-14  148.520004  148.669998  ...  146.919998  146.919998  2198600
# 3  2019-08-15  144.990005  144.990005  ...  142.919998  142.919998  3180500
# 4  2019-08-16  144.710007  145.320007  ...  144.130005  144.130005  1951800
#
# [5 rows x 7 columns]

# %%
ADSK.tail()
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 249  2020-08-06  243.639999  244.500000  ...  243.570007  243.570007   735900
# 250  2020-08-07  242.470001  242.470001  ...  236.240005  236.240005  1042900
# 251  2020-08-10  236.399994  236.929993  ...  231.880005  231.880005  1307700
# 252  2020-08-11  231.169998  232.789993  ...  228.789993  228.789993   927500
# 253  2020-08-12  229.300003  233.839996  ...  231.570007  231.570007   863906
#
# [5 rows x 7 columns]

# %%
ADSK.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  254.000000  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   182.590984  185.569842  179.693780  182.972481  182.972481  1.829542e+06
# std     33.210359   33.196766   32.887366   32.956663   32.956663  1.377011e+06
# min    131.429993  141.360001  125.379997  136.000000  136.000000  2.562000e+05
# 25%    150.804996  153.672505  148.147499  151.330002  151.330002  1.112150e+06
# 50%    179.440002  182.339996  177.610001  180.520004  180.520004  1.524850e+06
# 75%    203.614998  207.122501  200.467495  203.612503  203.612503  2.195175e+06
# max    250.300003  251.389999  243.070007  248.199997  248.199997  1.849840e+07

# %%
import sqlite3

# %%
conn = sqlite3.connect("ADSK.db")
c = conn.cursor()

# %%
c = conn.cursor()
conn = sqlite3.connect("ADSK.db")
c = conn.cursor()

# %%
ADSK.to_sql("ADSK", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM ADSK""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   '2019-08-12',
#   149.529999,
#   150.360001,
#   147.850006,
#   148.869995,
#   148.869995,
#   2584800),
#  (1,
#   '2019-08-13',
#   148.58999599999999,
#   154.520004,
#   148.139999,
#   151.809998,
#   151.809998,
#   1795400),
#  (2,
#   '2019-08-14',
#   148.520004,
#   148.669998,
#   143.610001,
#   146.919998,
#   146.919998,
#   2198600),
#  (3,
#   '2019-08-15',
#   144.990005,
#   144.990005,
#   141.46000700000002,
#   142.919998,
#   142.919998,
#   3180500),
#  (4,
#   '2019-08-16',
#   144.71000700000002,
#   145.320007,
#   143.53999299999998,
#   144.130005,
#   144.130005,
#   1951800),
#  (5,
#   '2019-08-19',
#   146.75,
#   146.800003,
#   145.46000700000002,
#   146.179993,
#   146.179993,
#   1900500),
#  (6,
#   '2019-08-20',
#   145.720001,
#   147.419998,
#   144.529999,
#   146.559998,
#   146.559998,
#   1078300),
#  (7,
#   '2019-08-21',
#   147.75,
#   148.100006,
#   145.009995,
#   145.949997,
#   145.949997,
#   1967100),
#  (8,
# ...

# %%
ADSK.to_excel("ADSK.xls")

pd.read_excel("ADSK.xls")
# Out:
#      Unnamed: 0        Date        Open  ...       Close   Adj Close   Volume
# 0             0  2019-08-12  149.529999  ...  148.869995  148.869995  2584800
# 1             1  2019-08-13  148.589996  ...  151.809998  151.809998  1795400
# 2             2  2019-08-14  148.520004  ...  146.919998  146.919998  2198600
# 3             3  2019-08-15  144.990005  ...  142.919998  142.919998  3180500
# 4             4  2019-08-16  144.710007  ...  144.130005  144.130005  1951800
# ..          ...         ...         ...  ...         ...         ...      ...
# 249         249  2020-08-06  243.639999  ...  243.570007  243.570007   735900
# 250         250  2020-08-07  242.470001  ...  236.240005  236.240005  1042900
# 251         251  2020-08-10  236.399994  ...  231.880005  231.880005  1307700
# 252         252  2020-08-11  231.169998  ...  228.789993  228.789993   927500
# 253         253  2020-08-12  229.300003  ...  231.570007  231.570007   863906
#
# [254 rows x 8 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Autodesk, Inc. (ADSK)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Autodesk, Inc. (ADSK)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
