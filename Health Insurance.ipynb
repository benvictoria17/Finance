# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/main/dataset/Health%20Insurance%20Coverage/states.csv")

# %%
df.head()
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# 1                                     390000
# 2                                    3288000
# 3                                    1365000
# 4                                   19552000
#
#    Marketplace Health Insurance Coverage (2016)  \
# 0                                        165534
# 1                                         17995
# 2                                        179445
# 3                                         63357
# 4                                       1415428
#
#    Marketplace Tax Credits (2016) Average Monthly Tax Credit (2016)  \
# 0                          152206                             $310
# 1                           16205                             $750
# 2                          124346                             $230
# 3                           56843                             $306
# 4                         1239893                             $309
#
#   State Medicaid Expansion (2016)  Medicaid Enrollment (2013)  \
# 0                           False                    799176.0
# 1                            True                    122334.0
# 2                            True                   1201770.0
# 3                            True                    556851.0
# 4                            True                   7755381.0
#
#    Medicaid Enrollment (2016)  Medicaid Enrollment Change (2013-2016)  \
# 0                      910775                                111599.0
# 1                      166625                                 44291.0
# 2                     1716198                                514428.0
# 3                      920194                                363343.0
# 4                    11843081                               4087700.0
#
#    Medicare Enrollment (2016)
# 0                      989855
# 1                       88966
# 2                     1175624
# 3                      606146
# 4                     5829777

# %%
df.isna().sum()
# Out:
# State                                           0
# Uninsured Rate (2010)                           0
# Uninsured Rate (2015)                           0
# Uninsured Rate Change (2010-2015)               0
# Health Insurance Coverage Change (2010-2015)    0
# Employer Health Insurance Coverage (2015)       0
# Marketplace Health Insurance Coverage (2016)    0
# Marketplace Tax Credits (2016)                  0
# Average Monthly Tax Credit (2016)               0
# State Medicaid Expansion (2016)                 1
# Medicaid Enrollment (2013)                      2
# Medicaid Enrollment (2016)                      0
# Medicaid Enrollment Change (2013-2016)          2
# Medicare Enrollment (2016)                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   State                                         52 non-null     object
#  1   Uninsured Rate (2010)                         52 non-null     object
#  2   Uninsured Rate (2015)                         52 non-null     object
#  3   Uninsured Rate Change (2010-2015)             52 non-null     object
#  4   Health Insurance Coverage Change (2010-2015)  52 non-null     int64
#  5   Employer Health Insurance Coverage (2015)     52 non-null     int64
#  6   Marketplace Health Insurance Coverage (2016)  52 non-null     int64
#  7   Marketplace Tax Credits (2016)                52 non-null     int64
#  8   Average Monthly Tax Credit (2016)             52 non-null     object
#  9   State Medicaid Expansion (2016)               51 non-null     object
#  10  Medicaid Enrollment (2013)                    50 non-null     float64
#  11  Medicaid Enrollment (2016)                    52 non-null     int64
#  12  Medicaid Enrollment Change (2013-2016)        50 non-null     float64
#  13  Medicare Enrollment (2016)                    52 non-null     int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 5.8+ KB

# %%
df["State Medicaid Expansion (2016)"].value_counts()
# Out:
# True     32
# False    19
# Name: State Medicaid Expansion (2016), dtype: int64

# %%
df["State Medicaid Expansion (2016)"].replace(np.nan, "True", inplace = True)

# %%
df["Medicaid Enrollment (2013)"].mean()
# Out:
# 2255699.08

# %%
df['Medicaid Enrollment (2013)'].replace(np.nan,2255699.08, inplace = True )

# %%
df["Medicaid Enrollment Change (2013-2016)"].mean()
# Out:
# 644246.28

# %%
df["Medicaid Enrollment Change (2013-2016)"].replace(np.nan, 6442246.28, inplace = True)

# %%
df.isna().sum()
# Out:
# State                                           0
# Uninsured Rate (2010)                           0
# Uninsured Rate (2015)                           0
# Uninsured Rate Change (2010-2015)               0
# Health Insurance Coverage Change (2010-2015)    0
# Employer Health Insurance Coverage (2015)       0
# Marketplace Health Insurance Coverage (2016)    0
# Marketplace Tax Credits (2016)                  0
# Average Monthly Tax Credit (2016)               0
# State Medicaid Expansion (2016)                 0
# Medicaid Enrollment (2013)                      0
# Medicaid Enrollment (2016)                      0
# Medicaid Enrollment Change (2013-2016)          0
# Medicare Enrollment (2016)                      0
# dtype: int64

# %%
df['State Medicaid Expansion (2016)'].replace('True', 1, inplace = True)
df['State Medicaid Expansion (2016)'].replace('False', 1, inplace = True)

# %%
df['Uninsured Rate (2010)'] = list(map(lambda x: x[:-1], df['Uninsured Rate (2010)'].values))
df['Uninsured Rate (2015)'] = list(map(lambda x: x[:-1], df['Uninsured Rate (2015)'].values))
df.head()
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                   14.6                  10.1
# 1     Alaska                   19.9                  14.9
# 2    Arizona                   16.9                  10.8
# 3   Arkansas                   17.5                   9.5
# 4  California                  18.5                   8.6
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# 1                                     390000
# 2                                    3288000
# 3                                    1365000
# 4                                   19552000
#
#    Marketplace Health Insurance Coverage (2016)  \
# 0                                        165534
# 1                                         17995
# 2                                        179445
# 3                                         63357
# 4                                       1415428
#
#    Marketplace Tax Credits (2016) Average Monthly Tax Credit (2016)  \
# 0                          152206                             $310
# 1                           16205                             $750
# 2                          124346                             $230
# 3                           56843                             $306
# 4                         1239893                             $309
#
#   State Medicaid Expansion (2016)  Medicaid Enrollment (2013)  \
# 0                           False                    799176.0
# 1                            True                    122334.0
# 2                            True                   1201770.0
# 3                            True                    556851.0
# 4                            True                   7755381.0
#
#    Medicaid Enrollment (2016)  Medicaid Enrollment Change (2013-2016)  \
# 0                      910775                                111599.0
# 1                      166625                                 44291.0
# 2                     1716198                                514428.0
# 3                      920194                                363343.0
# 4                    11843081                               4087700.0
#
#    Medicare Enrollment (2016)
# 0                      989855
# 1                       88966
# 2                     1175624
# 3                      606146
# 4                     5829777

# %%
df['Uninsured Rate Change (2010-2015)'] = list(map(lambda x: x[:-1], df['Uninsured Rate Change (2010-2015)'].values))
df.head()
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                   14.6                  10.1
# 1     Alaska                   19.9                  14.9
# 2    Arizona                   16.9                  10.8
# 3   Arkansas                   17.5                   9.5
# 4  California                  18.5                   8.6
#
#   Uninsured Rate Change (2010-2015)  \
# 0                             -4.5%
# 1                               -5%
# 2                             -6.1%
# 3                               -8%
# 4                             -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# 1                                     390000
# 2                                    3288000
# 3                                    1365000
# 4                                   19552000
#
#    Marketplace Health Insurance Coverage (2016)  \
# 0                                        165534
# 1                                         17995
# 2                                        179445
# 3                                         63357
# 4                                       1415428
#
#    Marketplace Tax Credits (2016) Average Monthly Tax Credit (2016)  \
# 0                          152206                             $310
# 1                           16205                             $750
# 2                          124346                             $230
# 3                           56843                             $306
# 4                         1239893                             $309
#
#   State Medicaid Expansion (2016)  Medicaid Enrollment (2013)  \
# 0                           False                    799176.0
# 1                            True                    122334.0
# 2                            True                   1201770.0
# 3                            True                    556851.0
# 4                            True                   7755381.0
#
#    Medicaid Enrollment (2016)  Medicaid Enrollment Change (2013-2016)  \
# 0                      910775                                111599.0
# 1                      166625                                 44291.0
# 2                     1716198                                514428.0
# 3                      920194                                363343.0
# 4                    11843081                               4087700.0
#
#    Medicare Enrollment (2016)
# 0                      989855
# 1                       88966
# 2                     1175624
# 3                      606146
# 4                     5829777

# %%
df['Uninsured Rate (2010)'] = [float(x) for x in df['Uninsured Rate (2010)'].values]
df['Uninsured Rate (2015)'] = [float(x) for x in df['Uninsured Rate (2015)'].values]
df['Uninsured Rate Change (2010-2015)'] = [float(x) for x in df['Uninsured Rate Change (2010-2015)'].values]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-1fcb5bbc2e2b> in <module>
#       1 df['Uninsured Rate (2010)'] = [float(x) for x in df['Uninsured Rate (2010)'].values]
#       2 df['Uninsured Rate (2015)'] = [float(x) for x in df['Uninsured Rate (2015)'].values]
# ----> 3 df['Uninsured Rate Change (2010-2015)'] = [float(x) for x in df['Uninsured Rate Change (2010-2015)'].values]
#
# <ipython-input-19-1fcb5bbc2e2b> in <listcomp>(.0)
#       1 df['Uninsured Rate (2010)'] = [float(x) for x in df['Uninsured Rate (2010)'].values]
#       2 df['Uninsured Rate (2015)'] = [float(x) for x in df['Uninsured Rate (2015)'].values]
# ----> 3 df['Uninsured Rate Change (2010-2015)'] = [float(x) for x in df['Uninsured Rate Change (2010-2015)'].values]
#
# ValueError: could not convert string to float: ' -4.5%'
