# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sqlite3

# %%
Employee = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Employee%20Attrition/Employee%20Data.csv")
Employee
# Out:
#     Gender Satisfaction Business Travel Department    EducationField  Salary  \
# 0   Female         High            Rare      Sales       Engineering  Medium
# 1     Male          Low        Frequent      Sales       Engineering     Low
# 2     Male       Medium            Rare        R&D             Other  Medium
# 3   Female          Low        Frequent        R&D       Engineering  Medium
# 4     Male       Medium            Rare        R&D           Medical  Medium
# ..     ...          ...             ...        ...               ...     ...
# 95  Female         High            Rare        R&D  Technical Degree  Medium
# 96  Female         High            Rare      Sales             Other     Low
# 97    Male         High              No      Sales           Medical  Medium
# 98    Male       Medium            Rare      Sales           Medical    High
# 99    Male          Low              No        R&D             Other     Low
#
#    Home-Office Attrition
# 0         Near       Yes
# 1         Near       Yes
# 2          Far        No
# 3          Far       Yes
# 4          Far        No
# ..         ...       ...
# 95        Near        No
# 96        Near       Yes
# 97        Near        No
# 98        Near        No
# 99         Far       Yes
#
# [100 rows x 8 columns]

# %%
Employee.head(101)
# Out:
#     Gender Satisfaction Business Travel Department    EducationField  Salary  \
# 0   Female         High            Rare      Sales       Engineering  Medium
# 1     Male          Low        Frequent      Sales       Engineering     Low
# 2     Male       Medium            Rare        R&D             Other  Medium
# 3   Female          Low        Frequent        R&D       Engineering  Medium
# 4     Male       Medium            Rare        R&D           Medical  Medium
# ..     ...          ...             ...        ...               ...     ...
# 95  Female         High            Rare        R&D  Technical Degree  Medium
# 96  Female         High            Rare      Sales             Other     Low
# 97    Male         High              No      Sales           Medical  Medium
# 98    Male       Medium            Rare      Sales           Medical    High
# 99    Male          Low              No        R&D             Other     Low
#
#    Home-Office Attrition
# 0         Near       Yes
# 1         Near       Yes
# 2          Far        No
# 3          Far       Yes
# 4          Far        No
# ..         ...       ...
# 95        Near        No
# 96        Near       Yes
# 97        Near        No
# 98        Near        No
# 99         Far       Yes
#
# [100 rows x 8 columns]

# %%
Employee.tail()
# Out:
#     Gender Satisfaction Business Travel Department    EducationField  Salary  \
# 95  Female         High            Rare        R&D  Technical Degree  Medium
# 96  Female         High            Rare      Sales             Other     Low
# 97    Male         High              No      Sales           Medical  Medium
# 98    Male       Medium            Rare      Sales           Medical    High
# 99    Male          Low              No        R&D             Other     Low
#
#    Home-Office Attrition
# 95        Near        No
# 96        Near       Yes
# 97        Near        No
# 98        Near        No
# 99         Far       Yes

# %%
Employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           100 non-null    object
#  1   Satisfaction     100 non-null    object
#  2   Business Travel  100 non-null    object
#  3   Department       100 non-null    object
#  4   EducationField   100 non-null    object
#  5   Salary           100 non-null    object
#  6   Home-Office      100 non-null    object
#  7   Attrition        100 non-null    object
# dtypes: object(8)
# memory usage: 6.4+ KB

# %%
Employee.describe()
# Out:
#        Gender Satisfaction Business Travel Department EducationField Salary  \
# count     100          100             100        100            100    100
# unique      2            3               3          2              5      3
# top      Male         High            Rare        R&D    Engineering   High
# freq       65           47              76         71             44     42
#
#        Home-Office Attrition
# count          100       100
# unique           2         2
# top           Near        No
# freq            67        82

# %%
Employee.sample(41)
# Out:
#     Gender Satisfaction Business Travel Department    EducationField  Salary  \
# 88    Male       Medium            Rare        R&D       Engineering  Medium
# 10    Male          Low            Rare        R&D           Medical  Medium
# 79    Male         High            Rare      Sales           Medical  Medium
# 75  Female         High            Rare        R&D       Engineering    High
# 4     Male       Medium            Rare        R&D           Medical  Medium
# 77    Male       Medium            Rare        R&D             Other     Low
# 71    Male         High            Rare        R&D       Engineering    High
# 8     Male         High        Frequent        R&D       Engineering    High
# 60    Male       Medium            Rare        R&D           Medical    High
# 83  Female         High              No        R&D           Medical    High
# 96  Female         High            Rare      Sales             Other     Low
# 81    Male         High            Rare        R&D           Medical     Low
# 91    Male         High            Rare      Sales         Marketing    High
# 89    Male       Medium            Rare      Sales           Medical     Low
# 61  Female          Low        Frequent        R&D       Engineering    High
# 23    Male         High            Rare        R&D       Engineering     Low
# 34    Male          Low            Rare        R&D           Medical  Medium
# 22  Female         High            Rare        R&D       Engineering  Medium
# 59    Male         High            Rare        R&D       Engineering     Low
# 50    Male         High            Rare        R&D       Engineering  Medium
# 28  Female       Medium            Rare        R&D           Medical  Medium
# 46    Male         High              No      Sales         Marketing     Low
# 86    Male          Low            Rare      Sales  Technical Degree  Medium
# 93    Male         High        Frequent        R&D           Medical    High
# 55  Female         High        Frequent        R&D       Engineering    High
# 65  Female         High            Rare        R&D           Medical    High
# 56    Male          Low        Frequent      Sales       Engineering    High
# 84    Male         High            Rare        R&D           Medical  Medium
# 52  Female          Low            Rare      Sales         Marketing  Medium
# 25  Female       Medium            Rare        R&D             Other    High
# 45  Female         High            Rare        R&D  Technical Degree  Medium
# 38  Female          Low            Rare        R&D       Engineering  Medium
# 32    Male         High            Rare        R&D           Medical    High
# 69    Male       Medium            Rare        R&D           Medical    High
# 6   Female         High            Rare        R&D           Medical    High
# 0   Female         High            Rare      Sales       Engineering  Medium
# 43    Male         High        Frequent      Sales       Engineering    High
# 57  Female       Medium            Rare        R&D           Medical     Low
# 5     Male         High        Frequent        R&D       Engineering     Low
# 7     Male         High            Rare        R&D       Engineering    High
# 33    Male         High            Rare      Sales  Technical Degree  Medium
#
#    Home-Office Attrition
# 88        Near        No
# 10        Near        No
# 79        Near        No
# 75         Far        No
# 4          Far        No
# 77         Far        No
# 71         Far        No
# 8         Near        No
# 60         Far        No
# 83        Near        No
# 96        Near       Yes
# 81        Near        No
# 91        Near        No
# 89        Near       Yes
# 61         Far        No
# 23         Far        No
# 34        Near       Yes
# 22        Near        No
# 59        Near        No
# 50        Near       Yes
# 28        Near        No
# 46        Near        No
# 86        Near        No
# 93        Near        No
# 55        Near        No
# 65         Far        No
# 56         Far        No
# 84        Near        No
# 52        Near        No
# 25         Far        No
# 45         Far       Yes
# 38        Near        No
# 32        Near        No
# 69         Far       Yes
# 6          Far        No
# 0         Near       Yes
# 43         Far        No
# 57        Near        No
# 5          Far        No
# 7         Near        No
# 33        Near       Yes

# %%
Employee.dtypes
# Out:
# Gender             object
# Satisfaction       object
# Business Travel    object
# Department         object
# EducationField     object
# Salary             object
# Home-Office        object
# Attrition          object
# dtype: object

# %%
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips)

# %%
sns.catplot(x="day", y="total_bill", jitter=False, data=tips)

# %%
sns.catplot(x="day", y="total_bill", kind="swarm", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips)

# %%
sns.catplot(x="size", y="total_bill", data=tips)

# %%
sns.catplot(x="smoker", y="tip", order=["No", "Yes"], data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", data=tips)
sns.catplot(x="day", y="total_bill", kind="box", data=tips)
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips)
tips["weekend"] = tips["day"].isin(["Sat", "Sun"])
sns.catplot(x="day", y="total_bill", hue="weekend",
            kind="box", dodge=False, data=tips)

# %%
diamonds = sns.load_dataset("diamonds")
sns.catplot(x="color", y="price", kind="boxen",
            data=diamonds.sort_values("color"))

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", data=tips)

# %%
sns.catplot(x="total_bill", y="day", hue="sex",
            kind="violin", bw=.15, cut=0,
            data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", split=True, data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            kind="violin", inner="stick", split=True,
            palette="pastel", data=tips)

# %%
g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips, ax=g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)

# %%
sns.catplot(x="deck", kind="count", palette="ch:.25", data=titanic)

# %%
sns.catplot(y="deck", hue="class", kind="count",
            palette="pastel", edgecolor=".6",
            data=titanic)

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="point", data=titanic)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            palette={"male": "g", "female": "m"},
            markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=titanic)

# %%
iris = sns.load_dataset("iris")
sns.catplot(data=iris, orient="h", kind="box")

# %%
sns.violinplot(x=iris.species, y=iris.sepal_length)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="deck", data=titanic, color="c")
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %%
sns.catplot(x="day", y="total_bill", hue="smoker",
            col="time", aspect=.7,
            kind="swarm", data=tips)

# %%
g = sns.catplot(x="fare", y="survived", row="class",
                kind="box", orient="h", height=1.5, aspect=4,
                data=titanic.query("fare > 0"))
g.set(xscale="log")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", ci=None, kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", kind="line", ci="sd", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", estimator=None, kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
            dashes=False, markers=True, kind="line", data=fmri);
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            kind="line", data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="region",
            units="subject", estimator=None,
            kind="line", data=fmri.query("event == 'stim'"));
dots = sns.load_dataset("dots").query("align == 'dots'")
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            kind="line", data=dots);
palette = sns.cubehelix_palette(light=.8, n_colors=6)
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            palette=palette,
            kind="line", data=dots);
from matplotlib.colors import LogNorm
palette = sns.cubehelix_palette(light=.7, n_colors=6)
sns.relplot(x="time", y="firing_rate",
            hue="coherence", style="choice",
            hue_norm=LogNorm(),
            kind="line",
            data=dots.query("coherence > 0"));

# %%
sns.relplot(x="time", y="firing_rate",
            size="coherence", style="choice",
            kind="line", data=dots);

# %%
sns.relplot(x="time", y="firing_rate",
           hue="coherence", size="choice",
           palette=palette,
           kind="line", data=dots);

# %%
df = pd.DataFrame(dict(time=pd.date_range("2017-1-1", periods=500),
                       value=np.random.randn(500).cumsum()))
g = sns.relplot(x="time", y="value", kind="line", data=df)
g.figure.autofmt_xdate()

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="time", data=tips);

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=fmri);

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind="line", data=fmri.query("region == 'frontal'"));
