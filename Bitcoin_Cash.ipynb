# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock-/blob/master/Bitcoin_Cash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
BitcoinCash = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/Bitcoin%20Cash%20.csv")

BitcoinCash
# Out:
#                                Category: All categories
# Region                Bitcoin Cash: (8/14/19 - 8/14/20)
# Colorado                                            100
# Massachusetts                                        91
# Nevada                                               82
# Florida                                              82
# California                                           70
# Hawaii                                               64
# Washington                                           61
# New Jersey                                           61
# New York                                             60
# Arizona                                              59
# Georgia                                              56
# New Hampshire                                        53
# Missouri                                             53
# Arkansas                                             52
# Illinois                                             52
# ...

# %%
BitcoinCash.head()
# Out:
#                         Category: All categories
# Region         Bitcoin Cash: (8/14/19 - 8/14/20)
# Colorado                                     100
# Massachusetts                                 91
# Nevada                                        82
# Florida                                       82

# %%
BitcoinCash.tail()
# Out:
#              Category: All categories
# Alaska                            NaN
# Wyoming                           NaN
# Vermont                           NaN
# North Dakota                      NaN
# South Dakota                      NaN

# %%
BitcoinCash.describe()
# Out:
#        Category: All categories
# count                        47
# unique                       31
# top                          43
# freq                          4

# %%
import sqlite3

# %%
conn = sqlite3.connect("BitcoinCash.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("BitcoinCash.db")
c = conn.cursor()

# %%
BitcoinCash.to_sql("BitcoinCash", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM BitcoinCash""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'Bitcoin Cash: (8/14/19 - 8/14/20)'),
#  ('Colorado', '100'),
#  ('Massachusetts', '91'),
#  ('Nevada', '82'),
#  ('Florida', '82'),
#  ('California', '70'),
#  ('Hawaii', '64'),
#  ('Washington', '61'),
#  ('New Jersey', '61'),
#  ('New York', '60'),
#  ('Arizona', '59'),
#  ('Georgia', '56'),
#  ('New Hampshire', '53'),
#  ('Missouri', '53'),
#  ('Arkansas', '52'),
#  ('Illinois', '52'),
#  ('District of Columbia', '51'),
#  ('Connecticut', '49'),
#  ('Oregon', '48'),
#  ('North Carolina', '48'),
#  ('Virginia', '47'),
#  ('Texas', '47'),
#  ('Kentucky', '46'),
#  ('South Carolina', '46'),
#  ('Rhode Island', '45'),
#  ('Minnesota', '45'),
#  ('Ohio', '44'),
#  ('Delaware', '43'),
#  ('Michigan', '43'),
#  ('Utah', '43'),
#  ('Indiana', '43'),
#  ('Maryland', '42'),
#  ('Tennessee', '41'),
#  ('Pennsylvania', '41'),
#  ('Nebraska', '39'),
#  ('Kansas', '39'),
#  ('Louisiana', '39'),
#  ('Montana', '38'),
#  ('West Virginia', '37'),
#  ('Alabama', '35'),
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Bitcoin Cash', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Bitcoin')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
BitcoinCash.to_excel("BitcoinCash.xls")

pd.read_excel("BitcoinCash.xls")
# Out:
#               Unnamed: 0           Category: All categories
# 0                 Region  Bitcoin Cash: (8/14/19 - 8/14/20)
# 1               Colorado                                100
# 2          Massachusetts                                 91
# 3                 Nevada                                 82
# 4                Florida                                 82
# 5             California                                 70
# 6                 Hawaii                                 64
# 7             Washington                                 61
# 8             New Jersey                                 61
# 9               New York                                 60
# 10               Arizona                                 59
# 11               Georgia                                 56
# 12         New Hampshire                                 53
# 13              Missouri                                 53
# 14              Arkansas                                 52
# ...
