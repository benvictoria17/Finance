# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Employee%20Resignation/Train.csv")
train.head(10)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
# 5    EID_2278      M  54.0                3             Married      Lebanon
# 6   EID_18588      F  21.0                4             Married  Springfield
# 7    EID_1235      F   NaN                3             Married  Springfield
# 8   EID_10197      M  40.0                4              Single  Springfield
# 9   EID_21262      M  45.0                3             Married      Lebanon
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
# 5                 Purchasing             Conceptual             19.0
# 6                 Purchasing              Directive              2.0
# 7                      Sales              Directive             34.0
# 8                 Production             Analytical             13.0
# 9                         IT              Directive             21.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                     4  ...                      type2                3.0
# 1                     4  ...                      type2                4.0
# 2                     3  ...                      type2                1.0
# 3                     3  ...                      type2                1.0
# 4                     4  ...                      type3                3.0
# 5                     1  ...                      type2                1.0
# 6                     1  ...                      type2                2.0
# 7                     4  ...                      type3                2.0
# 8                     1  ...                      type0                4.0
# 9                     4  ...                      type3                4.0
#
#    VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0     4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1     3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2     4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 3     3 -1.8176 -0.4537   NaN     3     7     3          0.0668
# 4     1  0.7516 -0.4537   2.0     2     8     2          0.1827
# 5     3 -1.8176  1.8688   2.0     2     8     3          0.7613
# 6     3 -0.9612  0.7075   2.0     3     7     3          0.2819
# 7     3 -0.1048 -0.4537   2.0     3     9     3          0.1169
# 8     1     NaN  1.8688   2.0     5     6     3          0.1968
# 9     3  0.7516 -0.4537   2.0     4     8     3          0.2870
#
# [10 rows x 24 columns]

# %%
test = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Employee%20Resignation/Test.csv")

# %%
test.head(10)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
# 5   EID_20283      F  22.0                4             Married     Franklin
# 6   EID_21014      M  42.0                3             Married   Washington
# 7    EID_7693      F  41.0                2             Married  Springfield
# 8   EID_13232      M  31.0                1              Single  Springfield
# 9    EID_6515      M  48.0                2              Single  Springfield
#
#          Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0         R&D             Conceptual              7.0                     4
# 1          IT              Directive             41.0                     2
# 2       Sales              Directive             21.0                     3
# 3   Marketing             Analytical             11.0                     4
# 4         R&D             Conceptual             12.0                     4
# 5          IT             Behavioral              3.0                     1
# 6  Purchasing             Analytical              6.0                     4
# 7       Sales             Conceptual              4.0                     4
# 8          IT             Analytical              7.0                     3
# 9         R&D             Conceptual             16.0                     1
#
#    ...  Pay_Scale  Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2  \
# 0  ...        4.0                      type2                1.0     3 -0.9612
# 1  ...        1.0                      type2                1.0     4 -0.9612
# 2  ...        8.0                      type3                1.0     4 -0.1048
# 3  ...        2.0                      type0                4.0     3 -0.1048
# 4  ...        2.0                      type2                4.0     4  1.6081
# 5  ...        6.0                      type2                1.0     3     NaN
# 6  ...        4.0                      type2                1.0     3  0.7516
# 7  ...        8.0                      type2                1.0     3 -0.1048
# 8  ...        8.0                      type2                3.0     3  1.6081
# 9  ...        4.0                      type0                3.0     3 -0.1048
#
#      VAR3  VAR4  VAR5  VAR6  VAR7
# 0 -0.4537   2.0     1     8     4
# 1  0.7075   1.0     2     8     2
# 2  0.7075   2.0     1     9     3
# 3  0.7075   2.0     2     8     3
# 4  0.7075   2.0     2     7     4
# 5 -0.4537   2.0     3     8     3
# 6  1.8688   2.0     3     7     3
# 7  1.8688   2.0     2     7     5
# 8  0.7075   2.0     2     7     4
# 9 -0.4537   2.0     4     7     4
#
# [10 rows x 23 columns]

# %%
train.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
train.count()
# Out:
# Employee_ID                  7000
# Gender                       7000
# Age                          6588
# Education_Level              7000
# Relationship_Status          7000
# Hometown                     7000
# Unit                         7000
# Decision_skill_possess       7000
# Time_of_service              6856
# Time_since_promotion         7000
# growth_rate                  7000
# Travel_Rate                  7000
# Post_Level                   7000
# Pay_Scale                    6991
# Compensation_and_Benefits    7000
# Work_Life_balance            6989
# VAR1                         7000
# VAR2                         6423
# VAR3                         7000
# VAR4                         6344
# VAR5                         7000
# VAR6                         7000
# VAR7                         7000
# Attrition_rate               7000
# dtype: int64

# %%
train.describe()
# Out:
#                Age  Education_Level  Time_of_service  Time_since_promotion  \
# count  6588.000000      7000.000000      6856.000000           7000.000000
# mean     39.622799         3.187857        13.385064              2.367143
# std      13.606920         1.065102        10.364188              1.149395
# min      19.000000         1.000000         0.000000              0.000000
# 25%      27.000000         3.000000         5.000000              1.000000
# 50%      37.000000         3.000000        10.000000              2.000000
# 75%      52.000000         4.000000        21.000000              3.000000
# max      65.000000         5.000000        43.000000              4.000000
#
#        growth_rate  Travel_Rate   Post_Level    Pay_Scale  Work_Life_balance  \
# count  7000.000000  7000.000000  7000.000000  6991.000000        6989.000000
# mean     47.064286     0.817857     2.798000     6.006294           2.387895
# std      15.761406     0.648205     1.163721     2.058435           1.122786
# min      20.000000     0.000000     1.000000     1.000000           1.000000
# 25%      33.000000     0.000000     2.000000     5.000000           1.000000
# 50%      47.000000     1.000000     3.000000     6.000000           2.000000
# 75%      61.000000     1.000000     3.000000     8.000000           3.000000
# max      74.000000     2.000000     5.000000    10.000000           5.000000
#
#               VAR1         VAR2         VAR3         VAR4         VAR5  \
# count  7000.000000  6423.000000  7000.000000  6344.000000  7000.000000
# mean      3.098571    -0.008126    -0.013606     1.891078     2.834143
# std       0.836377     0.989850     0.986933     0.529403     0.938945
# min       1.000000    -1.817600    -2.776200     1.000000     1.000000
# 25%       3.000000    -0.961200    -0.453700     2.000000     2.000000
# 50%       3.000000    -0.104800    -0.453700     2.000000     3.000000
# 75%       3.000000     0.751600     0.707500     2.000000     3.000000
# max       5.000000     1.608100     1.868800     3.000000     5.000000
#
#               VAR6         VAR7  Attrition_rate
# count  7000.000000  7000.000000     7000.000000
# mean      7.101286     3.257000        0.189376
# std       1.164262     0.925319        0.185753
# min       5.000000     1.000000        0.000000
# 25%       6.000000     3.000000        0.070400
# 50%       7.000000     3.000000        0.142650
# 75%       8.000000     4.000000        0.235000
# max       9.000000     5.000000        0.995900

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   object
#  1   Gender                     7000 non-null   object
#  2   Age                        6588 non-null   float64
#  3   Education_Level            7000 non-null   int64
#  4   Relationship_Status        7000 non-null   object
#  5   Hometown                   7000 non-null   object
#  6   Unit                       7000 non-null   object
#  7   Decision_skill_possess     7000 non-null   object
#  8   Time_of_service            6856 non-null   float64
#  9   Time_since_promotion       7000 non-null   int64
#  10  growth_rate                7000 non-null   int64
#  11  Travel_Rate                7000 non-null   int64
#  12  Post_Level                 7000 non-null   int64
#  13  Pay_Scale                  6991 non-null   float64
#  14  Compensation_and_Benefits  7000 non-null   object
#  15  Work_Life_balance          6989 non-null   float64
#  16  VAR1                       7000 non-null   int64
#  17  VAR2                       6423 non-null   float64
#  18  VAR3                       7000 non-null   float64
#  19  VAR4                       6344 non-null   float64
#  20  VAR5                       7000 non-null   int64
#  21  VAR6                       7000 non-null   int64
#  22  VAR7                       7000 non-null   int64
#  23  Attrition_rate             7000 non-null   float64
# dtypes: float64(8), int64(9), object(7)
# memory usage: 1.3+ MB

# %%
train.head(5)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                     4  ...                      type2                3.0
# 1                     4  ...                      type2                4.0
# 2                     3  ...                      type2                1.0
# 3                     3  ...                      type2                1.0
# 4                     4  ...                      type3                3.0
#
#    VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0     4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1     3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2     4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 3     3 -1.8176 -0.4537   NaN     3     7     3          0.0668
# 4     1  0.7516 -0.4537   2.0     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

def bar_plot(variable):
    
    """
        input: variable ex:"Sex"
        output: bar plot & value count
    """
    #get future
    var= train[variable]
    #count number of categorical variable(value/sample)
    varValue=var.value_counts()
    
    #visualize
    
    plt.figure(figsize=(10,4))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    
    print("{}: \n {}".format(variable,varValue))
    
category1= ["Gender","Age","Education_Level","Relationship_Status","Hometown","Unit","Decision_skill_possess","Time_of_service"]

for c in category1:
    bar_plot(c)
# Out:
# Gender:
#  F    4114
# M    2886
# Name: Gender, dtype: int64
# Age:
#  22.0    235
# 25.0    235
# 27.0    231
# 31.0    218
# 54.0    212
# 60.0    211
# 26.0    210
# 37.0    208
# 35.0    205
# 52.0    199
# 28.0    194
# 42.0    193
# 47.0    193
# 30.0    191
# 32.0    189
# 24.0    185
# 45.0    184
# 21.0    171
# 65.0    152
# 19.0    151
# 23.0    148
# 59.0    136
# 58.0    122
# 20.0    122
# 29.0    115
# 36.0    106
# 33.0    104
# 51.0    103
# 50.0    101
# 34.0     99
# 46.0     98
# 49.0     97
# 64.0     95
# 55.0     94
# 56.0     94
# 43.0     93
# 41.0     92
# 57.0     92
# 38.0     89
# 53.0     88
# 44.0     85
# 39.0     83
# 40.0     81
# 48.0     79
# 63.0     73
# 62.0     69
# 61.0     63
# Name: Age, dtype: int64
# Education_Level:
#  3    2878
# 4    2076
# 1     695
# 2     691
# 5     660
# Name: Education_Level, dtype: int64
# Relationship_Status:
#  Married    4520
# Single     2480
# Name: Relationship_Status, dtype: int64
# Hometown:
#  Lebanon        2070
# Springfield    1736
# Franklin       1523
# Washington     1106
# Clinton         565
# Name: Hometown, dtype: int64
# Unit:
#  IT                           1394
# Logistics                    1173
# Sales                         943
# Operarions                    706
# R&D                           680
# Purchasing                    504
# Accounting and Finance        496
# Human Resource Management     344
# Marketing                     212
# Production                    211
# Quality                       193
# Security                      144
# Name: Unit, dtype: int64
# Decision_skill_possess:
#  Conceptual    1756
# Analytical    1755
# Directive     1753
# Behavioral    1736
# Name: Decision_skill_possess, dtype: int64
# Time_of_service:
#  6.0     545
# 5.0     503
# 3.0     471
# 4.0     439
# 2.0     297
# 8.0     276
# 7.0     258
# 10.0    218
# 9.0     205
# 13.0    195
# 12.0    191
# 11.0    178
# 15.0    178
# 14.0    175
# 0.0     162
# 18.0    154
# 16.0    150
# 22.0    146
# 20.0    142
# 21.0    137
# 24.0    129
# 1.0     127
# 17.0    124
# 19.0    122
# 23.0    118
# 25.0    117
# 27.0    114
# 28.0    113
# 26.0    109
# 30.0     98
# 31.0     86
# 29.0     82
# 33.0     71
# 32.0     65
# 35.0     60
# 34.0     55
# 36.0     51
# 37.0     51
# 38.0     48
# 39.0     29
# 40.0     24
# 41.0     18
# 42.0     17
# 43.0      8
# Name: Time_of_service, dtype: int64

# %%
def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(train[variable],bins=50)
    
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()
numericVar =["Age"]

for n in numericVar:
    plot_hist(n)

# %%
print(train["Age"])
# Out:
# 0       42.0
# 1       24.0
# 2       58.0
# 3       26.0
# 4       31.0
#         ...
# 6995    23.0
# 6996    44.0
# 6997    49.0
# 6998    47.0
# 6999    58.0
# Name: Age, Length: 7000, dtype: float64

# %%
train.head(5)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                     4  ...                      type2                3.0
# 1                     4  ...                      type2                4.0
# 2                     3  ...                      type2                1.0
# 3                     3  ...                      type2                1.0
# 4                     4  ...                      type3                3.0
#
#    VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0     4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1     3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2     4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 3     3 -1.8176 -0.4537   NaN     3     7     3          0.0668
# 4     1  0.7516 -0.4537   2.0     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
train["Age"].unique()
# Out:
# array([42., 24., 58., 26., 31., 54., 21., nan, 40., 45., 65., 19., 63.,
#        23., 33., 32., 22., 25., 47., 28., 34., 55., 46., 30., 43., 39.,
#        27., 57., 51., 41., 37., 60., 50., 56., 44., 49., 36., 29., 20.,
#        59., 53., 35., 62., 61., 64., 38., 52., 48.])

# %%
train["Relationship_Status"].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
train["Unit"].unique()
# Out:
# array(['IT', 'Logistics', 'Quality', 'Human Resource Management',
#        'Purchasing', 'Sales', 'Production', 'Operarions',
#        'Accounting and Finance', 'Marketing', 'R&D', 'Security'],
#       dtype=object)

# %%
train["Decision_skill_possess"].unique()
# Out:
# array(['Conceptual', 'Analytical', 'Behavioral', 'Directive'],
#       dtype=object)

# %%
train["Compensation_and_Benefits"].unique()
# Out:
# array(['type2', 'type3', 'type0', 'type4', 'type1'], dtype=object)

# %%
train.head(2)
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0         IT             Conceptual              4.0                     4
# 1  Logistics             Analytical              5.0                     4
#
#    ...  Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  \
# 0  ...                      type2                3.0     4  0.7516  1.8688
# 1  ...                      type2                4.0     3 -0.9612 -0.4537
#
#    VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0   2.0     4     5     3          0.1841
# 1   2.0     3     5     3          0.0670
#
# [2 rows x 24 columns]

# %%
train[["Hometown","Attrition_rate"]].groupby(["Hometown"], as_index=False).mean().sort_values(by="Attrition_rate",ascending=False)
# Out:
#       Hometown  Attrition_rate
# 3  Springfield        0.194084
# 4   Washington        0.188895
# 0      Clinton        0.188464
# 1     Franklin        0.187901
# 2      Lebanon        0.187019

# %%
train[["Time_since_promotion","Attrition_rate"]].groupby(["Time_since_promotion"], as_index=False).mean().sort_values(by="Attrition_rate",ascending=False)
# Out:
#    Time_since_promotion  Attrition_rate
# 4                     4        0.195506
# 2                     2        0.192896
# 0                     0        0.188687
# 3                     3        0.185435
# 1                     1        0.184551

# %%
from collections import Counter 
def detect_outliers(df,features):
    outlier_indices=[]
    
    for c in features:
        Q1=np.percentile(df[c],25)
        
        Q3=np.percentile(df[c],75)
        
        IQR= Q3-Q1
        
        outlier_step= IQR * 1.5
        
        outlier_list_col = df[(df[c]< Q1 - outlier_step)|( df[c] > Q3 + outlier_step)].index
        
        outlier_indices.extend(outlier_list_col)
    
    outliers_indices = Counter(outlier_indices)
    
    multiple_outliers = list(i for i , v in outliers_indices.items() if v>2 )
    
    return multiple_outliers
train.loc[detect_outliers(train,["Age","VAR1","VAR2","VAR3","Pay_Scale"])]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Gender, Age, Education_Level, Relationship_Status, Hometown, Unit, Decision_skill_possess, Time_of_service, Time_since_promotion, growth_rate, Travel_Rate, Post_Level, Pay_Scale, Compensation_and_Benefits, Work_Life_balance, VAR1, VAR2, VAR3, VAR4, VAR5, VAR6, VAR7, Attrition_rate]
# Index: []
#
# [0 rows x 24 columns]

# %%
train.columns
# Out:
# Index(['Employee_ID', 'Gender', 'Age', 'Education_Level',
#        'Relationship_Status', 'Hometown', 'Unit', 'Decision_skill_possess',
#        'Time_of_service', 'Time_since_promotion', 'growth_rate', 'Travel_Rate',
#        'Post_Level', 'Pay_Scale', 'Compensation_and_Benefits',
#        'Work_Life_balance', 'VAR1', 'VAR2', 'VAR3', 'VAR4', 'VAR5', 'VAR6',
#        'VAR7', 'Attrition_rate'],
#       dtype='object')

# %%
train.columns[train.isnull().any()]
# Out:
# Index(['Age', 'Time_of_service', 'Pay_Scale', 'Work_Life_balance', 'VAR2',
#        'VAR4'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          412
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              144
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
train.boxplot(column="VAR1",by="Gender")
plt.show()

train.boxplot(column="VAR2",by="Gender")
plt.show()

train.boxplot(column="VAR3",by="Gender")
plt.show()

train.boxplot(column="VAR4",by="Gender")
plt.show()

train.boxplot(column="VAR5",by="Gender")
plt.show()

train.boxplot(column="VAR6",by="Gender")
plt.show()

train.boxplot(column="VAR7",by="Gender")
plt.show()

train.boxplot(column="Attrition_rate",by="Gender")
plt.show()
import seaborn as sns

# %%
train[train["Age"].isnull()]
# Out:
#      Employee_ID Gender  Age  Education_Level Relationship_Status  \
# 7       EID_1235      F  NaN                3             Married
# 15     EID_20121      F  NaN                3             Married
# 25      EID_3901      F  NaN                2             Married
# 40     EID_17527      F  NaN                2             Married
# 43      EID_1433      M  NaN                3             Married
# ...          ...    ...  ...              ...                 ...
# 6916   EID_16330      F  NaN                4              Single
# 6945   EID_20301      F  NaN                3              Single
# 6969   EID_18566      F  NaN                1              Single
# 6981   EID_25181      M  NaN                3             Married
# 6986   EID_17099      M  NaN                4              Single
#
#          Hometown                       Unit Decision_skill_possess  \
# 7     Springfield                      Sales              Directive
# 15    Springfield                  Logistics             Analytical
# 25     Washington                  Marketing              Directive
# 40    Springfield                         IT             Conceptual
# 43    Springfield                  Logistics             Conceptual
# ...           ...                        ...                    ...
# 6916     Franklin                 Purchasing              Directive
# 6945  Springfield                 Operarions             Conceptual
# 6969   Washington                        R&D             Conceptual
# 6981  Springfield                  Logistics             Behavioral
# 6986     Franklin  Human Resource Management              Directive
#
#       Time_of_service  Time_since_promotion  ...  Compensation_and_Benefits  \
# 7                34.0                     4  ...                      type3
# 15                0.0                     0  ...                      type2
# 25               15.0                     1  ...                      type2
# 40                4.0                     1  ...                      type3
# 43               19.0                     3  ...                      type2
# ...               ...                   ...  ...                        ...
# 6916              2.0                     2  ...                      type4
# 6945             17.0                     1  ...                      type2
# 6969              4.0                     2  ...                      type3
# 6981             17.0                     3  ...                      type2
# 6986              3.0                     1  ...                      type2
#
#       Work_Life_balance  VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  \
# 7                   2.0     3 -0.1048 -0.4537   2.0     3     9     3
# 15                  2.0     3  0.7516 -1.6150   1.0     3     8     3
# 25                  1.0     3 -0.1048 -0.4537   1.0     4     8     2
# 40                  2.0     3 -1.8176  0.7075   2.0     5     6     2
# 43                  2.0     5  0.7516  1.8688   2.0     3     8     3
# ...                 ...   ...     ...     ...   ...   ...   ...   ...
# 6916                3.0     5  0.7516 -0.4537   2.0     3     8     2
# 6945                2.0     4 -1.8176 -0.4537   2.0     4     8     3
# 6969                4.0     3  0.7516 -1.6150   3.0     4     6     3
# 6981                1.0     4  1.6081 -1.6150   NaN     5     8     5
# 6986                2.0     3  0.7516  0.7075   1.0     3     5     4
#
#       Attrition_rate
# 7             0.1169
# 15            0.1331
# 25            0.8727
# 40            0.0618
# 43            0.1571
# ...              ...
# 6916          0.2779
# 6945          0.1296
# 6969          0.0986
# 6981          0.1954
# 6986          0.1041
#
# [412 rows x 24 columns]

# %%
train[train["Age"].isnull()]
# Out:
#      Employee_ID Gender  Age  Education_Level Relationship_Status  \
# 7       EID_1235      F  NaN                3             Married
# 15     EID_20121      F  NaN                3             Married
# 25      EID_3901      F  NaN                2             Married
# 40     EID_17527      F  NaN                2             Married
# 43      EID_1433      M  NaN                3             Married
# ...          ...    ...  ...              ...                 ...
# 6916   EID_16330      F  NaN                4              Single
# 6945   EID_20301      F  NaN                3              Single
# 6969   EID_18566      F  NaN                1              Single
# 6981   EID_25181      M  NaN                3             Married
# 6986   EID_17099      M  NaN                4              Single
#
#          Hometown                       Unit Decision_skill_possess  \
# 7     Springfield                      Sales              Directive
# 15    Springfield                  Logistics             Analytical
# 25     Washington                  Marketing              Directive
# 40    Springfield                         IT             Conceptual
# 43    Springfield                  Logistics             Conceptual
# ...           ...                        ...                    ...
# 6916     Franklin                 Purchasing              Directive
# 6945  Springfield                 Operarions             Conceptual
# 6969   Washington                        R&D             Conceptual
# 6981  Springfield                  Logistics             Behavioral
# 6986     Franklin  Human Resource Management              Directive
#
#       Time_of_service  Time_since_promotion  ...  Compensation_and_Benefits  \
# 7                34.0                     4  ...                      type3
# 15                0.0                     0  ...                      type2
# 25               15.0                     1  ...                      type2
# 40                4.0                     1  ...                      type3
# 43               19.0                     3  ...                      type2
# ...               ...                   ...  ...                        ...
# 6916              2.0                     2  ...                      type4
# 6945             17.0                     1  ...                      type2
# 6969              4.0                     2  ...                      type3
# 6981             17.0                     3  ...                      type2
# 6986              3.0                     1  ...                      type2
#
#       Work_Life_balance  VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  \
# 7                   2.0     3 -0.1048 -0.4537   2.0     3     9     3
# 15                  2.0     3  0.7516 -1.6150   1.0     3     8     3
# 25                  1.0     3 -0.1048 -0.4537   1.0     4     8     2
# 40                  2.0     3 -1.8176  0.7075   2.0     5     6     2
# 43                  2.0     5  0.7516  1.8688   2.0     3     8     3
# ...                 ...   ...     ...     ...   ...   ...   ...   ...
# 6916                3.0     5  0.7516 -0.4537   2.0     3     8     2
# 6945                2.0     4 -1.8176 -0.4537   2.0     4     8     3
# 6969                4.0     3  0.7516 -1.6150   3.0     4     6     3
# 6981                1.0     4  1.6081 -1.6150   NaN     5     8     5
# 6986                2.0     3  0.7516  0.7075   1.0     3     5     4
#
#       Attrition_rate
# 7             0.1169
# 15            0.1331
# 25            0.8727
# 40            0.0618
# 43            0.1571
# ...              ...
# 6916          0.2779
# 6945          0.1296
# 6969          0.0986
# 6981          0.1954
# 6986          0.1041
#
# [412 rows x 24 columns]

# %%
train["Age"]=train["Age"].fillna(train['Age'].median())
train['Age'].unique()
# Out:
# array([42., 24., 58., 26., 31., 54., 21., 37., 40., 45., 65., 19., 63.,
#        23., 33., 32., 22., 25., 47., 28., 34., 55., 46., 30., 43., 39.,
#        27., 57., 51., 41., 60., 50., 56., 44., 49., 36., 29., 20., 59.,
#        53., 35., 62., 61., 64., 38., 52., 48.])

# %%
train[train["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Gender, Age, Education_Level, Relationship_Status, Hometown, Unit, Decision_skill_possess, Time_of_service, Time_since_promotion, growth_rate, Travel_Rate, Post_Level, Pay_Scale, Compensation_and_Benefits, Work_Life_balance, VAR1, VAR2, VAR3, VAR4, VAR5, VAR6, VAR7, Attrition_rate]
# Index: []
#
# [0 rows x 24 columns]

# %%
train[train["Time_of_service"].isnull()]
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 27     EID_12981      M  28.0                3              Single
# 57     EID_15391      M  24.0                4             Married
# 96     EID_23317      M  22.0                5             Married
# 104    EID_14719      F  25.0                1             Married
# 197     EID_8070      M  40.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 6767    EID_4979      F  56.0                5             Married
# 6809    EID_4479      M  52.0                5             Married
# 6843   EID_13050      M  28.0                3             Married
# 6935    EID_9616      F  46.0                4              Single
# 6976   EID_15099      M  28.0                4             Married
#
#          Hometown        Unit Decision_skill_possess  Time_of_service  \
# 27        Lebanon       Sales             Conceptual              NaN
# 57    Springfield     Quality             Behavioral              NaN
# 96       Franklin  Production             Conceptual              NaN
# 104       Lebanon     Quality              Directive              NaN
# 197   Springfield   Logistics              Directive              NaN
# ...           ...         ...                    ...              ...
# 6767  Springfield       Sales             Conceptual              NaN
# 6809      Lebanon         R&D             Conceptual              NaN
# 6843      Lebanon          IT              Directive              NaN
# 6935   Washington  Operarions             Behavioral              NaN
# 6976     Franklin  Operarions             Conceptual              NaN
#
#       Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 27                       1  ...                      type2                1.0
# 57                       4  ...                      type2                2.0
# 96                       1  ...                      type3                1.0
# 104                      4  ...                      type3                2.0
# 197                      1  ...                      type2                1.0
# ...                    ...  ...                        ...                ...
# 6767                     3  ...                      type3                3.0
# 6809                     2  ...                      type2                1.0
# 6843                     2  ...                      type2                4.0
# 6935                     3  ...                      type2                1.0
# 6976                     3  ...                      type3                4.0
#
#       VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 27       3  0.7516  0.7075   2.0     3     8     3          0.6272
# 57       4 -1.8176 -0.4537   2.0     3     8     5          0.2197
# 96       1  1.6081 -0.4537   NaN     2     5     5          0.0350
# 104      3  0.7516 -0.4537   2.0     2     8     5          0.2396
# 197      3 -0.9612 -0.4537   2.0     5     7     3          0.0543
# ...    ...     ...     ...   ...   ...   ...   ...             ...
# 6767     3  0.7516 -0.4537   2.0     1     6     2          0.0863
# 6809     3  0.7516 -0.4537   2.0     3     8     4          0.2110
# 6843     2  0.7516  0.7075   2.0     4     7     3          0.1575
# 6935     3  0.7516  0.7075   2.0     3     9     3          0.0335
# 6976     3     NaN -0.4537   2.0     2     7     3          0.2237
#
# [144 rows x 24 columns]

# %%
train["Time_of_service"]=train["Time_of_service"].fillna(train['Time_of_service'].median())
train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                            0
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service                0
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance             11
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
train[train["Work_Life_balance"].isnull()]
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 728    EID_12062      M  35.0                3              Single
# 902    EID_11146      F  37.0                1             Married
# 1252   EID_20549      M  42.0                3              Single
# 1378   EID_19310      F  21.0                4              Single
# 1634    EID_6814      F  43.0                5              Single
# 2101   EID_25336      M  52.0                4              Single
# 2971    EID_4230      F  64.0                2             Married
# 3954   EID_23012      F  37.0                4              Single
# 4532   EID_19982      F  30.0                4              Single
# 4735   EID_12687      F  29.0                1             Married
# 5010    EID_6341      F  48.0                1             Married
#
#          Hometown                    Unit Decision_skill_possess  \
# 728    Washington               Logistics             Behavioral
# 902       Lebanon                      IT             Analytical
# 1252  Springfield              Purchasing              Directive
# 1378     Franklin                   Sales              Directive
# 1634  Springfield              Purchasing             Conceptual
# 2101     Franklin               Logistics             Behavioral
# 2971  Springfield                      IT             Behavioral
# 3954  Springfield              Purchasing             Conceptual
# 4532      Lebanon              Production             Behavioral
# 4735   Washington              Purchasing             Behavioral
# 5010      Lebanon  Accounting and Finance             Behavioral
#
#       Time_of_service  Time_since_promotion  ...  Compensation_and_Benefits  \
# 728              10.0                     3  ...                      type2
# 902              10.0                     1  ...                      type3
# 1252             12.0                     2  ...                      type3
# 1378              2.0                     2  ...                      type2
# 1634             14.0                     2  ...                      type2
# 2101             25.0                     1  ...                      type2
# 2971             40.0                     4  ...                      type2
# 3954             10.0                     2  ...                      type3
# 4532              8.0                     4  ...                      type2
# 4735              6.0                     4  ...                      type0
# 5010             25.0                     2  ...                      type0
#
#       Work_Life_balance  VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  \
# 728                 NaN     3  0.7516  0.7075   2.0     2     9     4
# 902                 NaN     3  1.6081  0.7075   1.0     2     8     3
# 1252                NaN     3  0.7516  0.7075   NaN     2     6     3
# 1378                NaN     2     NaN -0.4537   2.0     3     7     4
# 1634                NaN     3     NaN  0.7075   2.0     4     6     5
# 2101                NaN     3  0.7516 -0.4537   2.0     4     7     5
# 2971                NaN     3  1.6081  0.7075   2.0     4     7     5
# 3954                NaN     3  1.6081 -0.4537   3.0     3     6     3
# 4532                NaN     4 -1.8176 -1.6150   2.0     4     6     3
# 4735                NaN     3 -0.9612  0.7075   3.0     4     8     3
# 5010                NaN     3  0.7516 -0.4537   2.0     4     8     5
#
#       Attrition_rate
# 728           0.0856
# 902           0.1206
# 1252          0.0476
# 1378          0.0617
# 1634          0.0709
# 2101          0.2981
# 2971          0.1322
# 3954          0.1744
# 4532          0.5131
# 4735          0.1517
# 5010          0.1512
#
# [11 rows x 24 columns]

# %%
train["Work_Life_balance"]=train["Work_Life_balance"].fillna(train['Work_Life_balance'].median())
train.isnull().sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                            0
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service                0
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      9
# Compensation_and_Benefits      0
# Work_Life_balance              0
# VAR1                           0
# VAR2                         577
# VAR3                           0
# VAR4                         656
# VAR5                           0
# VAR6                           0
# VAR7                           0
# Attrition_rate                 0
# dtype: int64

# %%
train["VAR2"]=train["VAR2"].fillna(train['VAR2'].median())
train["VAR4"]=train["VAR4"].fillna(train['VAR4'].median())
train["Pay_Scale"]=train["Pay_Scale"].fillna(train['Pay_Scale'].median())
train.isnull().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# Attrition_rate               0
# dtype: int64

# %%
train["Pay_Scale"]=train["Pay_Scale"].fillna(train["Pay_Scale"].median())
train.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# 0                     4  ...                      type2                3.0
# 1                     4  ...                      type2                4.0
# 2                     3  ...                      type2                1.0
# 3                     3  ...                      type2                1.0
# 4                     4  ...                      type3                3.0
#
#    VAR1    VAR2    VAR3  VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0     4  0.7516  1.8688   2.0     4     5     3          0.1841
# 1     3 -0.9612 -0.4537   2.0     3     5     3          0.0670
# 2     4 -0.9612 -0.4537   3.0     3     8     3          0.0851
# 3     3 -1.8176 -0.4537   2.0     3     7     3          0.0668
# 4     1  0.7516 -0.4537   2.0     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
train["Gender"]=[1 if i =="M" else 0 for i in train["Gender"]]
train["Relationship_Status"].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
train["Relationship_Status"]=[1 if i =="Married" else 0 for i in train["Relationship_Status"]]
train['Hometown'].unique()
# Out:
# array(['Franklin', 'Springfield', 'Clinton', 'Lebanon', 'Washington'],
#       dtype=object)

# %%
from sklearn import preprocessing 
  
label_encoder = preprocessing.LabelEncoder() 
  
train['Hometown']= label_encoder.fit_transform(train['Hometown']) 
  
train['Hometown'].unique()
# Out:
# array([1, 3, 0, 2, 4])

# %%
train.head(2)
# Out:
#   Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0   EID_23371       0  42.0                4                    1         1
# 1   EID_18000       1  24.0                3                    0         3
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0         IT             Conceptual              4.0                     4
# 1  Logistics             Analytical              5.0                     4
#
#    ...  Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  \
# 0  ...                      type2                3.0     4  0.7516  1.8688
# 1  ...                      type2                4.0     3 -0.9612 -0.4537
#
#    VAR4  VAR5  VAR6  VAR7  Attrition_rate
# 0   2.0     4     5     3          0.1841
# 1   2.0     3     5     3          0.0670
#
# [2 rows x 24 columns]

# %%
train['Unit']= label_encoder.fit_transform(train['Unit']) 
train['Decision_skill_possess']= label_encoder.fit_transform(train['Decision_skill_possess']) 
train['Compensation_and_Benefits']= label_encoder.fit_transform(train['Compensation_and_Benefits']) 
train.head(5)
# Out:
#   Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0   EID_23371       0  42.0                4                    1         1
# 1   EID_18000       1  24.0                3                    0         3
# 2    EID_3891       0  58.0                3                    1         0
# 3   EID_17492       0  26.0                3                    0         2
# 4   EID_22534       0  31.0                1                    1         3
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     2                       2              4.0                     4  ...
# 1     3                       0              5.0                     4  ...
# 2     8                       2             27.0                     3  ...
# 3     1                       1              4.0                     3  ...
# 4     3                       2              5.0                     4  ...
#
#    Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  VAR4  \
# 0                          2                3.0     4  0.7516  1.8688   2.0
# 1                          2                4.0     3 -0.9612 -0.4537   2.0
# 2                          2                1.0     4 -0.9612 -0.4537   3.0
# 3                          2                1.0     3 -1.8176 -0.4537   2.0
# 4                          3                3.0     1  0.7516 -0.4537   2.0
#
#    VAR5  VAR6  VAR7  Attrition_rate
# 0     4     5     3          0.1841
# 1     3     5     3          0.0670
# 2     3     8     3          0.0851
# 3     3     7     3          0.0668
# 4     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   object
#  1   Gender                     7000 non-null   int64
#  2   Age                        7000 non-null   float64
#  3   Education_Level            7000 non-null   int64
#  4   Relationship_Status        7000 non-null   int64
#  5   Hometown                   7000 non-null   int64
#  6   Unit                       7000 non-null   int64
#  7   Decision_skill_possess     7000 non-null   int64
#  8   Time_of_service            7000 non-null   float64
#  9   Time_since_promotion       7000 non-null   int64
#  10  growth_rate                7000 non-null   int64
#  11  Travel_Rate                7000 non-null   int64
#  12  Post_Level                 7000 non-null   int64
#  13  Pay_Scale                  7000 non-null   float64
#  14  Compensation_and_Benefits  7000 non-null   int64
#  15  Work_Life_balance          7000 non-null   float64
#  16  VAR1                       7000 non-null   int64
#  17  VAR2                       7000 non-null   float64
#  18  VAR3                       7000 non-null   float64
#  19  VAR4                       7000 non-null   float64
#  20  VAR5                       7000 non-null   int64
#  21  VAR6                       7000 non-null   int64
#  22  VAR7                       7000 non-null   int64
#  23  Attrition_rate             7000 non-null   float64
# dtypes: float64(8), int64(15), object(1)
# memory usage: 1.3+ MB

# %%
train.head(5)
# Out:
#   Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0   EID_23371       0  42.0                4                    1         1
# 1   EID_18000       1  24.0                3                    0         3
# 2    EID_3891       0  58.0                3                    1         0
# 3   EID_17492       0  26.0                3                    0         2
# 4   EID_22534       0  31.0                1                    1         3
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     2                       2              4.0                     4  ...
# 1     3                       0              5.0                     4  ...
# 2     8                       2             27.0                     3  ...
# 3     1                       1              4.0                     3  ...
# 4     3                       2              5.0                     4  ...
#
#    Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  VAR4  \
# 0                          2                3.0     4  0.7516  1.8688   2.0
# 1                          2                4.0     3 -0.9612 -0.4537   2.0
# 2                          2                1.0     4 -0.9612 -0.4537   3.0
# 3                          2                1.0     3 -1.8176 -0.4537   2.0
# 4                          3                3.0     1  0.7516 -0.4537   2.0
#
#    VAR5  VAR6  VAR7  Attrition_rate
# 0     4     5     3          0.1841
# 1     3     5     3          0.0670
# 2     3     8     3          0.0851
# 3     3     7     3          0.0668
# 4     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
id=[]
for i in list(train.Employee_ID):
    if not i.isdigit():
        id.append(i.replace("EID_","").strip().split(" ")[0])
train["Employee_ID"]=id
train.head(5)
# Out:
#   Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0       23371       0  42.0                4                    1         1
# 1       18000       1  24.0                3                    0         3
# 2        3891       0  58.0                3                    1         0
# 3       17492       0  26.0                3                    0         2
# 4       22534       0  31.0                1                    1         3
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     2                       2              4.0                     4  ...
# 1     3                       0              5.0                     4  ...
# 2     8                       2             27.0                     3  ...
# 3     1                       1              4.0                     3  ...
# 4     3                       2              5.0                     4  ...
#
#    Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  VAR4  \
# 0                          2                3.0     4  0.7516  1.8688   2.0
# 1                          2                4.0     3 -0.9612 -0.4537   2.0
# 2                          2                1.0     4 -0.9612 -0.4537   3.0
# 3                          2                1.0     3 -1.8176 -0.4537   2.0
# 4                          3                3.0     1  0.7516 -0.4537   2.0
#
#    VAR5  VAR6  VAR7  Attrition_rate
# 0     4     5     3          0.1841
# 1     3     5     3          0.0670
# 2     3     8     3          0.0851
# 3     3     7     3          0.0668
# 4     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                7000 non-null   object
#  1   Gender                     7000 non-null   int64
#  2   Age                        7000 non-null   float64
#  3   Education_Level            7000 non-null   int64
#  4   Relationship_Status        7000 non-null   int64
#  5   Hometown                   7000 non-null   int64
#  6   Unit                       7000 non-null   int64
#  7   Decision_skill_possess     7000 non-null   int64
#  8   Time_of_service            7000 non-null   float64
#  9   Time_since_promotion       7000 non-null   int64
#  10  growth_rate                7000 non-null   int64
#  11  Travel_Rate                7000 non-null   int64
#  12  Post_Level                 7000 non-null   int64
#  13  Pay_Scale                  7000 non-null   float64
#  14  Compensation_and_Benefits  7000 non-null   int64
#  15  Work_Life_balance          7000 non-null   float64
#  16  VAR1                       7000 non-null   int64
#  17  VAR2                       7000 non-null   float64
#  18  VAR3                       7000 non-null   float64
#  19  VAR4                       7000 non-null   float64
#  20  VAR5                       7000 non-null   int64
#  21  VAR6                       7000 non-null   int64
#  22  VAR7                       7000 non-null   int64
#  23  Attrition_rate             7000 non-null   float64
# dtypes: float64(8), int64(15), object(1)
# memory usage: 1.3+ MB

# %%
train["Employee_ID"] = train["Employee_ID"].astype(str).astype(int)
print(train.dtypes)
# Out:
# Employee_ID                    int64
# Gender                         int64
# Age                          float64
# Education_Level                int64
# Relationship_Status            int64
# Hometown                       int64
# Unit                           int64
# Decision_skill_possess         int64
# Time_of_service              float64
# Time_since_promotion           int64
# growth_rate                    int64
# Travel_Rate                    int64
# Post_Level                     int64
# Pay_Scale                    float64
# Compensation_and_Benefits      int64
# Work_Life_balance            float64
# VAR1                           int64
# VAR2                         float64
# VAR3                         float64
# VAR4                         float64
# VAR5                           int64
# VAR6                           int64
# VAR7                           int64
# Attrition_rate               float64
# dtype: object

# %%
train.head(5)
# Out:
#    Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0        23371       0  42.0                4                    1         1
# 1        18000       1  24.0                3                    0         3
# 2         3891       0  58.0                3                    1         0
# 3        17492       0  26.0                3                    0         2
# 4        22534       0  31.0                1                    1         3
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     2                       2              4.0                     4  ...
# 1     3                       0              5.0                     4  ...
# 2     8                       2             27.0                     3  ...
# 3     1                       1              4.0                     3  ...
# 4     3                       2              5.0                     4  ...
#
#    Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  VAR4  \
# 0                          2                3.0     4  0.7516  1.8688   2.0
# 1                          2                4.0     3 -0.9612 -0.4537   2.0
# 2                          2                1.0     4 -0.9612 -0.4537   3.0
# 3                          2                1.0     3 -1.8176 -0.4537   2.0
# 4                          3                3.0     1  0.7516 -0.4537   2.0
#
#    VAR5  VAR6  VAR7  Attrition_rate
# 0     4     5     3          0.1841
# 1     3     5     3          0.0670
# 2     3     8     3          0.0851
# 3     3     7     3          0.0668
# 4     2     8     2          0.1827
#
# [5 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
train_len=len(train)
test=train[:train_len]
test.drop(labels=["Attrition_rate"],axis=1,inplace=True)
test.head(10)
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0        23371       0  42.0                4                    1         1
# 1        18000       1  24.0                3                    0         3
# 2         3891       0  58.0                3                    1         0
# 3        17492       0  26.0                3                    0         2
# 4        22534       0  31.0                1                    1         3
# 5         2278       1  54.0                3                    1         2
# 6        18588       0  21.0                4                    1         3
# 7         1235       0  37.0                3                    1         3
# 8        10197       1  40.0                4                    0         3
# 9        21262       1  45.0                3                    1         2
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     2                       2              4.0                     4  ...
# 1     3                       0              5.0                     4  ...
# 2     8                       2             27.0                     3  ...
# 3     1                       1              4.0                     3  ...
# 4     3                       2              5.0                     4  ...
# 5     7                       2             19.0                     1  ...
# 6     7                       3              2.0                     1  ...
# 7    10                       3             34.0                     4  ...
# 8     6                       0             13.0                     1  ...
# 9     2                       3             21.0                     4  ...
#
#    Pay_Scale  Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2  \
# 0        7.0                          2                3.0     4  0.7516
# 1        6.0                          2                4.0     3 -0.9612
# 2        8.0                          2                1.0     4 -0.9612
# 3        8.0                          2                1.0     3 -1.8176
# 4        2.0                          3                3.0     1  0.7516
# 5        9.0                          2                1.0     3 -1.8176
# 6        6.0                          2                2.0     3 -0.9612
# 7        6.0                          3                2.0     3 -0.1048
# 8        9.0                          0                4.0     1 -0.1048
# 9        5.0                          3                4.0     3  0.7516
#
#      VAR3  VAR4  VAR5  VAR6  VAR7
# 0  1.8688   2.0     4     5     3
# 1 -0.4537   2.0     3     5     3
# 2 -0.4537   3.0     3     8     3
# 3 -0.4537   2.0     3     7     3
# 4 -0.4537   2.0     2     8     2
# 5  1.8688   2.0     2     8     3
# 6  0.7075   2.0     3     7     3
# 7 -0.4537   2.0     3     9     3
# 8  1.8688   2.0     5     6     3
# 9 -0.4537   2.0     4     8     3
#
# [10 rows x 23 columns]

# %%
train_df=train[:train_len]
X_train=train_df.drop(labels=["Attrition_rate"],axis=1)
y_train=train_df["Attrition_rate"]
X_train,X_test ,y_train,y_test=train_test_split(X_train,y_train,test_size=0.2,random_state=42)
print("X_train",len(X_train))
print("X_test",len(X_test))
print("y_train",len(y_train))
print("y_test",len(y_test))
print("test",len(test))

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# X_train 5600
# X_test 1400
# y_train 5600
# y_test 1400
# test 7000
# (5600, 23) (5600,)
# (1400, 23) (1400,)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
'''LinearRegression()'''
from sklearn.metrics import mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

y_pred = lr.predict(X_test)
print("Linear Regressor score on testing set: ", rmse(y_test, y_pred))
# Out:
# Linear Regressor score on testing set:  0.18660125575822858

# %%
Score = 100 * max(0 , 1 - rmse(y_test, y_pred))
print('Accuracy',Score)
# Out:
# Accuracy 81.33987442417714

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

model = XGBRegressor(n_estimators=1000,learning_rate=0.05,n_jobs=-1)
model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=1000, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

y_pred = model.predict(X_test)
print("XGBoost score on testing set: ", rmse(y_test, y_pred))
# Out:
# XGBoost score on testing set:  0.19843958727075534

# %%
Score = 100 * max(0 , 1 - rmse(y_test, y_pred))
print('Accuracy',Score)
# Out:
# Accuracy 80.15604127292445

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
  
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)


from sklearn.linear_model import Lasso
best_alpha = 0.0099

regr = Lasso(alpha=best_alpha, max_iter=50000)
regr.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.0099, max_iter=50000)

# %%
from sklearn.metrics import mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))
y_pred = regr.predict(X_test)
print("Lasso score on testing set: ", rmse(y_test, y_pred))
# Out:
# Lasso score on testing set:  0.18658105879227463

# %%
Score = 100 * max(0 , 1 - rmse(y_test, y_pred))
print('Accuracy',Score)
# Out:
# Accuracy 81.34189412077254
