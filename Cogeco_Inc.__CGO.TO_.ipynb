# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Cogeco = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/CGO.TO?period1=1568486777&period2=1600109177&interval=1d&events=history")

Cogeco
# Out:
#            Date       Open        High        Low      Close  Adj Close  Volume
# 0    2019-09-16  96.019997   96.029999  95.139999  96.010002  93.438721    8300
# 1    2019-09-17  96.150002  100.190002  96.150002  99.900002  97.224548   28900
# 2    2019-09-18  99.610001   99.610001  97.879997  98.010002  95.385162   20400
# 3    2019-09-19  98.650002   99.349998  98.449997  99.040001  96.387573    7300
# 4    2019-09-20  99.580002  100.080002  98.610001  99.139999  96.484901   13300
# ..          ...        ...         ...        ...        ...        ...     ...
# 246  2020-09-08  89.440002   89.889999  84.339996  88.209999  88.209999   60000
# 247  2020-09-09  88.510002   90.320000  86.760002  89.589996  89.589996   47900
# 248  2020-09-10  90.940002   91.019997  88.250000  89.529999  89.529999   42500
# 249  2020-09-11  90.400002   91.760002  89.529999  91.010002  91.010002   34700
# 250  2020-09-14  91.309998   92.610001  90.940002  91.480003  91.480003   18407
#
# ...

# %%
Cogeco.head()
# Out:
#          Date       Open        High        Low      Close  Adj Close  Volume
# 0  2019-09-16  96.019997   96.029999  95.139999  96.010002  93.438721    8300
# 1  2019-09-17  96.150002  100.190002  96.150002  99.900002  97.224548   28900
# 2  2019-09-18  99.610001   99.610001  97.879997  98.010002  95.385162   20400
# 3  2019-09-19  98.650002   99.349998  98.449997  99.040001  96.387573    7300
# 4  2019-09-20  99.580002  100.080002  98.610001  99.139999  96.484901   13300

# %%
Cogeco.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 246  2020-09-08  89.440002  89.889999  84.339996  88.209999  88.209999   60000
# 247  2020-09-09  88.510002  90.320000  86.760002  89.589996  89.589996   47900
# 248  2020-09-10  90.940002  91.019997  88.250000  89.529999  89.529999   42500
# 249  2020-09-11  90.400002  91.760002  89.529999  91.010002  91.010002   34700
# 250  2020-09-14  91.309998  92.610001  90.940002  91.480003  91.480003   18407

# %%
Cogeco.describe()
# Out:
#              Open        High  ...   Adj Close         Volume
# count  251.000000  251.000000  ...  251.000000     251.000000
# mean    91.117052   92.314223  ...   89.478961   25636.681275
# std      8.706672    8.378031  ...    7.978840   21263.851159
# min     71.000000   76.639999  ...   72.860283    3500.000000
# 25%     82.985000   84.479999  ...   82.262878   12300.000000
# 50%     90.940002   92.410004  ...   90.038567   19800.000000
# 75%     97.979999   99.059998  ...   95.171054   31750.000000
# max    106.970001  107.879997  ...  104.661247  184700.000000
#
# [8 rows x 6 columns]

# %%
Cogeco.info
# Out:
# <bound method DataFrame.info of            Date       Open        High        Low      Close  Adj Close  Volume
# 0    2019-09-16  96.019997   96.029999  95.139999  96.010002  93.438721    8300
# 1    2019-09-17  96.150002  100.190002  96.150002  99.900002  97.224548   28900
# 2    2019-09-18  99.610001   99.610001  97.879997  98.010002  95.385162   20400
# 3    2019-09-19  98.650002   99.349998  98.449997  99.040001  96.387573    7300
# 4    2019-09-20  99.580002  100.080002  98.610001  99.139999  96.484901   13300
# ..          ...        ...         ...        ...        ...        ...     ...
# 246  2020-09-08  89.440002   89.889999  84.339996  88.209999  88.209999   60000
# 247  2020-09-09  88.510002   90.320000  86.760002  89.589996  89.589996   47900
# 248  2020-09-10  90.940002   91.019997  88.250000  89.529999  89.529999   42500
# 249  2020-09-11  90.400002   91.760002  89.529999  91.010002  91.010002   34700
# ...

# %%
Cogeco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("Cogeco.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Cogeco.db")
c = conn.cursor()

# %%
Cogeco.to_sql("Cogeco", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM Cogeco""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   '2019-09-16',
#   96.019997,
#   96.029999,
#   95.139999,
#   96.010002,
#   93.438721,
#   8300),
#  (1,
#   '2019-09-17',
#   96.150002,
#   100.190002,
#   96.150002,
#   99.900002,
#   97.224548,
#   28900),
#  (2,
#   '2019-09-18',
#   99.610001,
#   99.610001,
#   97.879997,
#   98.010002,
#   95.385162,
#   20400),
#  (3,
#   '2019-09-19',
#   98.650002,
#   99.349998,
#   98.449997,
#   99.040001,
#   96.387573,
#   7300),
#  (4,
#   '2019-09-20',
#   99.58000200000001,
#   100.08000200000001,
#   98.610001,
#   99.139999,
#   96.48490100000001,
#   13300),
#  (5, '2019-09-23', 100.43, 100.43, 99.209999, 99.209999, 96.553024, 9100),
#  (6,
#   '2019-09-24',
#   99.33000200000001,
#   99.910004,
#   99.209999,
#   99.5,
#   96.835266,
#   5800),
#  (7, '2019-09-25', 99.809998, 100.25, 97.190002, 97.57, 94.95694, 19700),
#  (8,
#   '2019-09-26',
#   98.07,
#   98.779999,
#   97.83000200000001,
#   98.279999,
#   95.647926,
#   10200),
# ...

# %%
Cogeco.to_excel("Cogeco.xls")

pd.read_excel("Cogeco.xls")
# Out:
#      Unnamed: 0        Date       Open  ...      Close  Adj Close  Volume
# 0             0  2019-09-16  96.019997  ...  96.010002  93.438721    8300
# 1             1  2019-09-17  96.150002  ...  99.900002  97.224548   28900
# 2             2  2019-09-18  99.610001  ...  98.010002  95.385162   20400
# 3             3  2019-09-19  98.650002  ...  99.040001  96.387573    7300
# 4             4  2019-09-20  99.580002  ...  99.139999  96.484901   13300
# ..          ...         ...        ...  ...        ...        ...     ...
# 246         246  2020-09-08  89.440002  ...  88.209999  88.209999   60000
# 247         247  2020-09-09  88.510002  ...  89.589996  89.589996   47900
# 248         248  2020-09-10  90.940002  ...  89.529999  89.529999   42500
# 249         249  2020-09-11  90.400002  ...  91.010002  91.010002   34700
# 250         250  2020-09-14  91.309998  ...  91.480003  91.480003   18407
#
# [251 rows x 8 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Cogeco Inc. (CGO.TO)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Cogeco Inc. (CGO.TO)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.
