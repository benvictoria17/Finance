# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance

# %%
BTCUSD = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/BTC-USD?period1=1562519369&period2=1594141769&interval=1d&events=history")

BTCUSD

# %%
BTCUSD.head()

# %%
BTCUSD.tail()

# %%
BTCUSD.describe()

# %%
plt.pie([0,1,2,4,5]) 
plt.show

# %%
plt.plot([0,1,2,4,5])
plt.show

# %%
BTCUSD = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/%5EIXIC?period1=1562508067&period2=1594130467&interval=1d&events=history")

BTCUSD

# %%
BTCUSD.to_csv("BTCUSD.csv")

pd.read_csv("BTCUSD.csv")

# %%
BTCUSD = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/BTC-USD?period1=1562519369&period2=1594141769&interval=1d&events=history")

pd.read_csv("BTCUSD.csv")

# %%
BTCUSD.to_excel("BTCUSD.xls")

pd.read_excel("BTCUSD.xls")
