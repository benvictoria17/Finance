# %%
import pandas as pd 
import numpy as np 
import math 
import matplotlib.pyplot as plt
import sqlite3
import yfinance

# %%
CADEUR = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/CADEUR=X?period1=1563029350&period2=1594651750&interval=1d&events=history")


CADEUR
# Out:
#            Date     Open      High      Low     Close  Adj Close  Volume
# 0    2019-07-15  0.68058  0.681550  0.68000  0.680600   0.680600     0.0
# 1    2019-07-16  0.68049  0.684580  0.67990  0.680470   0.680470     0.0
# 2    2019-07-17  0.68120  0.683100  0.68100  0.681490   0.681490     0.0
# 3    2019-07-18  0.68216  0.683310  0.68020  0.682240   0.682240     0.0
# 4    2019-07-19  0.68119  0.682470  0.67970  0.681100   0.681100     0.0
# ..          ...      ...       ...      ...       ...        ...     ...
# 256  2020-07-07  0.65276  0.653971  0.65122  0.652882   0.652882     0.0
# 257  2020-07-08  0.65179  0.652400  0.65068  0.651600   0.651600     0.0
# 258  2020-07-09  0.65242  0.654190  0.65110  0.652450   0.652450     0.0
# 259  2020-07-10  0.65234  0.652730  0.64960  0.652100   0.652100     0.0
# 260  2020-07-13  0.65070  0.651600  0.64860  0.649000   0.649000     0.0
#
# [261 rows x 7 columns]

# %%
CADEUR.head()
# Out:
#          Date     Open     High     Low    Close  Adj Close  Volume
# 0  2019-07-15  0.68058  0.68155  0.6800  0.68060    0.68060     0.0
# 1  2019-07-16  0.68049  0.68458  0.6799  0.68047    0.68047     0.0
# 2  2019-07-17  0.68120  0.68310  0.6810  0.68149    0.68149     0.0
# 3  2019-07-18  0.68216  0.68331  0.6802  0.68224    0.68224     0.0
# 4  2019-07-19  0.68119  0.68247  0.6797  0.68110    0.68110     0.0

# %%
CADEUR.tail()
# Out:
#            Date     Open      High      Low     Close  Adj Close  Volume
# 256  2020-07-07  0.65276  0.653971  0.65122  0.652882   0.652882     0.0
# 257  2020-07-08  0.65179  0.652400  0.65068  0.651600   0.651600     0.0
# 258  2020-07-09  0.65242  0.654190  0.65110  0.652450   0.652450     0.0
# 259  2020-07-10  0.65234  0.652730  0.64960  0.652100   0.652100     0.0
# 260  2020-07-13  0.65070  0.651600  0.64860  0.649000   0.649000     0.0

# %%
CADEUR.describe()
# Out:
#             Open        High         Low       Close   Adj Close  Volume
# count  241.00000  241.000000  241.000000  241.000000  241.000000   241.0
# mean     0.67204    0.674146    0.669906    0.672002    0.672002     0.0
# std      0.01631    0.015554    0.016990    0.016332    0.016332     0.0
# min      0.63098    0.640380    0.625190    0.631400    0.631400     0.0
# 25%      0.65570    0.657850    0.653900    0.655770    0.655770     0.0
# 50%      0.67983    0.681770    0.678600    0.679700    0.679700     0.0
# 75%      0.68501    0.686530    0.683600    0.685050    0.685050     0.0
# max      0.69930    0.700900    0.698000    0.699600    0.699600     0.0

# %%
import sqlite3

# %%
conn = sqlite3.connect("CADEUR.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("CADEUR.db")
c = conn.cursor()

# %%
CADEUR.to_sql("CADEUR", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM CADEUR""")
rows = c.fetchall()
rows
# Out:
# [(0, '2019-07-15', 0.68058, 0.68155, 0.68, 0.6806, 0.6806, 0.0),
#  (1, '2019-07-16', 0.6804899999999999, 0.68458, 0.6799, 0.68047, 0.68047, 0.0),
#  (2,
#   '2019-07-17',
#   0.6812,
#   0.6831,
#   0.681,
#   0.6814899999999999,
#   0.6814899999999999,
#   0.0),
#  (3, '2019-07-18', 0.68216, 0.6833100000000001, 0.6802, 0.68224, 0.68224, 0.0),
#  (4, '2019-07-19', 0.68119, 0.68247, 0.6797, 0.6811, 0.6811, 0.0),
#  (5, '2019-07-22', 0.6827, 0.6835, 0.6794, 0.68276, 0.68276, 0.0),
#  (6, '2019-07-23', 0.67969, 0.68248, 0.6794, 0.67966, 0.67966, 0.0),
#  (7, '2019-07-24', 0.6822, 0.68395, 0.6822, 0.6824, 0.6824, 0.0),
#  (8, '2019-07-25', 0.68275, 0.68591, 0.67981, 0.6826, 0.6826, 0.0),
#  (9, '2019-07-26', 0.6816399999999999, 0.68213, 0.6804, 0.6814, 0.6814, 0.0),
#  (10, '2019-07-29', 0.68216, 0.6836300000000001, 0.6816, 0.682, 0.682, 0.0),
#  (11, '2019-07-30', 0.68166, 0.68203, 0.68, 0.68158, 0.68158, 0.0),
#  (12, '2019-07-31', 0.6815, 0.68509, 0.6814, 0.68157, 0.68157, 0.0),
# ...

# %%
CADEUR.to_excel("CADEUR.xls")

pd.read_excel("CADEUR.xls")
# Out:
#      Unnamed: 0        Date     Open      High      Low     Close  Adj Close  \
# 0             0  2019-07-15  0.68058  0.681550  0.68000  0.680600   0.680600
# 1             1  2019-07-16  0.68049  0.684580  0.67990  0.680470   0.680470
# 2             2  2019-07-17  0.68120  0.683100  0.68100  0.681490   0.681490
# 3             3  2019-07-18  0.68216  0.683310  0.68020  0.682240   0.682240
# 4             4  2019-07-19  0.68119  0.682470  0.67970  0.681100   0.681100
# ..          ...         ...      ...       ...      ...       ...        ...
# 256         256  2020-07-07  0.65276  0.653971  0.65122  0.652882   0.652882
# 257         257  2020-07-08  0.65179  0.652400  0.65068  0.651600   0.651600
# 258         258  2020-07-09  0.65242  0.654190  0.65110  0.652450   0.652450
# 259         259  2020-07-10  0.65234  0.652730  0.64960  0.652100   0.652100
# 260         260  2020-07-13  0.65070  0.651600  0.64860  0.649000   0.649000
#
#      Volume
# 0       0.0
# 1       0.0
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('CADEUR', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('CADEUR')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
