# %%
# !pip install  yfinance

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader
import sqlite3

# %%
BTC_USD_2020 = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/AnalyzeStocks/master/dataset/BTC_USD_2020-11-01-CoinDesk.csv")

BTC_USD_2020
# Out:
#   Currency        Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      BTC  2020-11-01         13795.594003    13740.042209    13873.963413
#
#    24h Low (USD)
# 0   13679.072242

# %%
BTC_USD_2020.head()
# Out:
#   Currency        Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      BTC  2020-11-01         13795.594003    13740.042209    13873.963413
#
#    24h Low (USD)
# 0   13679.072242

# %%
BTC_USD_2020.tail()
# Out:
#   Currency        Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      BTC  2020-11-01         13795.594003    13740.042209    13873.963413
#
#    24h Low (USD)
# 0   13679.072242

# %%
BTC_USD_2020.describe()
# Out:
#        Closing Price (USD)  24h Open (USD)  24h High (USD)  24h Low (USD)
# count             1.000000        1.000000        1.000000       1.000000
# mean          13795.594003    13740.042209    13873.963413   13679.072242
# std                    NaN             NaN             NaN            NaN
# min           13795.594003    13740.042209    13873.963413   13679.072242
# 25%           13795.594003    13740.042209    13873.963413   13679.072242
# 50%           13795.594003    13740.042209    13873.963413   13679.072242
# 75%           13795.594003    13740.042209    13873.963413   13679.072242
# max           13795.594003    13740.042209    13873.963413   13679.072242

# %%
BTC_USD_2020.info
# Out:
# <bound method DataFrame.info of   Currency        Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      BTC  2020-11-01         13795.594003    13740.042209    13873.963413
#
#    24h Low (USD)
# 0   13679.072242  >

# %%
BTC_USD_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Currency             1 non-null      object
#  1   Date                 1 non-null      object
#  2   Closing Price (USD)  1 non-null      float64
#  3   24h Open (USD)       1 non-null      float64
#  4   24h High (USD)       1 non-null      float64
#  5   24h Low (USD)        1 non-null      float64
# dtypes: float64(4), object(2)
# memory usage: 176.0+ bytes

# %%
conn = sqlite3.connect("BTC_USD_2020.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("BTC_USD_2020.db")
c = conn.cursor()

# %%
BTC_USD_2020.to_sql("BTC_USD_2020", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2615: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM BTC_USD_2020""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   'BTC',
#   '2020-11-01',
#   13795.5940034168,
#   13740.042209020901,
#   13873.9634129393,
#   13679.0722421431)]

# %%
BTC_USD_2020.to_excel("BTC_USD_2020.xls")

pd.read_excel("BTC_USD_2020.xls")
# Out:
#    Unnamed: 0 Currency        Date  Closing Price (USD)  24h Open (USD)  \
# 0           0      BTC  2020-11-01         13795.594003    13740.042209
#
#    24h High (USD)  24h Low (USD)
# 0    13873.963413   13679.072242
