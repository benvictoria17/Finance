# %%
import pandas as pd

# %%
unemployment_data = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/US%20Unemployment%20Dataset%20(2010%20-%202020)/unemployment_data_us.csv")
unemployment_data_state = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/US%20Unemployment%20Dataset%20(2010%20-%202020)/unemployment_data_us_state.csv")

# %%
unemployment_data.head(5)
# Out:
#    Year Month  Primary_School      Date  High_School  Associates_Degree  \
# 0  2010   Jan            15.3  Jan-2010         10.2                8.6
# 1  2011   Jan            14.3  Jan-2011          9.5                8.1
# 2  2012   Jan            13.0  Jan-2012          8.5                7.1
# 3  2013   Jan            12.0  Jan-2013          8.1                6.9
# 4  2014   Jan             9.4  Jan-2014          6.5                5.9
#
#    Professional_Degree  White  Black  Asian  Hispanic   Men  Women
# 0                  4.9    8.8   16.5    8.3      12.9  10.2    7.9
# 1                  4.3    8.1   15.8    6.8      12.3   9.0    7.9
# 2                  4.3    7.4   13.6    6.7      10.7   7.7    7.6
# 3                  3.8    7.1   13.7    6.4       9.7   7.5    7.2
# 4                  3.3    5.7   12.1    4.7       8.3   6.2    5.8

# %%
unemployment_data.tail(5)
# Out:
#      Year Month  Primary_School      Date  High_School  Associates_Degree  \
# 127  2016   Dec             7.5  Dec-2016          5.1                3.8
# 128  2017   Dec             6.2  Dec-2017          4.2                3.6
# 129  2018   Dec             5.8  Dec-2018          3.8                3.3
# 130  2019   Dec             5.2  Dec-2019          3.7                2.7
# 131  2020   Dec             NaN  Dec-2020          NaN                NaN
#
#      Professional_Degree  White  Black  Asian  Hispanic  Men  Women
# 127                  2.5    4.2    7.9    2.7       5.9  4.4    4.3
# 128                  2.2    3.7    6.7    2.5       5.0  3.7    3.7
# 129                  2.2    3.4    6.6    3.3       4.4  3.6    3.5
# 130                  1.9    3.2    5.9    2.5       4.2  3.1    3.2
# 131                  NaN    NaN    NaN    NaN       NaN  NaN    NaN

# %%
unemployment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 132 non-null    int64
#  1   Month                132 non-null    object
#  2   Primary_School       123 non-null    float64
#  3   Date                 132 non-null    object
#  4   High_School          123 non-null    float64
#  5   Associates_Degree    123 non-null    float64
#  6   Professional_Degree  123 non-null    float64
#  7   White                123 non-null    float64
#  8   Black                123 non-null    float64
#  9   Asian                123 non-null    float64
#  10  Hispanic             123 non-null    float64
#  11  Men                  123 non-null    float64
#  12  Women                123 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 13.5+ KB

# %%
unemployment_data = unemployment_data.dropna()
unemployment_data['Date'] =pd.to_datetime(unemployment_data.Date)
unemployment_data = unemployment_data.sort_values(by='Date', ascending=True)
# Out:
# <ipython-input-19-ea4617fc6606>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemployment_data['Date'] =pd.to_datetime(unemployment_data.Date)

# %%
unemployment_data.isna().sum()
# Out:
# Year                   0
# Month                  0
# Primary_School         0
# Date                   0
# High_School            0
# Associates_Degree      0
# Professional_Degree    0
# White                  0
# Black                  0
# Asian                  0
# Hispanic               0
# Men                    0
# Women                  0
# dtype: int64

# %%
unemployment_data.describe()
# Out:
#               Year  Primary_School  High_School  Associates_Degree  \
# count   123.000000      123.000000   123.000000         123.000000
# mean   2014.634146        9.329268     6.391057           5.338211
# std       2.973292        3.343178     2.223607           1.895314
# min    2010.000000        4.800000     3.400000           2.700000
# 25%    2012.000000        6.350000     4.450000           3.700000
# 50%    2015.000000        8.500000     5.500000           4.900000
# 75%    2017.000000       12.250000     8.300000           7.000000
# max    2020.000000       15.800000    11.000000           8.900000
#
#        Professional_Degree       White       Black       Asian    Hispanic  \
# count           123.000000  123.000000  123.000000  123.000000  123.000000
# mean              3.127642    5.455285   10.692683    4.679675    7.660163
# std               0.937585    1.881454    3.615907    1.668363    2.837274
# min               1.900000    3.100000    5.400000    2.100000    3.900000
# 25%               2.300000    3.750000    7.400000    3.300000    5.050000
# 50%               2.800000    4.800000   10.300000    4.200000    6.800000
# 75%               4.000000    7.250000   13.900000    6.050000   10.150000
# max               5.000000    9.000000   16.800000    8.300000   12.900000
#
#               Men       Women
# count  123.000000  123.000000
# mean     5.848780    5.485366
# std      2.160577    1.750910
# min      3.100000    3.100000
# 25%      3.950000    3.900000
# 50%      5.200000    5.000000
# 75%      7.600000    7.400000
# max     10.300000    8.400000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Primary_School', data=unemployment_data, color='red')
plt.plot( 'Date', 'High_School', data=unemployment_data, color='yellow')
plt.plot( 'Date', 'Associates_Degree', data=unemployment_data, color='magenta')
plt.plot( 'Date', 'Professional_Degree', data=unemployment_data, color='blue')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.plot( 'Date', 'White', data=unemployment_data, color='magenta')
plt.plot( 'Date', 'Black', data=unemployment_data, color='red')
plt.plot( 'Date', 'Asian', data=unemployment_data, color='blue')
plt.plot( 'Date', 'Hispanic', data=unemployment_data, color='yellow')
plt.legend()
# Out:
# <ipython-input-24-a2724a629632>:2: RuntimeWarning: Second argument 'White' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'Date', 'White', data=unemployment_data, color='magenta')
# <ipython-input-24-a2724a629632>:3: RuntimeWarning: Second argument 'Black' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'Date', 'Black', data=unemployment_data, color='red')

# %%
plt.figure(figsize=(20,10))
plt.plot( 'Date', 'Men', data=unemployment_data, color='blue')
plt.plot( 'Date', 'Women', data=unemployment_data, color='magenta')
plt.legend()

# %%
unemployment_data.head(5)
# Out:
#     Year Month  Primary_School       Date  High_School  Associates_Degree  \
# 0   2010   Jan            15.3 2010-01-01         10.2                8.6
# 11  2010   Feb            15.8 2010-02-01         10.7                8.1
# 22  2010   Mar            14.9 2010-03-01         11.0                8.4
# 33  2010   Apr            14.7 2010-04-01         10.8                8.4
# 44  2010   May            14.6 2010-05-01         10.9                8.2
#
#     Professional_Degree  White  Black  Asian  Hispanic   Men  Women
# 0                   4.9    8.8   16.5    8.3      12.9  10.2    7.9
# 11                  4.9    8.9   16.1    8.2      12.7  10.3    8.0
# 22                  4.9    8.9   16.8    7.6      12.9  10.2    8.1
# 33                  4.8    9.0   16.6    7.0      12.5  10.2    8.3
# 44                  4.6    8.7   15.5    7.8      12.0   9.7    8.1

# %%
unemployment_data_state.tail(5)
# Out:
#              State Month  Unemployment_Rate      Date
# 151     Washington   Mar                5.1  Mar-2020
# 152  West Virginia   Mar                6.1  Mar-2020
# 153      Wisconsin   Mar                3.4  Mar-2020
# 154        Wyoming   Mar                3.7  Mar-2020
# 155    Puerto Rico   Mar                NaN  Mar-2020

# %%
unemployment_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 123 entries, 0 to 32
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 123 non-null    int64
#  1   Month                123 non-null    object
#  2   Primary_School       123 non-null    float64
#  3   Date                 123 non-null    datetime64[ns]
#  4   High_School          123 non-null    float64
#  5   Associates_Degree    123 non-null    float64
#  6   Professional_Degree  123 non-null    float64
#  7   White                123 non-null    float64
#  8   Black                123 non-null    float64
#  9   Asian                123 non-null    float64
#  10  Hispanic             123 non-null    float64
#  11  Men                  123 non-null    float64
#  12  Women                123 non-null    float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 13.5+ KB

# %%
unemployment_data_state = unemployment_data_state.dropna()
unemployment_data_state['Date'] =pd.to_datetime(unemployment_data_state.Date)
unemployment_data_state = unemployment_data_state.sort_values(by='Date', ascending=True)
unemployment_data_state.isna().sum()
# Out:
# <ipython-input-29-0c2c5194f107>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unemployment_data_state['Date'] =pd.to_datetime(unemployment_data_state.Date)
# State                0
# Month                0
# Unemployment_Rate    0
# Date                 0
# dtype: int64

# %%
unemployment_data.describe()
# Out:
#               Year  Primary_School  High_School  Associates_Degree  \
# count   123.000000      123.000000   123.000000         123.000000
# mean   2014.634146        9.329268     6.391057           5.338211
# std       2.973292        3.343178     2.223607           1.895314
# min    2010.000000        4.800000     3.400000           2.700000
# 25%    2012.000000        6.350000     4.450000           3.700000
# 50%    2015.000000        8.500000     5.500000           4.900000
# 75%    2017.000000       12.250000     8.300000           7.000000
# max    2020.000000       15.800000    11.000000           8.900000
#
#        Professional_Degree       White       Black       Asian    Hispanic  \
# count           123.000000  123.000000  123.000000  123.000000  123.000000
# mean              3.127642    5.455285   10.692683    4.679675    7.660163
# std               0.937585    1.881454    3.615907    1.668363    2.837274
# min               1.900000    3.100000    5.400000    2.100000    3.900000
# 25%               2.300000    3.750000    7.400000    3.300000    5.050000
# 50%               2.800000    4.800000   10.300000    4.200000    6.800000
# 75%               4.000000    7.250000   13.900000    6.050000   10.150000
# max               5.000000    9.000000   16.800000    8.300000   12.900000
#
#               Men       Women
# count  123.000000  123.000000
# mean     5.848780    5.485366
# std      2.160577    1.750910
# min      3.100000    3.100000
# 25%      3.950000    3.900000
# 50%      5.200000    5.000000
# 75%      7.600000    7.400000
# max     10.300000    8.400000

# %%
print(unemployment_data_state[unemployment_data_state.State == 'New York'])
# Out:
#         State Month  Unemployment_Rate       Date
# 32   New York   Jan                3.8 2020-01-01
# 84   New York   Feb                3.6 2020-02-01
# 136  New York   Mar                4.5 2020-03-01
