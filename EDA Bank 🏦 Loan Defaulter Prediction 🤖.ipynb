# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import plotly
from plotly import tools
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
app_d = pd.read_csv("dataset/LoanDefaulter/columns_description.csv")

# %%
app_d
# Out:
#      Unnamed: 0                     Table                        Row  \
# 0             1          application_data                 SK_ID_CURR
# 1             2          application_data                     TARGET
# 2             5          application_data         NAME_CONTRACT_TYPE
# 3             6          application_data                CODE_GENDER
# 4             7          application_data               FLAG_OWN_CAR
# ..          ...                       ...                        ...
# 155         209  previous_application.csv             DAYS_FIRST_DUE
# 156         210  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 157         211  previous_application.csv              DAYS_LAST_DUE
# 158         212  previous_application.csv           DAYS_TERMINATION
# 159         213  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                            Description  \
# 0                             ID of loan in our sample
# ...

# %%
app_d.head()
# Out:
#    Unnamed: 0             Table                 Row  \
# 0           1  application_data          SK_ID_CURR
# 1           2  application_data              TARGET
# 2           5  application_data  NAME_CONTRACT_TYPE
# 3           6  application_data         CODE_GENDER
# 4           7  application_data        FLAG_OWN_CAR
#
#                                          Description Special
# 0                           ID of loan in our sample     NaN
# 1  Target variable (1 - client with payment diffi...     NaN
# 2        Identification if loan is cash or revolving     NaN
# 3                               Gender of the client     NaN
# 4                      Flag if the client owns a car     NaN

# %%
app_d.shape
# Out:
# (160, 5)

# %%
prev_app = pd.read_csv("dataset/LoanDefaulter/previous_application.csv")

# %%
prev_app
# Out:
#          SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# 0           2030495      271877     Consumer loans     1730.430
# 1           2802425      108129         Cash loans    25188.615
# 2           2523466      122040         Cash loans    15060.735
# 3           2819243      176158         Cash loans    47041.335
# 4           1784265      202054         Cash loans    31924.395
# ...             ...         ...                ...          ...
# 1670209     2300464      352015     Consumer loans    14704.290
# 1670210     2357031      334635     Consumer loans     6622.020
# 1670211     2659632      249544     Consumer loans    11520.855
# 1670212     2785582      400317         Cash loans    18821.520
# 1670213     2418762      261212         Cash loans    16431.300
#
#          AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# 0                17145.0     17145.0               0.0          17145.0
# ...

# %%
prev_app.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
# ...

# %%
prev_app.shape
# Out:
# (1670214, 37)

# %%
col_des = pd.read_csv("dataset/LoanDefaulter/columns_description.csv")

# %%
col_des
# Out:
#      Unnamed: 0                     Table                        Row  \
# 0             1          application_data                 SK_ID_CURR
# 1             2          application_data                     TARGET
# 2             5          application_data         NAME_CONTRACT_TYPE
# 3             6          application_data                CODE_GENDER
# 4             7          application_data               FLAG_OWN_CAR
# ..          ...                       ...                        ...
# 155         209  previous_application.csv             DAYS_FIRST_DUE
# 156         210  previous_application.csv  DAYS_LAST_DUE_1ST_VERSION
# 157         211  previous_application.csv              DAYS_LAST_DUE
# 158         212  previous_application.csv           DAYS_TERMINATION
# 159         213  previous_application.csv  NFLAG_INSURED_ON_APPROVAL
#
#                                            Description  \
# 0                             ID of loan in our sample
# ...

# %%
col_des.head()
# Out:
#    Unnamed: 0             Table                 Row  \
# 0           1  application_data          SK_ID_CURR
# 1           2  application_data              TARGET
# 2           5  application_data  NAME_CONTRACT_TYPE
# 3           6  application_data         CODE_GENDER
# 4           7  application_data        FLAG_OWN_CAR
#
#                                          Description Special
# 0                           ID of loan in our sample     NaN
# 1  Target variable (1 - client with payment diffi...     NaN
# 2        Identification if loan is cash or revolving     NaN
# 3                               Gender of the client     NaN
# 4                      Flag if the client owns a car     NaN

# %%
col_des.shape
# Out:
# (160, 5)

# %%
app_d.info("all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   160 non-null    int64
#  1   Table        160 non-null    object
#  2   Row          160 non-null    object
#  3   Description  160 non-null    object
#  4   Special      69 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 6.4+ KB

# %%
prev_app.info("all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
# ...

# %%
col_des.info("all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   160 non-null    int64
#  1   Table        160 non-null    object
#  2   Row          160 non-null    object
#  3   Description  160 non-null    object
#  4   Special      69 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 6.4+ KB

# %%
app_empty = app_d.isnull().sum()/len(app_d)*100
app_empty=app_d.isnull().sum()
app_empty
# Out:
# Unnamed: 0      0
# Table           0
# Row             0
# Description     0
# Special        91
# dtype: int64

# %%
pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 600)
pd.set_option('display.width', 1200)
app_empty.sort_values(ascending = False).head(50)
# Out:
# Special        91
# Unnamed: 0      0
# Table           0
# Row             0
# Description     0
# dtype: int64

# %%
null_col = app_d.isnull().sum().sort_values(ascending = False)
null_col = null_col[null_col.values >(0.3*len(app_d))]
null_col
# Out:
# Special    91
# dtype: int64

# %%
len(null_col)
# Out:
# 1

# %%
def nullremoval(dataframe_app,percent=0.30):     #function to accept the dataframe and percent value.
    df_app = dataframe_app.copy()                #creating a copy of the dataframe
    colnames = (df_app.isnull().sum()/len(df_app))  # finding out empty or blank columns
    colnames = list(colnames[colnames.values>=percent].index)  # checking if the values are greater then or equal to the percent value and then storing it in columns.
    df_app.drop(labels = colnames,axis =1,inplace=True)  
    print("Total number of columns dropped: ",len(colnames))    
    return df_app
app_d = nullremoval(app_d,percent = 0.30)
# Out:
# Total number of columns dropped:  1

# %%
app_d.info("all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   160 non-null    int64
#  1   Table        160 non-null    object
#  2   Row          160 non-null    object
#  3   Description  160 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 5.1+ KB

# %%
app_d.isnull().sum()/len(app_d)*100
# Out:
# Unnamed: 0     0.0
# Table          0.0
# Row            0.0
# Description    0.0
# dtype: float64

# %%
app_d['AMT_ANNUITY'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AMT_ANNUITY'
#
# The above exception was the direct cause of the following exception:
#
# ...
