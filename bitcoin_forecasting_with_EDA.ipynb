# %%
import pandas as pd 
bitcoin_price_1week_Test = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Bitcoin%20Price%20Prediction%20(LightWeight%20CSV)/bitcoin_price_1week_Test%20-%20Test.csv")
bitcoin_price_Training_Training = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Bitcoin%20Price%20Prediction%20(LightWeight%20CSV)/bitcoin_price_Training%20-%20Training.csv")

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
bitcoin = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/bitcoin/BTC-EUR.csv")
bitcoin.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 1  2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2  2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 3  2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 4  2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#      Volume
# 0  16389165
# 1  26691849
# 2  29560102
# 3  28736825
# 4  20702624

# %%
bitcoin["Close"].plot(figsize=(12,8))
plt.show()

# %%
bitcoin.index
# Out:
# RangeIndex(start=0, stop=1877, step=1)

# %%
bitcoin = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/bitcoin/BTC-EUR.csv",index_col='Date',parse_dates=True)
bitcoin.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  359.546204  361.468506  351.586884  355.957367  355.957367
# 2014-09-18  355.588409  355.505402  319.789459  328.539368  328.539368
# 2014-09-19  328.278503  330.936707  298.921021  307.761139  307.761139
# 2014-09-20  307.665253  329.978180  303.931244  318.758972  318.758972
# 2014-09-21  318.120514  321.504517  306.502197  310.632446  310.632446
#
#               Volume
# Date
# 2014-09-17  16389165
# 2014-09-18  26691849
# 2014-09-19  29560102
# 2014-09-20  28736825
# 2014-09-21  20702624

# %%
bitcoin['Close'].plot(figsize=(12,8))
plt.show()

# %%
bitcoin['Close'].plot(figsize=(12,8))
plt.show()

# %%
bitcoin['2019']['Close'].plot(figsize=(12,8))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin['2019/09']['Close'].plot(figsize=(12,8))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin['2017':'2019']['Close'].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bitcoin.loc['2018':'2019']['Close'].resample('M').plot(figsize=(12,8))
plt.show()

# %%
bitcoin.loc['2018':'2019']['Close'].resample('M').mean().plot(figsize=(12,8))
plt.show()

# %%
bitcoin.loc['2018':'2019']['Close'].resample('M').mean().plot.bar(figsize=(12,8))
plt.show()

# %%
bitcoin.loc['2018':'2019']['Close'].resample('3W').std().plot(figsize=(12,8))
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc['2019','Close'].plot()
bitcoin.loc['2019','Close'].resample('M').mean().plot(label='moyenne par mois',lw=3,ls='--',alpha=0.8)
bitcoin.loc['2019','Close'].resample('W').mean().plot(label='moyenne par semaine',lw=2,ls=':',alpha=0.8)
plt.legend()
plt.show()

# %%
bitcoin.loc['2019','Close'].resample('M').agg(['mean','std','min','max'])
# Out:
#                    mean          std          min           max
# Date
# 2019-01-31  3241.492786   154.675614  3015.454102   3572.601807
# 2019-02-28  3270.404367   183.437120  2998.157227   3653.833008
# 2019-03-31  3518.958677    84.929101  3317.817383   3659.444824
# 2019-04-30  4609.844377   222.918594  3710.858154   4964.707031
# 2019-05-31  6532.714403  1010.175947  4823.619629   7866.871094
# 2019-06-30  8327.527637  1357.107430  6791.208984  11443.038086
# 2019-07-31  9511.153604   776.404643  8452.749023  11221.008789
# 2019-08-31  9552.757151   598.797179  8598.343750  10697.322266
# 2019-09-30  8902.757308   762.564631  7405.604980   9681.073242
# 2019-10-31  7605.179577   461.685352  6748.621094   8617.566406
# 2019-11-30  8377.360677    84.559862  8270.445313   8458.521484

# %%
m = bitcoin.loc['2019','Close'].resample('M').agg(['mean','std','min','max'])

plt.figure(figsize=(12,8))
m['mean']['2019'].plot(label='moyenne par mois')

plt.fill_between(m.index,m['min']['2019'],m['max']['2019'],alpha=0.2,label='max-min par mois')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin['2019/09']['Close'].plot()

for i in np.arange(0.2,1,0.2):
    bitcoin['2019/09']['Close'].ewm(alpha=i).mean().plot(label=f"ewm pour alpha = {i}",ls = ':')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   """

# %%
etherium = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/etherium/ETH-EUR.csv",index_col='Date',parse_dates=True)
etherium.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2015-08-07  2.592821  3.231847  2.299453  2.526771   2.526771   149784
# 2015-08-08  2.546495  2.551098  0.651468  0.686651   0.686651   614518
# 2015-08-09  0.643639  0.801941  0.573504  0.640651   0.640651   485733
# 2015-08-10  0.651688  0.662660  0.579996  0.643283   0.643283   368004
# 2015-08-11  0.642956  1.024735  0.604369  0.967177   0.967177  1325151

# %%
pd.merge(bitcoin,etherium,on='Date',how = 'inner',suffixes = ('_btc','_eth'))
# Out:
#                Open_btc     High_btc      Low_btc    Close_btc  Adj Close_btc  \
# Date
# 2015-08-07   255.233948   255.762100   253.128769   254.840027     254.840027
# 2015-08-08   254.983139   255.152679   237.635574   237.897186     237.897186
# 2015-08-09   238.005646   243.371613   237.414993   241.952362     241.952362
# 2015-08-10   242.312881   243.509033   239.726135   240.143463     240.143463
# 2015-08-11   240.027252   244.892654   240.676193   244.892654     244.892654
# ...                 ...          ...          ...          ...            ...
# 2019-11-02  8291.172852  8397.126953  8282.598633  8349.874023    8349.874023
# 2019-11-03  8349.936523  8399.804688  8186.173828  8270.445313    8270.445313
# 2019-11-04  8270.670898  8541.590820  8259.809570  8458.521484    8458.521484
# 2019-11-05  8458.875000  8540.323242  8359.278320  8436.573242    8436.573242
# 2019-11-06  8435.071289  8512.726563  8406.735352  8456.394531    8456.394531
#
#              Volume_btc    Open_eth    High_eth     Low_eth   Close_eth  \
# Date
# 2015-08-07     38724637    2.592821    3.231847    2.299453    2.526771
# 2015-08-08     53352474    2.546495    2.551098    0.651468    0.686651
# 2015-08-09     21713764    0.643639    0.801941    0.573504    0.640651
# 2015-08-10     19049668    0.651688    0.662660    0.579996    0.643283
# 2015-08-11     23035866    0.642956    1.024735    0.604369    0.967177
# ...                 ...         ...         ...         ...         ...
# 2019-11-02  19021882025  164.769119  166.294189  163.687271  164.697388
# 2019-11-03  18924326413  164.759277  165.692886  161.030746  163.365250
# 2019-11-04  23517560012  163.270340  168.964371  163.391617  167.465668
# 2019-11-05  23658103729  167.424438  172.711365  166.457123  170.947159
# 2019-11-06  20898606220  170.774979  174.845932  170.437851  173.081284
#
#             Adj Close_eth  Volume_eth
# Date
# 2015-08-07       2.526771      149784
# 2015-08-08       0.686651      614518
# 2015-08-09       0.640651      485733
# 2015-08-10       0.643283      368004
# 2015-08-11       0.967177     1325151
# ...                   ...         ...
# 2019-11-02     164.697388  7242440812
# 2019-11-03     163.365250  7844977059
# 2019-11-04     167.465668  9482343886
# 2019-11-05     170.947159  9052122841
# 2019-11-06     173.081284  9175101020
#
# [1553 rows x 12 columns]

# %%
btc_eth = pd.merge(bitcoin,etherium,on='Date',how = 'inner',suffixes = ('_btc','_eth'))
btc_eth[['Close_btc','Close_eth']].plot(subplots=True,figsize=(12,8))
plt.show()

# %%
btc_eth[['Close_btc','Close_eth']].corr()
# Out:
#            Close_btc  Close_eth
# Close_btc    1.00000    0.77842
# Close_eth    0.77842    1.00000
