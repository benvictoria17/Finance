# %%
# !pip install  yfinance

# %%
# !pip install --upgrade pip
# Out:
# Requirement already up-to-date: pip in /opt/conda/lib/python3.7/site-packages (20.2.2)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader
import sqlite3
import yfinance

# %%
MU = "MU"

# %%
MU = yfinance.download(MU)

MU
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 1984-06-01   0.000000   1.425000   1.412500   1.412500   1.385186   7340000
# 1984-06-04   0.000000   1.425000   1.412500   1.412500   1.385186   4066800
# 1984-06-05   0.000000   1.412500   1.400000   1.400000   1.372928   2088800
# 1984-06-06   0.000000   1.500000   1.475000   1.475000   1.446478   1894000
# 1984-06-07   0.000000   1.650000   1.637500   1.637500   1.605836   2078000
# ...               ...        ...        ...        ...        ...       ...
# 2020-08-13  47.160000  47.230000  45.930000  46.139999  46.139999  41051700
# 2020-08-14  45.599998  46.080002  45.299999  45.599998  45.599998  18167300
# 2020-08-17  45.900002  45.939999  44.740002  45.220001  45.220001  17303800
# 2020-08-18  45.060001  45.160000  44.049999  44.400002  44.400002  20118100
# ...

# %%
MU.head()
# Out:
#             Open    High     Low   Close  Adj Close   Volume
# Date
# 1984-06-01   0.0  1.4250  1.4125  1.4125   1.385186  7340000
# 1984-06-04   0.0  1.4250  1.4125  1.4125   1.385186  4066800
# 1984-06-05   0.0  1.4125  1.4000  1.4000   1.372928  2088800
# 1984-06-06   0.0  1.5000  1.4750  1.4750   1.446478  1894000
# 1984-06-07   0.0  1.6500  1.6375  1.6375   1.605836  2078000

# %%
MU.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-08-13  47.160000  47.230000  45.930000  46.139999  46.139999  41051700
# 2020-08-14  45.599998  46.080002  45.299999  45.599998  45.599998  18167300
# 2020-08-17  45.900002  45.939999  44.740002  45.220001  45.220001  17303800
# 2020-08-18  45.060001  45.160000  44.049999  44.400002  44.400002  20118100
# 2020-08-19  44.299999  44.700001  43.849998  44.049999  44.049999  19437600

# %%
MU.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9130.000000  9130.000000  9130.000000  9130.000000  9130.000000
# mean     15.708235    16.253385    15.525120    15.880940    15.867949
# std      15.781765    15.942173    15.194925    15.562307    15.568095
# min       0.000000     0.375000     0.337500     0.350000     0.343232
# 25%       2.565625     3.037500     2.828750     2.965625     2.929798
# 50%      11.530625    11.720000    11.316250    11.510000    11.505000
# 75%      22.360001    22.812500    21.750000    22.309999    22.309999
# max      97.000000    97.500000    93.875000    96.562500    96.562500
#
#              Volume
# count  9.130000e+03
# mean   1.557391e+07
# std    1.477203e+07
# min    8.080000e+04
# 25%    5.132725e+06
# 50%    1.072905e+07
# 75%    2.247505e+07
# max    1.539061e+08

# %%
MU.info
# Out:
# <bound method DataFrame.info of                  Open       High        Low      Close  Adj Close    Volume
# Date
# 1984-06-01   0.000000   1.425000   1.412500   1.412500   1.385186   7340000
# 1984-06-04   0.000000   1.425000   1.412500   1.412500   1.385186   4066800
# 1984-06-05   0.000000   1.412500   1.400000   1.400000   1.372928   2088800
# 1984-06-06   0.000000   1.500000   1.475000   1.475000   1.446478   1894000
# 1984-06-07   0.000000   1.650000   1.637500   1.637500   1.605836   2078000
# ...               ...        ...        ...        ...        ...       ...
# 2020-08-13  47.160000  47.230000  45.930000  46.139999  46.139999  41051700
# 2020-08-14  45.599998  46.080002  45.299999  45.599998  45.599998  18167300
# 2020-08-17  45.900002  45.939999  44.740002  45.220001  45.220001  17303800
# 2020-08-18  45.060001  45.160000  44.049999  44.400002  44.400002  20118100
# 2020-08-19  44.299999  44.700001  43.849998  44.049999  44.049999  19437600
#
# ...

# %%
MU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9130 entries, 1984-06-01 to 2020-08-19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       9130 non-null   float64
#  1   High       9130 non-null   float64
#  2   Low        9130 non-null   float64
#  3   Close      9130 non-null   float64
#  4   Adj Close  9130 non-null   float64
#  5   Volume     9130 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 499.3 KB

# %%
import sqlite3

# %%
conn = sqlite3.connect("MU.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("MU.db")
c = conn.cursor()

# %%
MU.to_sql("MU", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2612: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM MU""")
rows = c.fetchall()
rows
# Out:
# [('1984-06-01 00:00:00',
#   0.0,
#   1.4249999523162842,
#   1.412500023841858,
#   1.412500023841858,
#   1.3851864337921143,
#   7340000),
#  ('1984-06-04 00:00:00',
#   0.0,
#   1.4249999523162842,
#   1.412500023841858,
#   1.412500023841858,
#   1.3851864337921143,
#   4066800),
#  ('1984-06-05 00:00:00',
#   0.0,
#   1.412500023841858,
#   1.399999976158142,
#   1.399999976158142,
#   1.372928261756897,
#   2088800),
#  ('1984-06-06 00:00:00',
#   0.0,
#   1.5,
#   1.475000023841858,
#   1.475000023841858,
#   1.446478009223938,
#   1894000),
#  ('1984-06-07 00:00:00',
#   0.0,
#   1.649999976158142,
#   1.6375000476837158,
#   1.6375000476837158,
#   1.6058357954025269,
#   2078000),
#  ('1984-06-08 00:00:00',
#   0.0,
#   1.7625000476837158,
#   1.7374999523162842,
#   1.7374999523162842,
#   1.7039021253585815,
#   2226800),
#  ('1984-06-11 00:00:00',
#   0.0,
#   1.649999976158142,
#   1.625,
#   1.625,
#   1.5935773849487305,
#   1218800),
#  ('1984-06-12 00:00:00',
# ...

# %%
MU.to_excel("MU.xls")

pd.read_excel("MU.xls")

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Micron Technology, Inc. (MU)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Micron Technology, Inc. (MU)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
