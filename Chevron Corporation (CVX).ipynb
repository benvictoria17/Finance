# %%
import pandas as pd 
import numpy as np 
import math 
import matplotlib.pyplot as plt
import sqlite3
import yfinance

# %%
CVX = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/CVX?period1=1562819066&period2=1594441466&interval=1d&events=history")


CVX
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-07-11  125.680000  125.680000  124.599998  125.430000  119.763748
# 1    2019-07-12  125.379997  126.250000  125.129997  125.980003  120.288902
# 2    2019-07-15  126.059998  126.400002  125.269997  125.720001  120.040642
# 3    2019-07-16  125.500000  125.779999  124.260002  124.760002  119.124008
# 4    2019-07-17  124.660004  125.279999  124.059998  124.139999  118.532021
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-07-06   89.500000   90.250000   87.820000   88.570000   88.570000
# 249  2020-07-07   87.820000   88.080002   86.150002   86.309998   86.309998
# 250  2020-07-08   86.389999   87.800003   85.889999   86.349998   86.349998
# 251  2020-07-09   85.970001   86.320000   82.690002   82.739998   82.739998
# 252  2020-07-10   82.500000   85.419998   82.500000   85.230003   85.230003
#
#       Volume
# 0    3548000
# 1    3974400
# ...

# %%
CVX.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-07-11  125.680000  125.680000  124.599998  125.430000  119.763748
# 1  2019-07-12  125.379997  126.250000  125.129997  125.980003  120.288902
# 2  2019-07-15  126.059998  126.400002  125.269997  125.720001  120.040642
# 3  2019-07-16  125.500000  125.779999  124.260002  124.760002  119.124008
# 4  2019-07-17  124.660004  125.279999  124.059998  124.139999  118.532021
#
#     Volume
# 0  3548000
# 1  3974400
# 2  3739200
# 3  4697600
# 4  3874200

# %%
CVX.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 248  2020-07-06  89.500000  90.250000  87.820000  88.570000  88.570000
# 249  2020-07-07  87.820000  88.080002  86.150002  86.309998  86.309998
# 250  2020-07-08  86.389999  87.800003  85.889999  86.349998  86.349998
# 251  2020-07-09  85.970001  86.320000  82.690002  82.739998  82.739998
# 252  2020-07-10  82.500000  85.419998  82.500000  85.230003  85.230003
#
#       Volume
# 248  6747500
# 249  5898000
# 250  6736400
# 251  8833600
# 252  6215900

# %%
CVX.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  253.000000  253.000000  253.000000  253.000000  253.000000
# mean   106.121818  107.331542  104.757787  105.990988  103.324543
# std     16.759377   16.116768   17.443021   16.790588   15.354390
# min     55.259998   58.490002   51.599998   54.220001   53.435528
# 25%     92.480003   93.459999   90.110001   91.589996   91.440002
# 50%    115.099998  115.150002  113.300003  114.589996  110.538185
# 75%    118.860001  119.629997  117.830002  118.629997  115.168465
# max    127.000000  127.000000  125.660004  126.540001  120.823608
#
#              Volume
# count  2.530000e+02
# mean   8.797747e+06
# std    5.469484e+06
# min    1.640100e+06
# 25%    5.051700e+06
# 50%    6.920000e+06
# 75%    1.048630e+07
# max    3.059550e+07

# %%
plt.plot([0,1,2,3,4,5])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.pie([0,1,2,4,5]) 
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pandas_datareader as pdr 
import datetime 
CVX = pdr.get_data_yahoo("CVX",
                          start=datetime.datetime(2006,10,1),
                          end=datetime.datetime(2012,1,1))

CVX.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-10-02  65.349998  64.459999  64.900002  64.510002   7955600.0  39.045601
# 2006-10-03  64.010002  62.919998  64.000000  62.939999  12808700.0  38.095333
# 2006-10-04  63.930000  62.220001  63.250000  63.700001  11281000.0  38.555336
# 2006-10-05  64.470001  63.419998  64.129997  63.880001   9577800.0  38.664276
# 2006-10-06  63.880001  62.799999  63.520000  63.660000   8886400.0  38.531136

# %%
# !pip install quandl

# %%
import quandl
quandl.ApiConfig.api_key = "uhWHfKsyu4vyg7ybfyyt"
CVX = quandl.get("WIKI/CVX",start_date="2006-10-01",end_date="2012-01-01")

CVX.head()
# Out:
#              Open   High    Low  Close      Volume  Ex-Dividend  Split Ratio  \
# Date
# 2006-10-02  64.90  65.35  64.46  64.51   7955600.0          0.0          1.0
# 2006-10-03  64.00  64.01  62.92  62.94  12808700.0          0.0          1.0
# 2006-10-04  63.25  63.93  62.22  63.70  11281000.0          0.0          1.0
# 2006-10-05  64.23  64.47  63.42  63.88   9577800.0          0.0          1.0
# 2006-10-06  63.52  63.88  62.80  63.66   8886400.0          0.0          1.0
#
#             Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# Date
# 2006-10-02  43.963904  44.268739  43.665844   43.699714    7955600.0
# 2006-10-03  43.354235  43.361009  42.622633   42.636181   12808700.0
# 2006-10-04  42.846178  43.306817  42.148446   43.151012   11281000.0
# 2006-10-05  43.510040  43.672618  42.961338   43.272946    9577800.0
# 2006-10-06  43.029079  43.272946  42.541343   43.123916    8886400.0

# %%
import sqlite3

# %%
conn = sqlite3.connect("CVX.db")
c = conn.cursor()

# %%
CVX.to_sql("CVX", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM CVX""")
rows = c.fetchall()
rows
# Out:
# [('2006-10-02 00:00:00',
#   64.9,
#   65.35,
#   64.46,
#   64.51,
#   7955600.0,
#   0.0,
#   1.0,
#   43.963904279124,
#   44.26873874639,
#   43.66584391113,
#   43.699714407493,
#   7955600.0),
#  ('2006-10-03 00:00:00',
#   64.0,
#   64.01,
#   62.92,
#   62.94,
#   12808700.0,
#   0.0,
#   1.0,
#   43.354235344591,
#   43.361009443863,
#   42.622632623151,
#   42.636180821696,
#   12808700.0),
#  ('2006-10-04 00:00:00',
#   63.25,
#   63.93,
#   62.22,
#   63.7,
#   11281000.0,
#   0.0,
#   1.0,
#   42.846177899146,
#   43.306816649682,
#   42.148445674069,
#   43.151012366413,
#   11281000.0),
#  ('2006-10-05 00:00:00',
#   64.23,
#   64.47,
#   63.42,
#   63.88,
#   9577800.0,
#   0.0,
#   1.0,
#   43.51003962786,
#   43.672618010402,
#   42.96133758678,
#   43.272946153319,
#   9577800.0),
#  ('2006-10-06 00:00:00',
#   63.52,
#   63.88,
#   62.8,
#   63.66,
#   8886400.0,
#   0.0,
#   1.0,
#   43.029078579506,
#   43.272946153319,
#   42.541343431879,
#   43.123915969322,
# ...

# %%
CVX.to_excel("CVX.xls")

pd.read_excel("CVX.xls")
# Out:
#            Date    Open     High     Low   Close    Volume  Ex-Dividend  \
# 0    2006-10-02   64.90   65.350   64.46   64.51   7955600          0.0
# 1    2006-10-03   64.00   64.010   62.92   62.94  12808700          0.0
# 2    2006-10-04   63.25   63.930   62.22   63.70  11281000          0.0
# 3    2006-10-05   64.23   64.470   63.42   63.88   9577800          0.0
# 4    2006-10-06   63.52   63.880   62.80   63.66   8886400          0.0
# ...         ...     ...      ...     ...     ...       ...          ...
# 1318 2011-12-23  106.63  107.610  106.10  107.50   3779400          0.0
# 1319 2011-12-27  107.26  108.490  107.26  107.98   4136200          0.0
# 1320 2011-12-28  107.86  108.160  105.88  105.96   5307900          0.0
# 1321 2011-12-29  106.38  107.560  106.32  107.47   4468500          0.0
# 1322 2011-12-30  106.79  107.505  106.18  106.40   5009400          0.0
#
#       Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Chevron Corporation (CVX)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('CVX')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
