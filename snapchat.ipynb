# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Snapchat = pd.read_csv("https://raw.githubusercontent.com/benvictoria21/python-panda/master/python%20pandas%20data/Snapchat%20.csv")

Snapchat
# Out:
#                            Category: All categories
# Region                Snapchat: (8/15/19 - 8/15/20)
# North Dakota                                    100
# Iowa                                             96
# South Dakota                                     94
# New Mexico                                       92
# Nebraska                                         89
# West Virginia                                    88
# Illinois                                         87
# Kansas                                           85
# Wisconsin                                        84
# Wyoming                                          83
# Oklahoma                                         83
# Kentucky                                         82
# Mississippi                                      82
# Missouri                                         81
# Minnesota                                        79
# Arkansas                                         79
# ...

# %%
Snapchat.head()
# Out:
#                    Category: All categories
# Region        Snapchat: (8/15/19 - 8/15/20)
# North Dakota                            100
# Iowa                                     96
# South Dakota                             94
# New Mexico                               92

# %%
Snapchat.tail()
# Out:
#                      Category: All categories
# Florida                                    58
# New York                                   57
# Maryland                                   55
# Hawaii                                     50
# District of Columbia                       29

# %%
Snapchat.describe()
# Out:
#        Category: All categories
# count                        52
# unique                       35
# top                          68
# freq                          4

# %%
import sqlite3

# %%
conn = sqlite3.connect("Snapchat.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("Snapchat.db")
c = conn.cursor()

# %%
Snapchat.to_sql("Snapchat", conn, if_exists='replace')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:2612: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM Snapchat""")
rows = c.fetchall()
rows
# Out:
# [('Region', 'Snapchat: (8/15/19 - 8/15/20)'),
#  ('North Dakota', '100'),
#  ('Iowa', '96'),
#  ('South Dakota', '94'),
#  ('New Mexico', '92'),
#  ('Nebraska', '89'),
#  ('West Virginia', '88'),
#  ('Illinois', '87'),
#  ('Kansas', '85'),
#  ('Wisconsin', '84'),
#  ('Wyoming', '83'),
#  ('Oklahoma', '83'),
#  ('Kentucky', '82'),
#  ('Mississippi', '82'),
#  ('Missouri', '81'),
#  ('Minnesota', '79'),
#  ('Arkansas', '79'),
#  ('Indiana', '78'),
#  ('Alabama', '78'),
#  ('Arizona', '77'),
#  ('Michigan', '77'),
#  ('Texas', '76'),
#  ('Louisiana', '75'),
#  ('Montana', '74'),
#  ('Ohio', '73'),
#  ('South Carolina', '73'),
#  ('Rhode Island', '73'),
#  ('Tennessee', '72'),
#  ('Pennsylvania', '70'),
#  ('Colorado', '69'),
#  ('North Carolina', '69'),
#  ('Idaho', '69'),
#  ('Georgia', '68'),
#  ('New Hampshire', '68'),
#  ('Alaska', '68'),
#  ('Utah', '68'),
#  ('Connecticut', '67'),
#  ('Vermont', '67'),
#  ('Massachusetts', '66'),
#  ('Maine', '64'),
#  ('California', '62'),
# ...

# %%
Snapchat.to_excel("Snapchat.xls")

pd.read_excel("Snapchat.xls")
# Out:
#               Unnamed: 0       Category: All categories
# 0                 Region  Snapchat: (8/15/19 - 8/15/20)
# 1           North Dakota                            100
# 2                   Iowa                             96
# 3           South Dakota                             94
# 4             New Mexico                             92
# 5               Nebraska                             89
# 6          West Virginia                             88
# 7               Illinois                             87
# 8                 Kansas                             85
# 9              Wisconsin                             84
# 10               Wyoming                             83
# 11              Oklahoma                             83
# 12              Kentucky                             82
# 13           Mississippi                             82
# 14              Missouri                             81
# 15             Minnesota                             79
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Snapchat', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Snapchat')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
