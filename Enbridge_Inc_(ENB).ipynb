# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock/blob/master/Enbridge_Inc_(ENB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import math 
import sqlite3
import yfinance

# %%
ENB = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ENB.TO?period1=1562699257&period2=1594321657&interval=1d&events=history")

ENB
# Out:
#            Date       Open       High        Low      Close  Adj Close   Volume
# 0    2019-07-09  47.099998  48.090000  47.020000  47.990002  45.029549  3264800
# 1    2019-07-10  48.099998  48.459999  47.970001  48.060001  45.095226  3775900
# 2    2019-07-11  48.080002  48.380001  47.910000  48.110001  45.142139  4016100
# 3    2019-07-12  48.189999  48.189999  47.459999  47.610001  44.672981  3096400
# 4    2019-07-15  47.610001  47.770000  47.169998  47.369999  44.447788  1557500
# ..          ...        ...        ...        ...        ...        ...      ...
# 248  2020-07-03  41.509998  41.650002  41.200001  41.650002  41.650002   621700
# 249  2020-07-06  42.130001  42.150002  40.950001  41.220001  41.220001  3829400
# 250  2020-07-07  40.950001  41.500000  40.639999  40.779999  40.779999  2850300
# 251  2020-07-08  40.790001  41.090000  40.360001  40.700001  40.700001  2040300
# 252  2020-07-09  40.700001  40.744999  40.000000  40.154999  40.154999  1840461
#
# ...

# %%
ENB.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close   Volume
# 248  2020-07-03  41.509998  41.650002  41.200001  41.650002  41.650002   621700
# 249  2020-07-06  42.130001  42.150002  40.950001  41.220001  41.220001  3829400
# 250  2020-07-07  40.950001  41.500000  40.639999  40.779999  40.779999  2850300
# 251  2020-07-08  40.790001  41.090000  40.360001  40.700001  40.700001  2040300
# 252  2020-07-09  40.700001  40.744999  40.000000  40.154999  40.154999  1840461

# %%
ENB.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  253.000000  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean    46.678972   47.154328   46.164190   46.656028   45.218256  5.780232e+06
# std      4.672720    4.476112    4.921324    4.760491    4.477033  3.733187e+06
# min     34.369999   36.880001   33.060001   34.090000   33.463005  6.217000e+05
# 25%     43.590000   44.099998   43.020000   43.540001   41.914349  3.349700e+06
# 50%     46.500000   46.750000   45.939999   46.349998   44.475136  4.779800e+06
# 75%     50.480000   50.730000   50.090000   50.549999   48.916740  7.323400e+06
# max     57.090000   57.320000   56.759998   57.130001   55.284138  2.823360e+07

# %%
ENB.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2019-07-09  47.099998  48.090000  47.020000  47.990002  45.029549  3264800
# 1  2019-07-10  48.099998  48.459999  47.970001  48.060001  45.095226  3775900
# 2  2019-07-11  48.080002  48.380001  47.910000  48.110001  45.142139  4016100
# 3  2019-07-12  48.189999  48.189999  47.459999  47.610001  44.672981  3096400
# 4  2019-07-15  47.610001  47.770000  47.169998  47.369999  44.447788  1557500

# %%
plt.plot([0,1,2,3,4,5])
plt.plot()
# Out:
# []

# %%
plt.pie([0,1,2,3,4,5])
plt.plot()
# Out:
# []

# %%
ENB.to_csv("ENB.csv")

pd.read_csv("ENB.csv")
# Out:
#      Unnamed: 0        Date       Open  ...      Close  Adj Close   Volume
# 0             0  2019-07-09  47.099998  ...  47.990002  45.029549  3264800
# 1             1  2019-07-10  48.099998  ...  48.060001  45.095226  3775900
# 2             2  2019-07-11  48.080002  ...  48.110001  45.142139  4016100
# 3             3  2019-07-12  48.189999  ...  47.610001  44.672981  3096400
# 4             4  2019-07-15  47.610001  ...  47.369999  44.447788  1557500
# ..          ...         ...        ...  ...        ...        ...      ...
# 248         248  2020-07-03  41.509998  ...  41.650002  41.650002   621700
# 249         249  2020-07-06  42.130001  ...  41.220001  41.220001  3829400
# 250         250  2020-07-07  40.950001  ...  40.779999  40.779999  2850300
# 251         251  2020-07-08  40.790001  ...  40.700001  40.700001  2040300
# 252         252  2020-07-09  40.700001  ...  40.154999  40.154999  1840461
#
# [253 rows x 8 columns]

# %%
ENB = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ENB.TO?period1=1562699257&period2=1594321657&interval=1d&events=history")

pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ENB.TO?period1=1562699257&period2=1594321657&interval=1d&events=history")
# Out:
#            Date       Open       High        Low      Close  Adj Close   Volume
# 0    2019-07-09  47.099998  48.090000  47.020000  47.990002  45.029549  3264800
# 1    2019-07-10  48.099998  48.459999  47.970001  48.060001  45.095226  3775900
# 2    2019-07-11  48.080002  48.380001  47.910000  48.110001  45.142139  4016100
# 3    2019-07-12  48.189999  48.189999  47.459999  47.610001  44.672981  3096400
# 4    2019-07-15  47.610001  47.770000  47.169998  47.369999  44.447788  1557500
# ..          ...        ...        ...        ...        ...        ...      ...
# 248  2020-07-03  41.509998  41.650002  41.200001  41.650002  41.650002   621700
# 249  2020-07-06  42.130001  42.150002  40.950001  41.220001  41.220001  3829400
# 250  2020-07-07  40.950001  41.500000  40.639999  40.779999  40.779999  2850300
# 251  2020-07-08  40.790001  41.090000  40.360001  40.700001  40.700001  2040300
# 252  2020-07-09  40.700001  40.744999  40.000000  40.154999  40.154999  1840461
#
# ...

# %%
ENB.to_excel("ENB.xls")

pd.read_excel("ENB.xls")
# Out:
#      Unnamed: 0        Date       Open  ...      Close  Adj Close   Volume
# 0             0  2019-07-09  47.099998  ...  47.990002  45.029549  3264800
# 1             1  2019-07-10  48.099998  ...  48.060001  45.095226  3775900
# 2             2  2019-07-11  48.080002  ...  48.110001  45.142139  4016100
# 3             3  2019-07-12  48.189999  ...  47.610001  44.672981  3096400
# 4             4  2019-07-15  47.610001  ...  47.369999  44.447788  1557500
# ..          ...         ...        ...  ...        ...        ...      ...
# 248         248  2020-07-03  41.509998  ...  41.650002  41.650002   621700
# 249         249  2020-07-06  42.130001  ...  41.220001  41.220001  3829400
# 250         250  2020-07-07  40.950001  ...  40.779999  40.779999  2850300
# 251         251  2020-07-08  40.790001  ...  40.700001  40.700001  2040300
# 252         252  2020-07-09  40.700001  ...  40.154999  40.154999  1840461
#
# [253 rows x 8 columns]

# %%
con = sqlite3.connect(" Enbridge Inc.db")
c = con.cursor()

ENB.to_sql("ENB", con, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
result = c.execute("""SELECT * FROM ENB""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   '2019-07-09',
#   47.099998,
#   48.09,
#   47.02,
#   47.990002000000004,
#   45.029548999999996,
#   3264800),
#  (1,
#   '2019-07-10',
#   48.099998,
#   48.459998999999996,
#   47.970001,
#   48.060001,
#   45.095226000000004,
#   3775900),
#  (2,
#   '2019-07-11',
#   48.080002,
#   48.380001,
#   47.91,
#   48.110001000000004,
#   45.142139,
#   4016100),
#  (3,
#   '2019-07-12',
#   48.189999,
#   48.189999,
#   47.459998999999996,
#   47.610001000000004,
#   44.672981,
#   3096400),
#  (4,
#   '2019-07-15',
#   47.610001000000004,
#   47.77,
#   47.169998,
#   47.369999,
#   44.447788,
#   1557500),
#  (5,
#   '2019-07-16',
#   47.200001,
#   47.259997999999996,
#   46.709998999999996,
#   47.0,
#   44.100613,
#   2059200),
#  (6,
#   '2019-07-17',
#   47.080002,
#   47.369999,
#   47.02,
#   47.119999,
#   44.213207000000004,
#   4317800),
#  (7,
#   '2019-07-18',
#   47.130001,
#   47.389998999999996,
#   46.93,
#   47.290001000000004,
#   44.372726,
#   3528300),
# ...
