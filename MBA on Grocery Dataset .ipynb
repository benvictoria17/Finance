# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/Finance/main/dataset/Groceries%20dataset%20for%20Market%20Basket%20Analysis(MBA)/Groceries%20data.csv")

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription  year  month  day  day_of_week
# 0           1808  2015-07-21    tropical fruit  2015      7   21            1
# 1           2552  2015-05-01        whole milk  2015      5    1            4
# 2           2300  2015-09-19         pip fruit  2015      9   19            5
# 3           1187  2015-12-12  other vegetables  2015     12   12            5
# 4           3037  2015-01-02        whole milk  2015      1    2            4

# %%
df['date'] = pd.to_datetime(df[['year', 'month', 'day']])
df.head()
# Out:
#    Member_number        Date   itemDescription  year  month  day  day_of_week  \
# 0           1808  2015-07-21    tropical fruit  2015      7   21            1
# 1           2552  2015-05-01        whole milk  2015      5    1            4
# 2           2300  2015-09-19         pip fruit  2015      9   19            5
# 3           1187  2015-12-12  other vegetables  2015     12   12            5
# 4           3037  2015-01-02        whole milk  2015      1    2            4
#
#         date
# 0 2015-07-21
# 1 2015-05-01
# 2 2015-09-19
# 3 2015-12-12
# 4 2015-01-02

# %%
df['member_date'] = list(zip(df['Member_number'], df['date'].dt.date))
df['quantity'] = 1

# %%
df.shape
# Out:
# (38765, 10)

# %%
df.groupby('itemDescription').size().sort_values(ascending=False)
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# preservation products       1
# kitchen utensil             1
# Length: 167, dtype: int64

# %%
basket = df.groupby(['member_date', 'itemDescription'])['quantity'].count().unstack().fillna(0)
def convert_values(value):
    if value >= 1:
        return 1
    else:
        return 0 
basket = basket.applymap(convert_values)

# %%
from mlxtend.frequent_patterns import apriori 
from mlxtend.frequent_patterns import association_rules
basket_items = apriori(basket, min_support = 0.005, use_colnames = True, max_len = 2)
rules = association_rules(basket_items, metric = 'lift')
# Out:
# /opt/conda/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:115: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,

# %%
rules.sort_values("confidence", ascending=False).head(15)
# Out:
#         antecedents         consequents  antecedent support  \
# 0    (bottled beer)        (whole milk)            0.045312
# 33        (sausage)        (whole milk)            0.060349
# 12     (newspapers)        (whole milk)            0.038896
# 6   (domestic eggs)        (whole milk)            0.037091
# 10    (frankfurter)        (whole milk)            0.037760
# 8     (frankfurter)  (other vegetables)            0.037760
# 20           (pork)        (whole milk)            0.037091
# 18      (pip fruit)        (whole milk)            0.049054
# 4    (citrus fruit)        (whole milk)            0.053131
# 36  (shopping bags)        (whole milk)            0.047584
# 42         (yogurt)        (whole milk)            0.085879
# 2     (canned beer)        (whole milk)            0.046916
# 26     (rolls/buns)        (whole milk)            0.110005
# 16           (soda)  (other vegetables)            0.097106
# 15        (sausage)  (other vegetables)            0.060349
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.157923  0.007151    0.157817  0.999330 -0.000005    0.999874
# 33            0.157923  0.008955    0.148394  0.939663 -0.000575    0.988811
# 12            0.157923  0.005614    0.144330  0.913926 -0.000529    0.984114
# 6             0.157923  0.005280    0.142342  0.901341 -0.000578    0.981834
# 10            0.157923  0.005280    0.139823  0.885388 -0.000683    0.978958
# 8             0.122101  0.005146    0.136283  1.116150  0.000536    1.016420
# 20            0.157923  0.005012    0.135135  0.855703 -0.000845    0.973652
# 18            0.157923  0.006616    0.134877  0.854071 -0.001130    0.973362
# 4             0.157923  0.007151    0.134591  0.852259 -0.001240    0.973040
# 36            0.157923  0.006349    0.133427  0.844887 -0.001166    0.971732
# 42            0.157923  0.011161    0.129961  0.822940 -0.002401    0.967861
# 2             0.157923  0.006015    0.128205  0.811821 -0.001394    0.965912
# 26            0.157923  0.013968    0.126974  0.804028 -0.003404    0.964550
# 16            0.122101  0.009691    0.099794  0.817302 -0.002166    0.975219
# 15            0.122101  0.006015    0.099668  0.816272 -0.001354    0.975083
