# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
AMD = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/AMD?period1=1565630394&period2=1597252794&interval=1d&events=history")

AMD
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2019-08-12  34.160000  34.650002  32.080002  32.430000  32.430000
# 1    2019-08-13  32.360001  33.139999  31.719999  32.110001  32.110001
# 2    2019-08-14  31.000000  31.049999  29.510000  30.240000  30.240000
# 3    2019-08-15  30.629999  30.730000  29.209999  29.670000  29.670000
# 4    2019-08-16  30.309999  31.480000  30.209999  31.180000  31.180000
# ..          ...        ...        ...        ...        ...        ...
# 249  2020-08-06  85.489998  86.980003  84.779999  86.709999  86.709999
# 250  2020-08-07  86.669998  87.290001  82.669998  84.849998  84.849998
# 251  2020-08-10  85.050003  85.160004  79.320000  82.239998  82.239998
# 252  2020-08-11  80.709999  80.709999  76.099998  76.879997  76.879997
# 253  2020-08-12  78.430000  82.430000  77.559998  82.275002  82.275002
#
#         Volume
# 0    106737000
# 1    102009700
# 2    127521500
# 3     71674400
# 4     70469800
# ..         ...
# ...

# %%
AMD.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-08-12  34.160000  34.650002  32.080002  32.430000  32.430000
# 1  2019-08-13  32.360001  33.139999  31.719999  32.110001  32.110001
# 2  2019-08-14  31.000000  31.049999  29.510000  30.240000  30.240000
# 3  2019-08-15  30.629999  30.730000  29.209999  29.670000  29.670000
# 4  2019-08-16  30.309999  31.480000  30.209999  31.180000  31.180000
#
#       Volume
# 0  106737000
# 1  102009700
# 2  127521500
# 3   71674400
# 4   70469800

# %%
AMD.tail()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 249  2020-08-06  85.489998  86.980003  84.779999  86.709999  86.709999
# 250  2020-08-07  86.669998  87.290001  82.669998  84.849998  84.849998
# 251  2020-08-10  85.050003  85.160004  79.320000  82.239998  82.239998
# 252  2020-08-11  80.709999  80.709999  76.099998  76.879997  76.879997
# 253  2020-08-12  78.430000  82.430000  77.559998  82.275002  82.275002
#
#        Volume
# 249  53961700
# 250  66498000
# 251  70536100
# 252  77762500
# 253  59078564

# %%
AMD.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  254.000000  254.000000  254.000000  254.000000  254.000000
# mean    46.139803   47.125158   45.158898   46.214941   46.214941
# std     12.090929   12.433159   11.728844   12.180260   12.180260
# min     28.280001   28.639999   27.430000   28.230000   28.230000
# 25%     36.452500   37.025002   36.007500   36.295001   36.295001
# 50%     47.844999   48.695002   46.645000   47.565000   47.565000
# 75%     53.402500   54.737502   52.330002   53.530001   53.530001
# max     86.669998   87.290001   84.779999   86.709999   86.709999
#
#              Volume
# count  2.540000e+02
# mean   6.346635e+07
# std    2.551385e+07
# min    1.760990e+07
# 25%    4.453148e+07
# 50%    5.724735e+07
# 75%    7.871158e+07
# max    2.053145e+08

# %%
import sqlite3

# %%
conn = sqlite3.connect("AMD.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("AMD.db")
c = conn.cursor()

# %%
AMD.to_sql("AMD", conn, if_exists='replace')

# %%
#See data
c.execute("""SELECT * FROM AMD""")
rows = c.fetchall()
rows
# Out:
# [(0, '2019-08-12', 34.16, 34.650002, 32.080002, 32.43, 32.43, 106737000),
#  (1,
#   '2019-08-13',
#   32.360001000000004,
#   33.139998999999996,
#   31.719998999999998,
#   32.110001000000004,
#   32.110001000000004,
#   102009700),
#  (2, '2019-08-14', 31.0, 31.049999, 29.51, 30.24, 30.24, 127521500),
#  (3,
#   '2019-08-15',
#   30.629998999999998,
#   30.73,
#   29.209999,
#   29.67,
#   29.67,
#   71674400),
#  (4,
#   '2019-08-16',
#   30.309998999999998,
#   31.48,
#   30.209999,
#   31.18,
#   31.18,
#   70469800),
#  (5, '2019-08-19', 32.0, 32.189999, 31.42, 31.48, 31.48, 67596900),
#  (6,
#   '2019-08-20',
#   30.940001000000002,
#   31.309998999999998,
#   30.450001,
#   30.719998999999998,
#   30.719998999999998,
#   47924000),
#  (7, '2019-08-21', 31.049999, 31.74, 30.84, 31.700001, 31.700001, 41441500),
#  (8, '2019-08-22', 31.76, 31.92, 30.98, 31.9, 31.9, 47667900),
#  (9, '2019-08-23', 31.299999, 31.83, 29.4, 29.540001, 29.540001, 83681100),
#  (10,
# ...

# %%
T.to_excel("T.xls")

pd.read_excel("T.xls")
