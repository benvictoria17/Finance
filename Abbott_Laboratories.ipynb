# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/AnalyzeStocks/blob/master/Abbott_Laboratories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=f8c5a75911f6d3ee4478f3368ace151202ed913a9124814d3fefa5b25af28ecf
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas_datareader
import sqlite3
import yfinance
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
ABT = "ABT"

# %%
ABT = yfinance.download(ABT)

ABT
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close   Volume
# Date
# 1980-03-17    0.000000    0.512028    0.497999    0.501506    0.009776  7513300
# 1980-03-18    0.000000    0.512028    0.494492    0.505013    0.009845  5303400
# 1980-03-19    0.000000    0.515535    0.503260    0.512028    0.009981  2523300
# 1980-03-20    0.000000    0.513781    0.499753    0.499753    0.009742  4654800
# 1980-03-21    0.000000    0.506767    0.499753    0.505013    0.009845  1332800
# ...                ...         ...         ...         ...         ...      ...
# 2020-09-21  105.800003  106.459999  104.459999  105.949997  105.949997  4559800
# 2020-09-22  105.459999  105.519997  103.570000  104.800003  104.800003  4180300
# 2020-09-23  104.989998  104.989998  102.230003  102.730003  102.730003  4040100
# 2020-09-24  102.750000  103.529999  100.470001  100.919998  100.919998  7604000
# ...

# %%
ABT.head()
# Out:
#             Open      High       Low     Close  Adj Close   Volume
# Date
# 1980-03-17   0.0  0.512028  0.497999  0.501506   0.009776  7513300
# 1980-03-18   0.0  0.512028  0.494492  0.505013   0.009845  5303400
# 1980-03-19   0.0  0.515535  0.503260  0.512028   0.009981  2523300
# 1980-03-20   0.0  0.513781  0.499753  0.499753   0.009742  4654800
# 1980-03-21   0.0  0.506767  0.499753  0.505013   0.009845  1332800

# %%
ABT.tail()
# Out:
#                   Open        High         Low       Close   Adj Close   Volume
# Date
# 2020-09-21  105.800003  106.459999  104.459999  105.949997  105.949997  4559800
# 2020-09-22  105.459999  105.519997  103.570000  104.800003  104.800003  4180300
# 2020-09-23  104.989998  104.989998  102.230003  102.730003  102.730003  4040100
# 2020-09-24  102.750000  103.529999  100.470001  100.919998  100.919998  7604000
# 2020-09-25  100.559998  103.610001  100.339996  103.449997  103.449997  5059000

# %%
ABT.describe()
# Out:
#                Open          High  ...     Adj Close        Volume
# count  10221.000000  10221.000000  ...  10221.000000  1.022100e+04
# mean      20.638279     20.904437  ...     15.149927  8.257919e+06
# std       20.506325     20.632358  ...     20.809472  5.616892e+06
# min        0.000000      0.490985  ...      0.009503  3.522000e+05
# 25%        3.885798      3.906841  ...      0.592255  4.711800e+06
# 50%       18.678766     18.909950  ...      8.236805  6.650000e+06
# 75%       26.024351     26.235464  ...     17.807148  9.981600e+06
# max      113.540001    114.199997  ...    111.290001  7.810830e+07
#
# [8 rows x 6 columns]

# %%
ABT.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close   Volume
# Date
# 1980-03-17    0.000000    0.512028    0.497999    0.501506    0.009776  7513300
# 1980-03-18    0.000000    0.512028    0.494492    0.505013    0.009845  5303400
# 1980-03-19    0.000000    0.515535    0.503260    0.512028    0.009981  2523300
# 1980-03-20    0.000000    0.513781    0.499753    0.499753    0.009742  4654800
# 1980-03-21    0.000000    0.506767    0.499753    0.505013    0.009845  1332800
# ...                ...         ...         ...         ...         ...      ...
# 2020-09-21  105.800003  106.459999  104.459999  105.949997  105.949997  4559800
# 2020-09-22  105.459999  105.519997  103.570000  104.800003  104.800003  4180300
# 2020-09-23  104.989998  104.989998  102.230003  102.730003  102.730003  4040100
# 2020-09-24  102.750000  103.529999  100.470001  100.919998  100.919998  7604000
# ...

# %%
ABT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10221 entries, 1980-03-17 to 2020-09-25
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10221 non-null  float64
#  1   High       10221 non-null  float64
#  2   Low        10221 non-null  float64
#  3   Close      10221 non-null  float64
#  4   Adj Close  10221 non-null  float64
#  5   Volume     10221 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 559.0 KB

# %%
conn = sqlite3.connect("ABT.db")
c = conn.cursor()

# %%
conn = sqlite3.connect("ABT.db")
c = conn.cursor()

# %%
ABT.to_sql("ABT", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM ABT""")
rows = c.fetchall()
rows
# Out:
# [('1980-03-17 00:00:00',
#   0.0,
#   0.5120275616645813,
#   0.4979993999004364,
#   0.5015064477920532,
#   0.009776325896382332,
#   7513300),
#  ('1980-03-18 00:00:00',
#   0.0,
#   0.5120275616645813,
#   0.49449238181114197,
#   0.5050134658813477,
#   0.00984469149261713,
#   5303400),
#  ('1980-03-19 00:00:00',
#   0.0,
#   0.5155345797538757,
#   0.5032599568367004,
#   0.5120275616645813,
#   0.009981430135667324,
#   2523300),
#  ('1980-03-20 00:00:00',
#   0.0,
#   0.5137810707092285,
#   0.499752938747406,
#   0.499752938747406,
#   0.009742138907313347,
#   4654800),
#  ('1980-03-21 00:00:00',
#   0.0,
#   0.5067670345306396,
#   0.499752938747406,
#   0.5050134658813477,
#   0.00984469149261713,
#   1332800),
#  ('1980-03-24 00:00:00',
#   0.0,
#   0.49449238181114197,
#   0.4839712679386139,
#   0.48923182487487793,
#   0.009537046775221825,
#   4105800),
#  ('1980-03-25 00:00:00',
#   0.0,
#   0.499752938747406,
#   0.4839712679386139,
#   0.4874782860279083,
# ...

# %%
ABT.to_excel("ABT.xls")

pd.read_excel("ABT.xls")
# Out:
#             Date        Open        High  ...       Close   Adj Close   Volume
# 0     1980-03-17    0.000000    0.512028  ...    0.501506    0.009776  7513300
# 1     1980-03-18    0.000000    0.512028  ...    0.505013    0.009845  5303400
# 2     1980-03-19    0.000000    0.515535  ...    0.512028    0.009981  2523300
# 3     1980-03-20    0.000000    0.513781  ...    0.499753    0.009742  4654800
# 4     1980-03-21    0.000000    0.506767  ...    0.505013    0.009845  1332800
# ...          ...         ...         ...  ...         ...         ...      ...
# 10216 2020-09-21  105.800003  106.459999  ...  105.949997  105.949997  4559800
# 10217 2020-09-22  105.459999  105.519997  ...  104.800003  104.800003  4180300
# 10218 2020-09-23  104.989998  104.989998  ...  102.730003  102.730003  4040100
# 10219 2020-09-24  102.750000  103.529999  ...  100.919998  100.919998  7604000
# 10220 2020-09-25  100.559998  103.610001  ...  103.449997  103.449997  5059000
#
# ...

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Abbott Laboratories', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Abbott Laboratories')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
