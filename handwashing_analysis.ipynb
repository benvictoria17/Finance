# %%
import numpy as np
import pandas as pd

# %%
yearly = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Dr.%20Semmelweis%20Handwashing%20Survey%20Data/yearly_deaths_by_clinic.csv")
print(yearly)

# %%
yearly['proportion_deaths'] = yearly['deaths'] /  yearly['births']
print(yearly)

clinic_1 = yearly[yearly['clinic'] == 'clinic 1']
clinic_2 = yearly[yearly['clinic'] == 'clinic 2']

clinic_1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ax = clinic_1.plot(x='year',y='proportion_deaths',label='Clinic 1')
clinic_2.plot(x='year',y='proportion_deaths', label='Clinic 2', ax=ax)
plt.ylabel('Proportion deaths')

# %%
monthly = pd.read_csv('https://raw.githubusercontent.com/benvictoria17/DataVisualization/master/dataset/Dr.%20Semmelweis%20Handwashing%20Survey%20Data/monthly_deaths.csv', 
    parse_dates=["date"])
monthly['proportion_deaths']= monthly.deaths / monthly.births
monthly.head()

# %%
ax = monthly.plot(x='date',y='proportion_deaths')
plt.ylabel('Proportion deaths')

# %%
handwashing_start = pd.to_datetime('1847-06-01')

before_washing = monthly[monthly['date']< handwashing_start]
after_washing = monthly[monthly['date']>= handwashing_start]

ax= before_washing.plot(x = 'date', y= 'proportion_deaths', label = 'before')
after_washing.plot(x= 'date', y='proportion_deaths',label= 'after',  ax =ax) 
plt.ylabel('Proportion deaths')

# %%
before_proportion = before_washing['proportion_deaths']
after_proportion = after_washing['proportion_deaths']

mean_diff = after_proportion.mean()  -before_proportion.mean()
mean_diff

# %%
boot_mean_diff = []
for i in range(3000):
    boot_before = before_proportion.sample(frac=1, replace=True)
    boot_after = after_proportion.sample(frac=1, replace=True)
    boot_mean_diff.append( boot_before.mean() - boot_after.mean() )

confidence_interval = pd.Series(boot_mean_diff).quantile([.025, .975])
confidence_interval

# %%
doctors_should_wash_their_hands = True
