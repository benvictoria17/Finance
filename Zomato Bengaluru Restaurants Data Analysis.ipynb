# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/DataAnalytics/master/dataset/Zomato%20Bangalore%20Restaurants%202022/BangaloreZomatoData.csv")
df.head()
# Out:
#                    Name                                                URL  \
# 0        Sri Udupi Park  https://www.zomato.com/bangalore/sri-udupi-par...
# 1         Meghana Foods  https://www.zomato.com/bangalore/meghana-foods...
# 2  Donne Biriyani House  https://www.zomato.com/bangalore/donne-biriyan...
# 3        Domino's Pizza  https://www.zomato.com/bangalore/dominos-pizza...
# 4                   KFC   https://www.zomato.com/bangalore/kfc-indiranagar
#
#                                             Cuisines                    Area  \
# 0  South Indian, North Indian, Chinese, Street Fo...  Indiranagar, Bangalore
# 1             Biryani, Andhra, North Indian, Seafood  Indiranagar, Bangalore
# 2                                            Biryani  Indiranagar, Bangalore
# 3                         Pizza, Fast Food, Desserts  Indiranagar, Bangalore
# 4    Burger, Fast Food, Biryani, Desserts, Beverages  Indiranagar, Bangalore
#
#                          Timing  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8923 entries, 0 to 8922
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              8923 non-null   object
#  1   URL               8923 non-null   object
#  2   Cuisines          8923 non-null   object
#  3   Area              8923 non-null   object
#  4   Timing            5820 non-null   object
#  5   Full_Address      8923 non-null   object
#  6   PhoneNumber       8923 non-null   object
#  7   IsHomeDelivery    8923 non-null   int64
#  8   isTakeaway        8923 non-null   int64
#  9   isIndoorSeating   8923 non-null   int64
#  10  isVegOnly         8923 non-null   int64
#  11  Dinner Ratings    8923 non-null   object
#  12  Dinner Reviews    8923 non-null   int64
#  13  Delivery Ratings  8923 non-null   object
#  14  Delivery Reviews  8923 non-null   int64
#  15  KnownFor          258 non-null    object
# ...

# %%
df.describe()
# Out:
#        IsHomeDelivery   isTakeaway  isIndoorSeating    isVegOnly  \
# count     8923.000000  8923.000000      8923.000000  8923.000000
# mean         0.997871     0.660092         0.442676     0.072285
# std          0.046098     0.473704         0.496731     0.258974
# min          0.000000     0.000000         0.000000     0.000000
# 25%          1.000000     0.000000         0.000000     0.000000
# 50%          1.000000     1.000000         0.000000     0.000000
# 75%          1.000000     1.000000         1.000000     0.000000
# max          1.000000     1.000000         1.000000     1.000000
#
#        Dinner Reviews  Delivery Reviews  AverageCost
# count     8923.000000       8923.000000  8923.000000
# mean       157.106018       2014.709403   340.225261
# std        731.834227       5524.430542   308.338943
# min          0.000000          0.000000    50.000000
# 25%          0.000000         42.000000   150.000000
# 50%          0.000000        279.000000   250.000000
# ...

# %%
df.corr()
# Out:
#                   IsHomeDelivery  isTakeaway  isIndoorSeating  isVegOnly  \
# IsHomeDelivery          1.000000    0.064373         0.041169   0.012894
# isTakeaway              0.064373    1.000000         0.581904   0.128129
# isIndoorSeating         0.041169    0.581904         1.000000   0.109324
# isVegOnly               0.012894    0.128129         0.109324   1.000000
# Dinner Reviews          0.009764    0.126117         0.227500   0.007035
# Delivery Reviews        0.015824    0.136623         0.166983   0.049004
# AverageCost            -0.001464    0.257453         0.516492  -0.015293
#
#                   Dinner Reviews  Delivery Reviews  AverageCost
# IsHomeDelivery          0.009764          0.015824    -0.001464
# isTakeaway              0.126117          0.136623     0.257453
# isIndoorSeating         0.227500          0.166983     0.516492
# isVegOnly               0.007035          0.049004    -0.015293
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator, ImageColorGenerator
# %matplotlib inline
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (15, 10)
df.drop(['URL', 'Full_Address','PhoneNumber'], axis= 1, inplace=True)
df
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                Cuisines  \
# 0     South Indian, North Indian, Chinese, Street Fo...
# 1                Biryani, Andhra, North Indian, Seafood
# 2                                               Biryani
# 3                            Pizza, Fast Food, Desserts
# 4       Burger, Fast Food, Biryani, Desserts, Beverages
# ...                                                 ...
# 8918                                          Fast Food
# 8919                    Seafood, Mangalorean, Beverages
# 8920                                     Salad, Chinese
# ...

# %%
plt.title("Average Cost while ordering food online from Zomato in Bengaluru")
plt.xlabel('Average Cost')
sns.histplot(x= df['AverageCost']);

# %%
df1 = df.copy().sort_values(by='AverageCost',ascending= False).drop_duplicates('Name').head(10)
df1
# Out:
#                                                    Name  \
# 7868                          B Café - Shangri-La Hotel
# 8011                Edo Restaurant & Bar - ITC Gardenia
# 7876                   24/7 - The Lalit Ashok Bangalore
# 4544  Ministry of Food - Hilton Bangalore Embassy Go...
# 2721                                              Shiro
# 5520  Feast - Sheraton Grand Bangalore Hotel at Brig...
# 4796                    Shang Palace - Shangri-La Hotel
# 1815                                Shao - Radisson Blu
# 4545           Asia Alive - DoubleTree Suites By Hilton
# 1871                             Melange - Radisson Blu
#
#                                                Cuisines  \
# 7868  North Indian, Italian, Chinese, Japanese, Beve...
# 8011                                    Japanese, Sushi
# 7876       Continental, North Indian, Chinese, Desserts
# 4544  North Indian, Asian, Continental, Italian, Mug...
# 2721                              Japanese, Asian, Thai
# ...

# %%
plt.xticks(rotation=45)
sns.barplot(x=df1['Name'] , y= df1['AverageCost']);

# %%
df2 = df.copy().sort_values(by='Dinner Ratings',ascending= False).drop_duplicates('Name').head(10)
df2[['Name','Area','AverageCost','Delivery Ratings','Dinner Ratings', 'isVegOnly',]]
# Out:
#                          Name                              Area  AverageCost  \
# 3530     Brahmin's Coffee Bar           Basavanagudi, Bangalore          100
# 1062     Windmills Craftworks   Windmills Craftworks, Bangalore         2500
# 231          Milano Ice Cream            Indiranagar, Bangalore          400
# 22                Burma Burma            Indiranagar, Bangalore         1500
# 5529           CTR Shri Sagar           Malleshwaram, Bangalore          150
# 47    Corner House Ice Creams            Indiranagar, Bangalore          300
# 2222        Natural Ice Cream  Koramangala 1st Block, Bangalore          300
# 6096                  Chianti            Indiranagar, Bangalore         2000
# 1196                  Bologna            Indiranagar, Bangalore         1600
# 4770                Brik Oven          Church Street, Bangalore         1000
#
#      Delivery Ratings Dinner Ratings  isVegOnly
# 3530              4.5            4.9          1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8923 entries, 0 to 8922
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              8923 non-null   object
#  1   Cuisines          8923 non-null   object
#  2   Area              8923 non-null   object
#  3   Timing            5820 non-null   object
#  4   IsHomeDelivery    8923 non-null   int64
#  5   isTakeaway        8923 non-null   int64
#  6   isIndoorSeating   8923 non-null   int64
#  7   isVegOnly         8923 non-null   int64
#  8   Dinner Ratings    8923 non-null   object
#  9   Dinner Reviews    8923 non-null   int64
#  10  Delivery Ratings  8923 non-null   object
#  11  Delivery Reviews  8923 non-null   int64
#  12  KnownFor          258 non-null    object
#  13  PopularDishes     1535 non-null   object
#  14  PeopleKnownFor    3484 non-null   object
#  15  AverageCost       8923 non-null   int64
# dtypes: int64(7), object(9)
# ...

# %%
df['Dinner Ratings'] = df['Dinner Ratings'].str.replace('-', '0').astype(np.float64)
df['Delivery Ratings'] = df['Delivery Ratings'].str.replace('-', '0').astype(np.float64)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8923 entries, 0 to 8922
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              8923 non-null   object
#  1   Cuisines          8923 non-null   object
#  2   Area              8923 non-null   object
#  3   Timing            5820 non-null   object
#  4   IsHomeDelivery    8923 non-null   int64
#  5   isTakeaway        8923 non-null   int64
#  6   isIndoorSeating   8923 non-null   int64
#  7   isVegOnly         8923 non-null   int64
#  8   Dinner Ratings    8923 non-null   float64
#  9   Dinner Reviews    8923 non-null   int64
#  10  Delivery Ratings  8923 non-null   float64
#  11  Delivery Reviews  8923 non-null   int64
#  12  KnownFor          258 non-null    object
#  13  PopularDishes     1535 non-null   object
#  14  PeopleKnownFor    3484 non-null   object
#  15  AverageCost       8923 non-null   int64
# ...

# %%
df
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                Cuisines  \
# 0     South Indian, North Indian, Chinese, Street Fo...
# 1                Biryani, Andhra, North Indian, Seafood
# 2                                               Biryani
# 3                            Pizza, Fast Food, Desserts
# 4       Burger, Fast Food, Biryani, Desserts, Beverages
# ...                                                 ...
# 8918                                          Fast Food
# 8919                    Seafood, Mangalorean, Beverages
# 8920                                     Salad, Chinese
# ...

# %%
New_df = df.copy()
New_df.drop(['Cuisines', 'PopularDishes','PeopleKnownFor', 'KnownFor'], axis= 1, inplace=True)
New_df
# Out:
#                        Name                            Area  \
# 0            Sri Udupi Park          Indiranagar, Bangalore
# 1             Meghana Foods          Indiranagar, Bangalore
# 2      Donne Biriyani House          Indiranagar, Bangalore
# 3            Domino's Pizza          Indiranagar, Bangalore
# 4                       KFC          Indiranagar, Bangalore
# ...                     ...                             ...
# 8918    New SBFC Food Funda          Frazer Town, Bangalore
# 8919      Kudla - Coraltree  Coraltree, RT Nagar, Bangalore
# 8920           Bangkok Bowl         Kammanahalli, Bangalore
# 8921        Yuan Restaurant           HBR Layout, Bangalore
# 8922  Amma's Biryani & Rice         Kammanahalli, Bangalore
#
#                                    Timing  IsHomeDelivery  isTakeaway  \
# 0                      7am – 11pm (Today)               1           1
# 1                         Opens at 6:30pm               1           1
# ...

# %%
sns.countplot(data= df, x=df.IsHomeDelivery);

# %%
sns.countplot(data= df, x=df.isTakeaway);

# %%
df
# Out:
#                        Name  \
# 0            Sri Udupi Park
# 1             Meghana Foods
# 2      Donne Biriyani House
# 3            Domino's Pizza
# 4                       KFC
# ...                     ...
# 8918    New SBFC Food Funda
# 8919      Kudla - Coraltree
# 8920           Bangkok Bowl
# 8921        Yuan Restaurant
# 8922  Amma's Biryani & Rice
#
#                                                Cuisines  \
# 0     South Indian, North Indian, Chinese, Street Fo...
# 1                Biryani, Andhra, North Indian, Seafood
# 2                                               Biryani
# 3                            Pizza, Fast Food, Desserts
# 4       Burger, Fast Food, Biryani, Desserts, Beverages
# ...                                                 ...
# 8918                                          Fast Food
# 8919                    Seafood, Mangalorean, Beverages
# 8920                                     Salad, Chinese
# ...

# %%
df[['Name','Area']].groupby(by='Area').sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df[['Area','Cuisines']].groupby(by='Area').sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
Ratings = df[['Cuisines', 'Delivery Ratings']].copy().sort_values(by='Delivery Ratings',ascending= False).head(10)
plt.figure(figsize=(15,10))
sns.histplot(x=df['Delivery Ratings'])
plt.title("Ratings Of Various Cuisines")
plt.xlabel('Delivery Ratings');

# %%
df.Cuisines.value_counts()
# Out:
# South Indian                                                                           309
# North Indian                                                                           205
# Bakery, Desserts                                                                       196
# North Indian, Chinese                                                                  138
# Chinese                                                                                115
#                                                                                       ...
# Chinese, North Indian, Fast Food, Mughlai, Beverages, Kebab, Shake                       1
# Street Food, North Indian, South Indian, Ice Cream, Beverages, Chinese                   1
# Mangalorean, Seafood, North Indian, Chinese, Mughlai, Street Food, Beverages, Shake      1
# North Indian, Chinese, Fast Food, Rolls, Sandwich, Shake, Beverages                      1
# ...

# %%
plt.title("Ratings Of Various Cuisines")
sns.barplot(data=Ratings.head(20), x='Delivery Ratings', y='Cuisines');

# %%
Ratings.groupby(by='Cuisines').mean().sort_values(by='Delivery Ratings', ascending=False).head(20)
# Out:
#                                         Delivery Ratings
# Cuisines
# Ice Cream, Desserts                                  4.7
# Bakery, Fast Food, Desserts, Beverages               4.6
# Desserts                                             4.6
# Ice Cream                                            4.6
# Ice Cream, Beverages                                 4.6
# Paan                                                 4.6
# South Indian                                         4.6
