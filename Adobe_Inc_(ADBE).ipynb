# %% [markdown]
# <a href="https://colab.research.google.com/github/benvictoria21/python-stock-/blob/master/Adobe_Inc_(ADBE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ADBE = pd.read_csv("https://query1.finance.yahoo.com/v7/finance/download/ADBE?period1=1565653129&period2=1597275529&interval=1d&events=history")

ADBE
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 0    2019-08-12  293.140015  294.420013  ...  288.649994  288.649994  1580500
# 1    2019-08-13  288.230011  295.500000  ...  293.170013  293.170013  2326400
# 2    2019-08-14  287.600006  289.649994  ...  283.660004  283.660004  2586000
# 3    2019-08-15  285.640015  286.489990  ...  282.709991  282.709991  2336800
# 4    2019-08-16  285.579987  290.149994  ...  287.450012  287.450012  1954500
# ..          ...         ...         ...  ...         ...         ...      ...
# 249  2020-08-06  451.350006  464.369995  ...  464.109985  464.109985  2362000
# 250  2020-08-07  460.869995  461.790009  ...  449.570007  449.570007  3288300
# 251  2020-08-10  450.369995  451.130005  ...  443.290009  443.290009  1836800
# 252  2020-08-11  440.260010  444.480011  ...  435.230011  435.230011  1899400
# 253  2020-08-12  437.369995  447.904999  ...  445.359985  445.359985  1916808
#
# [254 rows x 7 columns]

# %%
ADBE.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2019-08-12  293.140015  294.420013  ...  288.649994  288.649994  1580500
# 1  2019-08-13  288.230011  295.500000  ...  293.170013  293.170013  2326400
# 2  2019-08-14  287.600006  289.649994  ...  283.660004  283.660004  2586000
# 3  2019-08-15  285.640015  286.489990  ...  282.709991  282.709991  2336800
# 4  2019-08-16  285.579987  290.149994  ...  287.450012  287.450012  1954500
#
# [5 rows x 7 columns]

# %%
ADBE.tail()
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 249  2020-08-06  451.350006  464.369995  ...  464.109985  464.109985  2362000
# 250  2020-08-07  460.869995  461.790009  ...  449.570007  449.570007  3288300
# 251  2020-08-10  450.369995  451.130005  ...  443.290009  443.290009  1836800
# 252  2020-08-11  440.260010  444.480011  ...  435.230011  435.230011  1899400
# 253  2020-08-12  437.369995  447.904999  ...  445.359985  445.359985  1916808
#
# [5 rows x 7 columns]

# %%
ADBE.describe()
# Out:
#              Open        High         Low       Close   Adj Close        Volume
# count  254.000000  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   340.565590  345.061240  335.691299  340.940985  340.940985  2.966367e+06
# std     55.703002   56.297023   55.022521   55.788074   55.788074  1.408131e+06
# min    261.000000  265.519989  255.130005  261.089996  261.089996  1.055100e+06
# 25%    290.892510  293.815010  286.515007  290.959992  290.959992  2.034400e+06
# 50%    330.175003  335.395005  328.684998  333.420013  333.420013  2.578500e+06
# 75%    373.187492  377.282493  368.855011  374.702499  374.702499  3.512125e+06
# max    469.769989  470.609985  455.480011  466.200012  466.200012  8.935200e+06

# %%
import sqlite3

# %%
conn = sqlite3.connect("ADBE.db")
c = conn.cursor()

# %%
c = conn.cursor()
conn = sqlite3.connect("ADBE.db")
c = conn.cursor()

# %%
ADBE.to_sql("ADBE", conn, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
#See data
c.execute("""SELECT * FROM ADBE""")
rows = c.fetchall()
rows
# Out:
# [(0,
#   '2019-08-12',
#   293.140015,
#   294.420013,
#   287.410004,
#   288.649994,
#   288.649994,
#   1580500),
#  (1,
#   '2019-08-13',
#   288.230011,
#   295.5,
#   286.390015,
#   293.170013,
#   293.170013,
#   2326400),
#  (2,
#   '2019-08-14',
#   287.600006,
#   289.649994,
#   281.429993,
#   283.660004,
#   283.660004,
#   2586000),
#  (3,
#   '2019-08-15',
#   285.640015,
#   286.48999,
#   280.859985,
#   282.709991,
#   282.709991,
#   2336800),
#  (4,
#   '2019-08-16',
#   285.579987,
#   290.149994,
#   283.320007,
#   287.450012,
#   287.450012,
#   1954500),
#  (5,
#   '2019-08-19',
#   291.320007,
#   291.769989,
#   287.170013,
#   287.97000099999997,
#   287.97000099999997,
#   1955200),
#  (6,
#   '2019-08-20',
#   287.97000099999997,
#   288.660004,
#   285.399994,
#   285.709991,
#   285.709991,
#   1491000),
#  (7,
#   '2019-08-21',
#   288.540009,
#   292.920013,
#   286.51001,
#   291.52999900000003,
#   291.52999900000003,
#   1520200),
#  (8,
# ...

# %%
ADBE.to_excel("ADBE.xls")

pd.read_excel("ADBE.xls")
# Out:
#      Unnamed: 0        Date        Open  ...       Close   Adj Close   Volume
# 0             0  2019-08-12  293.140015  ...  288.649994  288.649994  1580500
# 1             1  2019-08-13  288.230011  ...  293.170013  293.170013  2326400
# 2             2  2019-08-14  287.600006  ...  283.660004  283.660004  2586000
# 3             3  2019-08-15  285.640015  ...  282.709991  282.709991  2336800
# 4             4  2019-08-16  285.579987  ...  287.450012  287.450012  1954500
# ..          ...         ...         ...  ...         ...         ...      ...
# 249         249  2020-08-06  451.350006  ...  464.109985  464.109985  2362000
# 250         250  2020-08-07  460.869995  ...  449.570007  449.570007  3288300
# 251         251  2020-08-10  450.369995  ...  443.290009  443.290009  1836800
# 252         252  2020-08-11  440.260010  ...  435.230011  435.230011  1899400
# 253         253  2020-08-12  437.369995  ...  445.359985  445.359985  1916808
#
# [254 rows x 8 columns]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize your Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(8,5), dpi=100)

# Line 1

# Keyword Argument Notation
#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

## Line 2

# select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')

# Plot remainder of graph as a dot
plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Adobe Inc. (ADBE)', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})

# X and Y labels
plt.xlabel('Adobe Inc. (ADBE)')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,])
#plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

# Show plot
plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()
